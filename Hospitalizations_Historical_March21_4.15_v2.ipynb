# %%
import requests
import json
from config import api_key
from datetime import datetime

# %%
####Project Skeleton v1 (Starbucks v1_04.15)###

# URL for GET requests to retrieve historical hospitalization data
url = "https://api.covidactnow.org/v2/county/TX.timeseries.json?"

# Date range for March 2021
start_date = "2021-03-01"
end_date = "2021-03-03"  # Adjusted to cover the full month of March 2021

# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# Function to recursively collect field names from a JSON object/dictionary (explore JSON object)
# Collect the path to every field - track field's full path
def collect_fields(json_obj, fields_set, parent_key=''):
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            # Construct a "path" for nested fields
            new_key = f"{parent_key}.{key}" if parent_key else key
            fields_set.add(new_key)
            collect_fields(value, fields_set, new_key)
    elif isinstance(json_obj, list):
        for item in json_obj:
            collect_fields(item, fields_set, parent_key)

# Fetch data from the URL used to query API, parse as JSON, and extract fields
# Add a try-except block around the HTTP request and JSON parsing logic
def fetch_data_and_fields(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError exception for bad responses
        response_json = response.json()

        fields_set = set()
        collect_fields(response_json, fields_set)

        return list(fields_set)
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return []

# # Placeholder for integrating vaccine data
# def integrate_vaccine_data(covid_data):
#     # Fetch or load vaccine data
#     # Align and merge data
#     pass

# # Placeholder for data cleaning
# def clean_data(data):
#     # Handle missing values, anomalies, etc.
#     pass

# # Placeholder for preparing visualization
# def prepare_visualization_data(cleaned_data):
#     # Convert to appropriate JSON format
#     # Optimize for specific visualization library
#     pass

# # Example flow of processing
# covid_data = fetch_data_and_fields(query_url)
# vaccine_data = integrate_vaccine_data(covid_data)
# cleaned_data = clean_data(vaccine_data)
# visualization_data = prepare_visualization_data(cleaned_data)

# %%
####Find All fields from JSON (Starbucks v2_04.15) - to list fields and sample values### == WORKS!

# url = "https://api.covidactnow.org/v2/county/TX.timeseries.json?"
# start_date = "2021-03-01"
# end_date = "2021-03-31"
# query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# def collect_fields(json_obj, fields_dict, parent_key=''):
#     if isinstance(json_obj, dict):
#         for key, value in json_obj.items():
#             new_key = f"{parent_key}.{key}" if parent_key else key
#             # Store a sample value (the first encountered) for each field
#             if new_key not in fields_dict:
#                 fields_dict[new_key] = value if not isinstance(value, (dict, list)) else 'Nested Object/Array'
#             # Recurse into nested dictionaries and lists
#             collect_fields(value, fields_dict, new_key)
#     elif isinstance(json_obj, list):
#         if json_obj:
#             collect_fields(json_obj[0], fields_dict, parent_key)  # Sample from the first item

# def fetch_data_and_fields(url):
#     try:
#         response = requests.get(url)
#         response.raise_for_status()  # Raises an HTTPError for bad responses
#         response_json = response.json()

#         fields_dict = {}
#         collect_fields(response_json, fields_dict)
        
#         return fields_dict
#     except requests.RequestException as e:
#         print(f"Error fetching data: {e}")
#         return {}

# fields_dict = fetch_data_and_fields(query_url)

# # Print each field and its sample value
# for field, sample in sorted(fields_dict.items()):
#     print(f"{field}: {sample}")
# Out:
# actuals: Nested Object/Array
# actuals.cases: 11383
# actuals.contactTracers: None
# actuals.deaths: 45
# actuals.hospitalBeds: Nested Object/Array
# actuals.hospitalBeds.capacity: 91
# actuals.hospitalBeds.currentUsageCovid: 0
# actuals.hospitalBeds.currentUsageTotal: 29
# actuals.hospitalBeds.weeklyCovidAdmissions: 6
# actuals.hsaHospitalBeds: Nested Object/Array
# actuals.hsaHospitalBeds.capacity: 172
# actuals.hsaHospitalBeds.currentUsageCovid: 0
# actuals.hsaHospitalBeds.currentUsageTotal: 64
# actuals.hsaHospitalBeds.weeklyCovidAdmissions: 4
# actuals.hsaIcuBeds: Nested Object/Array
# actuals.hsaIcuBeds.capacity: 12
# actuals.hsaIcuBeds.currentUsageCovid: 0
# actuals.hsaIcuBeds.currentUsageTotal: 5
# actuals.icuBeds: Nested Object/Array
# actuals.icuBeds.capacity: 6
# actuals.icuBeds.currentUsageCovid: 0
# actuals.icuBeds.currentUsageTotal: 3
# actuals.negativeTests: None
# actuals.newCases: 0
# actuals.newDeaths: 0
# actuals.positiveTests: None
# actuals.vaccinationsAdditionalDose: 9941
# actuals.vaccinationsCompleted: 23445
# actuals.vaccinationsFall2022BivalentBooster: 2420
# actuals.vaccinationsInitiated: 26562
# actuals.vaccinationsInitiatedDemographics: Nested Object/Array
# actuals.vaccinationsInitiatedDemographics.age: Nested Object/Array
# actuals.vaccinationsInitiatedDemographics.age.12-15: 546
# actuals.vaccinationsInitiatedDemographics.age.16-49: 12527
# actuals.vaccinationsInitiatedDemographics.age.5-11: 263
# actuals.vaccinationsInitiatedDemographics.age.50-64: 7484
# actuals.vaccinationsInitiatedDemographics.age.65-79: 5169
# actuals.vaccinationsInitiatedDemographics.age.80_plus: 1452
# actuals.vaccinationsInitiatedDemographics.age.unknown: 3
# actuals.vaccinationsInitiatedDemographics.ethnicity: None
# actuals.vaccinationsInitiatedDemographics.race: Nested Object/Array
# actuals.vaccinationsInitiatedDemographics.race.asian: 238
# actuals.vaccinationsInitiatedDemographics.race.black: 5286
# actuals.vaccinationsInitiatedDemographics.race.other: 4702
# actuals.vaccinationsInitiatedDemographics.race.unknown: 836
# actuals.vaccinationsInitiatedDemographics.race.white: 13386
# actuals.vaccinationsInitiatedDemographics.sex: None
# actuals.vaccinesAdministered: None
# actuals.vaccinesAdministeredDemographics: Nested Object/Array
# actuals.vaccinesAdministeredDemographics.age: Nested Object/Array
# actuals.vaccinesAdministeredDemographics.age.12-15: 1036
# actuals.vaccinesAdministeredDemographics.age.16-49: 25697
# actuals.vaccinesAdministeredDemographics.age.5-11: 470
# actuals.vaccinesAdministeredDemographics.age.50-64: 17125
# actuals.vaccinesAdministeredDemographics.age.65-79: 12254
# actuals.vaccinesAdministeredDemographics.age.80_plus: 3581
# actuals.vaccinesAdministeredDemographics.age.unknown: 3
# actuals.vaccinesAdministeredDemographics.ethnicity: None
# actuals.vaccinesAdministeredDemographics.race: Nested Object/Array
# actuals.vaccinesAdministeredDemographics.race.asian: 520
# actuals.vaccinesAdministeredDemographics.race.black: 11109
# actuals.vaccinesAdministeredDemographics.race.other: 9905
# actuals.vaccinesAdministeredDemographics.race.unknown: 1412
# actuals.vaccinesAdministeredDemographics.race.white: 28192
# actuals.vaccinesAdministeredDemographics.sex: None
# actuals.vaccinesDistributed: None
# actualsTimeseries: Nested Object/Array
# actualsTimeseries.cases: None
# actualsTimeseries.contactTracers: None
# actualsTimeseries.date: 2020-03-18
# actualsTimeseries.deaths: None
# actualsTimeseries.hospitalBeds: Nested Object/Array
# actualsTimeseries.hospitalBeds.capacity: None
# actualsTimeseries.hospitalBeds.currentUsageCovid: None
# actualsTimeseries.hospitalBeds.currentUsageTotal: None
# actualsTimeseries.hospitalBeds.weeklyCovidAdmissions: None
# actualsTimeseries.hsaHospitalBeds: Nested Object/Array
# actualsTimeseries.hsaHospitalBeds.capacity: None
# actualsTimeseries.hsaHospitalBeds.currentUsageCovid: None
# actualsTimeseries.hsaHospitalBeds.currentUsageTotal: None
# actualsTimeseries.hsaHospitalBeds.weeklyCovidAdmissions: None
# actualsTimeseries.hsaIcuBeds: Nested Object/Array
# actualsTimeseries.hsaIcuBeds.capacity: None
# actualsTimeseries.hsaIcuBeds.currentUsageCovid: None
# actualsTimeseries.hsaIcuBeds.currentUsageTotal: None
# actualsTimeseries.icuBeds: Nested Object/Array
# actualsTimeseries.icuBeds.capacity: None
# actualsTimeseries.icuBeds.currentUsageCovid: None
# actualsTimeseries.icuBeds.currentUsageTotal: None
# actualsTimeseries.negativeTests: None
# actualsTimeseries.newCases: None
# actualsTimeseries.newDeaths: None
# actualsTimeseries.positiveTests: None
# actualsTimeseries.vaccinationsInitiatedDemographics: None
# actualsTimeseries.vaccinesAdministeredDemographics: None
# annotations: Nested Object/Array
# annotations.bedsWithCovidPatientsRatio: Nested Object/Array
# annotations.bedsWithCovidPatientsRatio.anomalies: Nested Object/Array
# annotations.bedsWithCovidPatientsRatio.sources: Nested Object/Array
# annotations.bedsWithCovidPatientsRatio.sources.name: Department of Health and Human Services
# annotations.bedsWithCovidPatientsRatio.sources.type: other
# annotations.bedsWithCovidPatientsRatio.sources.url: https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# annotations.caseDensity: Nested Object/Array
# annotations.caseDensity.anomalies: Nested Object/Array
# annotations.caseDensity.sources: Nested Object/Array
# annotations.caseDensity.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.caseDensity.sources.type: other
# annotations.caseDensity.sources.url: Nested Object/Array
# annotations.cases: Nested Object/Array
# annotations.cases.anomalies: Nested Object/Array
# annotations.cases.sources: Nested Object/Array
# annotations.cases.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.cases.sources.type: other
# annotations.cases.sources.url: Nested Object/Array
# annotations.contactTracerCapacityRatio: None
# annotations.contactTracers: None
# annotations.deaths: Nested Object/Array
# annotations.deaths.anomalies: Nested Object/Array
# annotations.deaths.sources: Nested Object/Array
# annotations.deaths.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.deaths.sources.type: other
# annotations.deaths.sources.url: Nested Object/Array
# annotations.hospitalBeds: Nested Object/Array
# annotations.hospitalBeds.anomalies: Nested Object/Array
# annotations.hospitalBeds.sources: Nested Object/Array
# annotations.hospitalBeds.sources.name: Department of Health and Human Services
# annotations.hospitalBeds.sources.type: other
# annotations.hospitalBeds.sources.url: https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# annotations.hsaHospitalBeds: None
# annotations.hsaIcuBeds: None
# annotations.icuBeds: Nested Object/Array
# annotations.icuBeds.anomalies: Nested Object/Array
# annotations.icuBeds.sources: Nested Object/Array
# annotations.icuBeds.sources.name: Department of Health and Human Services
# annotations.icuBeds.sources.type: other
# annotations.icuBeds.sources.url: https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# annotations.icuCapacityRatio: Nested Object/Array
# annotations.icuCapacityRatio.anomalies: Nested Object/Array
# annotations.icuCapacityRatio.sources: Nested Object/Array
# annotations.icuCapacityRatio.sources.name: Department of Health and Human Services
# annotations.icuCapacityRatio.sources.type: other
# annotations.icuCapacityRatio.sources.url: https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# annotations.infectionRate: Nested Object/Array
# annotations.infectionRate.anomalies: Nested Object/Array
# annotations.infectionRate.sources: Nested Object/Array
# annotations.infectionRate.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.infectionRate.sources.type: other
# annotations.infectionRate.sources.url: Nested Object/Array
# annotations.infectionRateCI90: Nested Object/Array
# annotations.infectionRateCI90.anomalies: Nested Object/Array
# annotations.infectionRateCI90.sources: Nested Object/Array
# annotations.infectionRateCI90.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.infectionRateCI90.sources.type: other
# annotations.infectionRateCI90.sources.url: Nested Object/Array
# annotations.negativeTests: None
# annotations.newCases: Nested Object/Array
# annotations.newCases.anomalies: Nested Object/Array
# annotations.newCases.anomalies.date: 2020-07-09
# annotations.newCases.anomalies.original_observation: 381.0
# annotations.newCases.anomalies.type: zscore_outlier
# annotations.newCases.sources: Nested Object/Array
# annotations.newDeaths: None
# annotations.positiveTests: None
# annotations.testPositivityRatio: None
# annotations.vaccinationsAdditionalDose: Nested Object/Array
# annotations.vaccinationsAdditionalDose.anomalies: Nested Object/Array
# annotations.vaccinationsAdditionalDose.sources: Nested Object/Array
# annotations.vaccinationsAdditionalDose.sources.name: Centers for Disease Control and Prevention
# annotations.vaccinationsAdditionalDose.sources.type: other
# annotations.vaccinationsAdditionalDose.sources.url: https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh
# annotations.vaccinationsAdditionalDoseRatio: None
# annotations.vaccinationsCompleted: Nested Object/Array
# annotations.vaccinationsCompleted.anomalies: Nested Object/Array
# annotations.vaccinationsCompleted.sources: Nested Object/Array
# annotations.vaccinationsCompleted.sources.name: Centers for Disease Control and Prevention
# annotations.vaccinationsCompleted.sources.type: other
# annotations.vaccinationsCompleted.sources.url: https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh
# annotations.vaccinationsCompletedRatio: None
# annotations.vaccinationsFall2022BivalentBooster: Nested Object/Array
# annotations.vaccinationsFall2022BivalentBooster.anomalies: Nested Object/Array
# annotations.vaccinationsFall2022BivalentBooster.sources: Nested Object/Array
# annotations.vaccinationsFall2022BivalentBooster.sources.name: Centers for Disease Control and Prevention
# annotations.vaccinationsFall2022BivalentBooster.sources.type: other
# annotations.vaccinationsFall2022BivalentBooster.sources.url: https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh
# annotations.vaccinationsFall2022BivalentBoosterRatio: None
# annotations.vaccinationsInitiated: Nested Object/Array
# annotations.vaccinationsInitiated.anomalies: Nested Object/Array
# annotations.vaccinationsInitiated.sources: Nested Object/Array
# annotations.vaccinationsInitiated.sources.name: Centers for Disease Control and Prevention
# annotations.vaccinationsInitiated.sources.type: other
# annotations.vaccinationsInitiated.sources.url: https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh
# annotations.vaccinationsInitiatedRatio: None
# annotations.vaccinesAdministered: None
# annotations.vaccinesDistributed: None
# annotations.weeklyCovidAdmissionsPer100k: Nested Object/Array
# annotations.weeklyCovidAdmissionsPer100k.anomalies: Nested Object/Array
# annotations.weeklyCovidAdmissionsPer100k.sources: Nested Object/Array
# annotations.weeklyCovidAdmissionsPer100k.sources.name: Department of Health and Human Services
# annotations.weeklyCovidAdmissionsPer100k.sources.type: other
# annotations.weeklyCovidAdmissionsPer100k.sources.url: https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# annotations.weeklyNewCasesPer100k: Nested Object/Array
# annotations.weeklyNewCasesPer100k.anomalies: Nested Object/Array
# annotations.weeklyNewCasesPer100k.sources: Nested Object/Array
# annotations.weeklyNewCasesPer100k.sources.name: Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.
# annotations.weeklyNewCasesPer100k.sources.type: other
# annotations.weeklyNewCasesPer100k.sources.url: Nested Object/Array
# cdcTransmissionLevel: 4
# cdcTransmissionLevelTimeseries: Nested Object/Array
# cdcTransmissionLevelTimeseries.cdcTransmissionLevel: 0
# cdcTransmissionLevelTimeseries.date: 2020-03-18
# communityLevels: Nested Object/Array
# communityLevels.canCommunityLevel: 0
# communityLevels.cdcCommunityLevel: 0
# communityLevelsTimeseries: Nested Object/Array
# communityLevelsTimeseries.canCommunityLevel: None
# communityLevelsTimeseries.cdcCommunityLevel: None
# communityLevelsTimeseries.date: 2020-03-18
# country: US
# county: Anderson County
# fips: 48001
# hsa: 509
# hsaName: Anderson, TX - Cherokee, TX
# hsaPopulation: 133349
# lastUpdatedDate: 2024-04-15
# lat: None
# level: county
# locationId: iso1:us#iso2:us-tx#fips:48001
# long: None
# metrics: Nested Object/Array
# metrics.bedsWithCovidPatientsRatio: 0.003
# metrics.caseDensity: None
# metrics.contactTracerCapacityRatio: None
# metrics.icuCapacityRatio: 0.5
# metrics.infectionRate: None
# metrics.infectionRateCI90: None
# metrics.testPositivityRatio: None
# metrics.testPositivityRatioDetails: Nested Object/Array
# metrics.testPositivityRatioDetails.source: other
# metrics.vaccinationsAdditionalDoseRatio: 0.172
# metrics.vaccinationsCompletedRatio: 0.406
# metrics.vaccinationsFall2022BivalentBoosterRatio: 0.042
# metrics.vaccinationsInitiatedRatio: 0.46
# metrics.weeklyCovidAdmissionsPer100k: None
# metrics.weeklyNewCasesPer100k: None
# metricsTimeseries: Nested Object/Array
# metricsTimeseries.bedsWithCovidPatientsRatio: None
# metricsTimeseries.caseDensity: 0.0
# metricsTimeseries.contactTracerCapacityRatio: None
# metricsTimeseries.date: 2020-03-18
# metricsTimeseries.icuCapacityRatio: None
# metricsTimeseries.infectionRate: None
# metricsTimeseries.infectionRateCI90: None
# metricsTimeseries.testPositivityRatio: None
# metricsTimeseries.weeklyCovidAdmissionsPer100k: None
# metricsTimeseries.weeklyNewCasesPer100k: 0.0
# population: 57735
# riskLevels: Nested Object/Array
# riskLevels.caseDensity: 4
# riskLevels.contactTracerCapacityRatio: 4
# riskLevels.icuCapacityRatio: 0
# riskLevels.infectionRate: 4
# riskLevels.overall: 4
# riskLevels.testPositivityRatio: 4
# riskLevelsTimeseries: Nested Object/Array
# riskLevelsTimeseries.caseDensity: 0
# riskLevelsTimeseries.date: 2020-03-18
# riskLevelsTimeseries.overall: 0
# state: TX
# url: https://covidactnow.org/us/texas-tx/county/anderson_county

# %%
####Find All fields from JSON (PREVIOUS V1) ###

# URL for GET requests to retrieve historical hospitalization data
url = "https://api.covidactnow.org/v2/county/TX.timeseries.json?"

# Date range for March 2021
start_date = "2021-03-01"
end_date = "2021-03-03"  # Adjusted to cover the full month of March 2021

# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# Function to recursively collect field names from a JSON object/dictionary
def collect_fields(json_obj, fields_set, parent_key=''):
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            # Constructing a "path" for nested fields
            new_key = f"{parent_key}.{key}" if parent_key else key
            fields_set.add(new_key)
            collect_fields(value, fields_set, new_key)
    elif isinstance(json_obj, list):
        for item in json_obj:
            collect_fields(item, fields_set, parent_key)

# Function to fetch and parse the JSON data from the API
def fetch_data_and_fields(url):
    response = requests.get(url)
    response_json = response.json()
    
    fields_set = set()
    collect_fields(response_json, fields_set)
    
    return list(fields_set)

# Fetching data and collecting fields
fields = fetch_data_and_fields(query_url)

# Printing the number of different fields
print(f"Total number of different fields: {len(fields)}")

# # Printing the list of all fields
# for field in sorted(fields):
#     print(field)
# Out:
# Total number of different fields: 284

# %%
# Printing the list of all fields
for field in sorted(fields):
    print(field)
# Out:
# actuals
# actuals.cases
# actuals.contactTracers
# actuals.deaths
# actuals.hospitalBeds
# actuals.hospitalBeds.capacity
# actuals.hospitalBeds.currentUsageCovid
# actuals.hospitalBeds.currentUsageTotal
# actuals.hospitalBeds.weeklyCovidAdmissions
# actuals.hsaHospitalBeds
# actuals.hsaHospitalBeds.capacity
# actuals.hsaHospitalBeds.currentUsageCovid
# actuals.hsaHospitalBeds.currentUsageTotal
# actuals.hsaHospitalBeds.weeklyCovidAdmissions
# actuals.hsaIcuBeds
# actuals.hsaIcuBeds.capacity
# actuals.hsaIcuBeds.currentUsageCovid
# actuals.hsaIcuBeds.currentUsageTotal
# actuals.icuBeds
# actuals.icuBeds.capacity
# actuals.icuBeds.currentUsageCovid
# actuals.icuBeds.currentUsageTotal
# actuals.negativeTests
# actuals.newCases
# actuals.newDeaths
# actuals.positiveTests
# actuals.vaccinationsAdditionalDose
# actuals.vaccinationsCompleted
# actuals.vaccinationsFall2022BivalentBooster
# actuals.vaccinationsInitiated
# actuals.vaccinationsInitiatedDemographics
# actuals.vaccinationsInitiatedDemographics.age
# actuals.vaccinationsInitiatedDemographics.age.12-15
# actuals.vaccinationsInitiatedDemographics.age.16-49
# actuals.vaccinationsInitiatedDemographics.age.5-11
# actuals.vaccinationsInitiatedDemographics.age.50-64
# actuals.vaccinationsInitiatedDemographics.age.65-79
# actuals.vaccinationsInitiatedDemographics.age.80_plus
# actuals.vaccinationsInitiatedDemographics.age.unknown
# actuals.vaccinationsInitiatedDemographics.ethnicity
# actuals.vaccinationsInitiatedDemographics.race
# actuals.vaccinationsInitiatedDemographics.race.asian
# actuals.vaccinationsInitiatedDemographics.race.black
# actuals.vaccinationsInitiatedDemographics.race.other
# actuals.vaccinationsInitiatedDemographics.race.unknown
# actuals.vaccinationsInitiatedDemographics.race.white
# actuals.vaccinationsInitiatedDemographics.sex
# actuals.vaccinesAdministered
# actuals.vaccinesAdministeredDemographics
# actuals.vaccinesAdministeredDemographics.age
# actuals.vaccinesAdministeredDemographics.age.12-15
# actuals.vaccinesAdministeredDemographics.age.16-49
# actuals.vaccinesAdministeredDemographics.age.5-11
# actuals.vaccinesAdministeredDemographics.age.50-64
# actuals.vaccinesAdministeredDemographics.age.65-79
# actuals.vaccinesAdministeredDemographics.age.80_plus
# actuals.vaccinesAdministeredDemographics.age.unknown
# actuals.vaccinesAdministeredDemographics.ethnicity
# actuals.vaccinesAdministeredDemographics.race
# actuals.vaccinesAdministeredDemographics.race.asian
# actuals.vaccinesAdministeredDemographics.race.black
# actuals.vaccinesAdministeredDemographics.race.other
# actuals.vaccinesAdministeredDemographics.race.unknown
# actuals.vaccinesAdministeredDemographics.race.white
# actuals.vaccinesAdministeredDemographics.sex
# actuals.vaccinesDistributed
# actualsTimeseries
# actualsTimeseries.cases
# actualsTimeseries.contactTracers
# actualsTimeseries.date
# actualsTimeseries.deaths
# actualsTimeseries.hospitalBeds
# actualsTimeseries.hospitalBeds.capacity
# actualsTimeseries.hospitalBeds.currentUsageCovid
# actualsTimeseries.hospitalBeds.currentUsageTotal
# actualsTimeseries.hospitalBeds.weeklyCovidAdmissions
# actualsTimeseries.hsaHospitalBeds
# actualsTimeseries.hsaHospitalBeds.capacity
# actualsTimeseries.hsaHospitalBeds.currentUsageCovid
# actualsTimeseries.hsaHospitalBeds.currentUsageTotal
# actualsTimeseries.hsaHospitalBeds.weeklyCovidAdmissions
# actualsTimeseries.hsaIcuBeds
# actualsTimeseries.hsaIcuBeds.capacity
# actualsTimeseries.hsaIcuBeds.currentUsageCovid
# actualsTimeseries.hsaIcuBeds.currentUsageTotal
# actualsTimeseries.icuBeds
# actualsTimeseries.icuBeds.capacity
# actualsTimeseries.icuBeds.currentUsageCovid
# actualsTimeseries.icuBeds.currentUsageTotal
# actualsTimeseries.negativeTests
# actualsTimeseries.newCases
# actualsTimeseries.newDeaths
# actualsTimeseries.positiveTests
# actualsTimeseries.vaccinationsAdditionalDose
# actualsTimeseries.vaccinationsCompleted
# actualsTimeseries.vaccinationsFall2022BivalentBooster
# actualsTimeseries.vaccinationsInitiated
# actualsTimeseries.vaccinationsInitiatedDemographics
# actualsTimeseries.vaccinesAdministered
# actualsTimeseries.vaccinesAdministeredDemographics
# actualsTimeseries.vaccinesDistributed
# annotations
# annotations.bedsWithCovidPatientsRatio
# annotations.bedsWithCovidPatientsRatio.anomalies
# annotations.bedsWithCovidPatientsRatio.sources
# annotations.bedsWithCovidPatientsRatio.sources.name
# annotations.bedsWithCovidPatientsRatio.sources.type
# annotations.bedsWithCovidPatientsRatio.sources.url
# annotations.caseDensity
# annotations.caseDensity.anomalies
# annotations.caseDensity.sources
# annotations.caseDensity.sources.name
# annotations.caseDensity.sources.type
# annotations.caseDensity.sources.url
# annotations.cases
# annotations.cases.anomalies
# annotations.cases.sources
# annotations.cases.sources.name
# annotations.cases.sources.type
# annotations.cases.sources.url
# annotations.contactTracerCapacityRatio
# annotations.contactTracers
# annotations.deaths
# annotations.deaths.anomalies
# annotations.deaths.sources
# annotations.deaths.sources.name
# annotations.deaths.sources.type
# annotations.deaths.sources.url
# annotations.hospitalBeds
# annotations.hospitalBeds.anomalies
# annotations.hospitalBeds.sources
# annotations.hospitalBeds.sources.name
# annotations.hospitalBeds.sources.type
# annotations.hospitalBeds.sources.url
# annotations.hsaHospitalBeds
# annotations.hsaIcuBeds
# annotations.icuBeds
# annotations.icuBeds.anomalies
# annotations.icuBeds.sources
# annotations.icuBeds.sources.name
# annotations.icuBeds.sources.type
# annotations.icuBeds.sources.url
# annotations.icuCapacityRatio
# annotations.icuCapacityRatio.anomalies
# annotations.icuCapacityRatio.sources
# annotations.icuCapacityRatio.sources.name
# annotations.icuCapacityRatio.sources.type
# annotations.icuCapacityRatio.sources.url
# annotations.infectionRate
# annotations.infectionRate.anomalies
# annotations.infectionRate.sources
# annotations.infectionRate.sources.name
# annotations.infectionRate.sources.type
# annotations.infectionRate.sources.url
# annotations.infectionRateCI90
# annotations.infectionRateCI90.anomalies
# annotations.infectionRateCI90.sources
# annotations.infectionRateCI90.sources.name
# annotations.infectionRateCI90.sources.type
# annotations.infectionRateCI90.sources.url
# annotations.negativeTests
# annotations.newCases
# annotations.newCases.anomalies
# annotations.newCases.anomalies.date
# annotations.newCases.anomalies.original_observation
# annotations.newCases.anomalies.type
# annotations.newCases.sources
# annotations.newDeaths
# annotations.newDeaths.anomalies
# annotations.newDeaths.anomalies.date
# annotations.newDeaths.anomalies.original_observation
# annotations.newDeaths.anomalies.type
# annotations.newDeaths.sources
# annotations.positiveTests
# annotations.testPositivityRatio
# annotations.vaccinationsAdditionalDose
# annotations.vaccinationsAdditionalDose.anomalies
# annotations.vaccinationsAdditionalDose.sources
# annotations.vaccinationsAdditionalDose.sources.name
# annotations.vaccinationsAdditionalDose.sources.type
# annotations.vaccinationsAdditionalDose.sources.url
# annotations.vaccinationsAdditionalDoseRatio
# annotations.vaccinationsCompleted
# annotations.vaccinationsCompleted.anomalies
# annotations.vaccinationsCompleted.sources
# annotations.vaccinationsCompleted.sources.name
# annotations.vaccinationsCompleted.sources.type
# annotations.vaccinationsCompleted.sources.url
# annotations.vaccinationsCompletedRatio
# annotations.vaccinationsFall2022BivalentBooster
# annotations.vaccinationsFall2022BivalentBooster.anomalies
# annotations.vaccinationsFall2022BivalentBooster.sources
# annotations.vaccinationsFall2022BivalentBooster.sources.name
# annotations.vaccinationsFall2022BivalentBooster.sources.type
# annotations.vaccinationsFall2022BivalentBooster.sources.url
# annotations.vaccinationsFall2022BivalentBoosterRatio
# annotations.vaccinationsInitiated
# annotations.vaccinationsInitiated.anomalies
# annotations.vaccinationsInitiated.sources
# annotations.vaccinationsInitiated.sources.name
# annotations.vaccinationsInitiated.sources.type
# annotations.vaccinationsInitiated.sources.url
# annotations.vaccinationsInitiatedRatio
# annotations.vaccinesAdministered
# annotations.vaccinesDistributed
# annotations.weeklyCovidAdmissionsPer100k
# annotations.weeklyCovidAdmissionsPer100k.anomalies
# annotations.weeklyCovidAdmissionsPer100k.sources
# annotations.weeklyCovidAdmissionsPer100k.sources.name
# annotations.weeklyCovidAdmissionsPer100k.sources.type
# annotations.weeklyCovidAdmissionsPer100k.sources.url
# annotations.weeklyNewCasesPer100k
# annotations.weeklyNewCasesPer100k.anomalies
# annotations.weeklyNewCasesPer100k.sources
# annotations.weeklyNewCasesPer100k.sources.name
# annotations.weeklyNewCasesPer100k.sources.type
# annotations.weeklyNewCasesPer100k.sources.url
# cdcTransmissionLevel
# cdcTransmissionLevelTimeseries
# cdcTransmissionLevelTimeseries.cdcTransmissionLevel
# cdcTransmissionLevelTimeseries.date
# communityLevels
# communityLevels.canCommunityLevel
# communityLevels.cdcCommunityLevel
# communityLevelsTimeseries
# communityLevelsTimeseries.canCommunityLevel
# communityLevelsTimeseries.cdcCommunityLevel
# communityLevelsTimeseries.date
# country
# county
# fips
# hsa
# hsaName
# hsaPopulation
# lastUpdatedDate
# lat
# level
# locationId
# long
# metrics
# metrics.bedsWithCovidPatientsRatio
# metrics.caseDensity
# metrics.contactTracerCapacityRatio
# metrics.icuCapacityRatio
# metrics.infectionRate
# metrics.infectionRateCI90
# metrics.testPositivityRatio
# metrics.testPositivityRatioDetails
# metrics.testPositivityRatioDetails.source
# metrics.vaccinationsAdditionalDoseRatio
# metrics.vaccinationsCompletedRatio
# metrics.vaccinationsFall2022BivalentBoosterRatio
# metrics.vaccinationsInitiatedRatio
# metrics.weeklyCovidAdmissionsPer100k
# metrics.weeklyNewCasesPer100k
# metricsTimeseries
# metricsTimeseries.bedsWithCovidPatientsRatio
# metricsTimeseries.caseDensity
# metricsTimeseries.contactTracerCapacityRatio
# metricsTimeseries.date
# metricsTimeseries.icuCapacityRatio
# metricsTimeseries.infectionRate
# metricsTimeseries.infectionRateCI90
# metricsTimeseries.testPositivityRatio
# metricsTimeseries.vaccinationsAdditionalDoseRatio
# metricsTimeseries.vaccinationsCompletedRatio
# metricsTimeseries.vaccinationsFall2022BivalentBoosterRatio
# metricsTimeseries.vaccinationsInitiatedRatio
# metricsTimeseries.weeklyCovidAdmissionsPer100k
# metricsTimeseries.weeklyNewCasesPer100k
# population
# riskLevels
# riskLevels.caseDensity
# riskLevels.contactTracerCapacityRatio
# riskLevels.icuCapacityRatio
# riskLevels.infectionRate
# riskLevels.overall
# riskLevels.testPositivityRatio
# riskLevelsTimeseries
# riskLevelsTimeseries.caseDensity
# riskLevelsTimeseries.date
# riskLevelsTimeseries.overall
# state
# url

# %%
# Show hospitalizations (one for each county)
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()

# Extract and process hospitalization data for March 2021
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    hospitalizations = county_data["actuals"]["hospitalBeds"]
    hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})

# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")

# Print hospitalization data for March 2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# Total hospitalization entries for March 2021: 254
#
# County: Anderson County, Hospitalizations in March 2021: {'capacity': 91, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Andrews County, Hospitalizations in March 2021: {'capacity': 37, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Angelina County, Hospitalizations in March 2021: {'capacity': 177, 'currentUsageTotal': 151, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Aransas County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Hospitalizations in March 2021: {'capacity': 68, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Austin County, Hospitalizations in March 2021: {'capacity': 9, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Bailey County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bandera County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bastrop County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Baylor County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Bee County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 24, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bell County, Hospitalizations in March 2021: {'capacity': 828, 'currentUsageTotal': 787, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 18}
# County: Bexar County, Hospitalizations in March 2021: {'capacity': 4965, 'currentUsageTotal': 3633, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 41}
# County: Blanco County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Borden County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bosque County, Hospitalizations in March 2021: {'capacity': 11, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Bowie County, Hospitalizations in March 2021: {'capacity': 435, 'currentUsageTotal': 335, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 24}
# County: Brazoria County, Hospitalizations in March 2021: {'capacity': 120, 'currentUsageTotal': 112, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 9}
# County: Brazos County, Hospitalizations in March 2021: {'capacity': 682, 'currentUsageTotal': 362, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 14}
# County: Brewster County, Hospitalizations in March 2021: {'capacity': 58, 'currentUsageTotal': 25, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Briscoe County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Brooks County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Brown County, Hospitalizations in March 2021: {'capacity': 45, 'currentUsageTotal': 44, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Burleson County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 6, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Burnet County, Hospitalizations in March 2021: {'capacity': 51, 'currentUsageTotal': 45, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Caldwell County, Hospitalizations in March 2021: {'capacity': 57, 'currentUsageTotal': 47, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': 30, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Callahan County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Cameron County, Hospitalizations in March 2021: {'capacity': 930, 'currentUsageTotal': 754, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 6}
# County: Camp County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Carson County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Cass County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Castro County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Chambers County, Hospitalizations in March 2021: {'capacity': 62, 'currentUsageTotal': 6, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Cherokee County, Hospitalizations in March 2021: {'capacity': 66, 'currentUsageTotal': 30, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Childress County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Clay County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cochran County, Hospitalizations in March 2021: {'capacity': 2, 'currentUsageTotal': 1, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Coke County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Coleman County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Collin County, Hospitalizations in March 2021: {'capacity': 1825, 'currentUsageTotal': 1608, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 5}
# County: Collingsworth County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 2, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Colorado County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 18, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Comal County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 88, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Comanche County, Hospitalizations in March 2021: {'capacity': 65, 'currentUsageTotal': 16, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Concho County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 1, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': None}
# County: Cooke County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 33, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Coryell County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cottle County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Crane County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Crockett County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Crosby County, Hospitalizations in March 2021: {'capacity': 2, 'currentUsageTotal': 0, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Culberson County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Dallam County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Dallas County, Hospitalizations in March 2021: {'capacity': 5479, 'currentUsageTotal': 4806, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 12}
# County: Dawson County, Hospitalizations in March 2021: {'capacity': 8, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Deaf Smith County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Delta County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Denton County, Hospitalizations in March 2021: {'capacity': 664, 'currentUsageTotal': 553, 'currentUsageCovid': 21, 'weeklyCovidAdmissions': 5}
# County: DeWitt County, Hospitalizations in March 2021: {'capacity': 73, 'currentUsageTotal': 13, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Dickens County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Dimmit County, Hospitalizations in March 2021: {'capacity': 23, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Donley County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Duval County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Eastland County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Ector County, Hospitalizations in March 2021: {'capacity': 396, 'currentUsageTotal': 290, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Edwards County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Ellis County, Hospitalizations in March 2021: {'capacity': 179, 'currentUsageTotal': 164, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: El Paso County, Hospitalizations in March 2021: {'capacity': 1499, 'currentUsageTotal': 1396, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 23}
# County: Erath County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 8, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Falls County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Fannin County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 18, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Fayette County, Hospitalizations in March 2021: {'capacity': 1, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Fisher County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Floyd County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Foard County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Fort Bend County, Hospitalizations in March 2021: {'capacity': 658, 'currentUsageTotal': 567, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Franklin County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Freestone County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Frio County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gaines County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 11}
# County: Galveston County, Hospitalizations in March 2021: {'capacity': 302, 'currentUsageTotal': 286, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 8}
# County: Garza County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Gillespie County, Hospitalizations in March 2021: {'capacity': 89, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Glasscock County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Goliad County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Gonzales County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gray County, Hospitalizations in March 2021: {'capacity': 89, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Grayson County, Hospitalizations in March 2021: {'capacity': 367, 'currentUsageTotal': 298, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Gregg County, Hospitalizations in March 2021: {'capacity': 560, 'currentUsageTotal': 497, 'currentUsageCovid': 20, 'weeklyCovidAdmissions': 35}
# County: Grimes County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Guadalupe County, Hospitalizations in March 2021: {'capacity': 170, 'currentUsageTotal': 42, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Hale County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 18, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Hall County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Hamilton County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hansford County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hardeman County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Hardin County, Hospitalizations in March 2021: {'capacity': 4, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Harris County, Hospitalizations in March 2021: {'capacity': 9637, 'currentUsageTotal': 8948, 'currentUsageCovid': 132, 'weeklyCovidAdmissions': 103}
# County: Harrison County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Hartley County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Haskell County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Hays County, Hospitalizations in March 2021: {'capacity': 190, 'currentUsageTotal': 174, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Hemphill County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Henderson County, Hospitalizations in March 2021: {'capacity': 53, 'currentUsageTotal': 39, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hidalgo County, Hospitalizations in March 2021: {'capacity': 1704, 'currentUsageTotal': 1326, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 74}
# County: Hill County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hockley County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hood County, Hospitalizations in March 2021: {'capacity': 49, 'currentUsageTotal': 38, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hopkins County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Houston County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Howard County, Hospitalizations in March 2021: {'capacity': 106, 'currentUsageTotal': 22, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hudspeth County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Hunt County, Hospitalizations in March 2021: {'capacity': 128, 'currentUsageTotal': 126, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Hutchinson County, Hospitalizations in March 2021: {'capacity': 41, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Irion County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Jack County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Jasper County, Hospitalizations in March 2021: {'capacity': 71, 'currentUsageTotal': 44, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Jeff Davis County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 594, 'currentUsageTotal': 534, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 7}
# County: Jim Hogg County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Jim Wells County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Johnson County, Hospitalizations in March 2021: {'capacity': 254, 'currentUsageTotal': 230, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Jones County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Karnes County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Kaufman County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Kendall County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Kenedy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Kent County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Kerr County, Hospitalizations in March 2021: {'capacity': 137, 'currentUsageTotal': 85, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Kimble County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: King County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Kinney County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Kleberg County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Knox County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 34, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Lamar County, Hospitalizations in March 2021: {'capacity': 125, 'currentUsageTotal': 102, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Lamb County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lampasas County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: La Salle County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lavaca County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Lee County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Leon County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Liberty County, Hospitalizations in March 2021: {'capacity': 30, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Limestone County, Hospitalizations in March 2021: {'capacity': 54, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Lipscomb County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Live Oak County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Llano County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 1, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Loving County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lubbock County, Hospitalizations in March 2021: {'capacity': 1187, 'currentUsageTotal': 901, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 15}
# County: Lynn County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: McCulloch County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: McLennan County, Hospitalizations in March 2021: {'capacity': 411, 'currentUsageTotal': 394, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 13}
# County: McMullen County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Madison County, Hospitalizations in March 2021: {'capacity': 9, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Marion County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Martin County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Mason County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Matagorda County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Maverick County, Hospitalizations in March 2021: {'capacity': 109, 'currentUsageTotal': 51, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Medina County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 12, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Menard County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Midland County, Hospitalizations in March 2021: {'capacity': 222, 'currentUsageTotal': 173, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Milam County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Mills County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Mitchell County, Hospitalizations in March 2021: {'capacity': 39, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Montague County, Hospitalizations in March 2021: {'capacity': 23, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Montgomery County, Hospitalizations in March 2021: {'capacity': 768, 'currentUsageTotal': 736, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 12}
# County: Moore County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Morris County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Motley County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Nacogdoches County, Hospitalizations in March 2021: {'capacity': 129, 'currentUsageTotal': 93, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Navarro County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Newton County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Nolan County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Nueces County, Hospitalizations in March 2021: {'capacity': 838, 'currentUsageTotal': 713, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 42}
# County: Ochiltree County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Oldham County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Orange County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Palo Pinto County, Hospitalizations in March 2021: {'capacity': 39, 'currentUsageTotal': 22, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 24}
# County: Panola County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Parker County, Hospitalizations in March 2021: {'capacity': 88, 'currentUsageTotal': 88, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Parmer County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Pecos County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Polk County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Potter County, Hospitalizations in March 2021: {'capacity': 659, 'currentUsageTotal': 607, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 10}
# County: Presidio County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Rains County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Randall County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Reagan County, Hospitalizations in March 2021: {'capacity': 2, 'currentUsageTotal': 0, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Real County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Red River County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Reeves County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 11, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Refugio County, Hospitalizations in March 2021: {'capacity': 8, 'currentUsageTotal': 2, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Roberts County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Robertson County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Rockwall County, Hospitalizations in March 2021: {'capacity': 68, 'currentUsageTotal': 49, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 10}
# County: Runnels County, Hospitalizations in March 2021: {'capacity': 36, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Rusk County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Sabine County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: San Augustine County, Hospitalizations in March 2021: {'capacity': 4, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: San Jacinto County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Patricio County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Saba County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Schleicher County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 2, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Scurry County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Shackelford County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Shelby County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sherman County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Smith County, Hospitalizations in March 2021: {'capacity': 1100, 'currentUsageTotal': 897, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 7}
# County: Somervell County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Starr County, Hospitalizations in March 2021: {'capacity': 36, 'currentUsageTotal': 18, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 10}
# County: Stephens County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Sterling County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Stonewall County, Hospitalizations in March 2021: {'capacity': 9, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Sutton County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Swisher County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Tarrant County, Hospitalizations in March 2021: {'capacity': 4083, 'currentUsageTotal': 3647, 'currentUsageCovid': 102, 'weeklyCovidAdmissions': 41}
# County: Taylor County, Hospitalizations in March 2021: {'capacity': 420, 'currentUsageTotal': 390, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Terrell County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Terry County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 0, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Throckmorton County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Titus County, Hospitalizations in March 2021: {'capacity': 60, 'currentUsageTotal': 51, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Tom Green County, Hospitalizations in March 2021: {'capacity': 451, 'currentUsageTotal': 276, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 9}
# County: Travis County, Hospitalizations in March 2021: {'capacity': 2115, 'currentUsageTotal': 1862, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 7}
# County: Trinity County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Tyler County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Upshur County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Upton County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 31, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Uvalde County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 17, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Val Verde County, Hospitalizations in March 2021: {'capacity': 87, 'currentUsageTotal': 23, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Van Zandt County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Victoria County, Hospitalizations in March 2021: {'capacity': 671, 'currentUsageTotal': 261, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Walker County, Hospitalizations in March 2021: {'capacity': 69, 'currentUsageTotal': 59, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Waller County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Ward County, Hospitalizations in March 2021: {'capacity': 67, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 36, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Webb County, Hospitalizations in March 2021: {'capacity': 355, 'currentUsageTotal': 317, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 5}
# County: Wharton County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wheeler County, Hospitalizations in March 2021: {'capacity': 46, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wichita County, Hospitalizations in March 2021: {'capacity': 274, 'currentUsageTotal': 230, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Wilbarger County, Hospitalizations in March 2021: {'capacity': 41, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Willacy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Williamson County, Hospitalizations in March 2021: {'capacity': 578, 'currentUsageTotal': 506, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 8}
# County: Wilson County, Hospitalizations in March 2021: {'capacity': 53, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Winkler County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wise County, Hospitalizations in March 2021: {'capacity': 113, 'currentUsageTotal': 76, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Wood County, Hospitalizations in March 2021: {'capacity': 66, 'currentUsageTotal': 31, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Yoakum County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Young County, Hospitalizations in March 2021: {'capacity': 53, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Zapata County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}

# %%
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()

# Ensure covid_data is a list of dictionaries; each dictionary represents a county
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    # Check if 'actualsTimeseries' is a list and iterate through it
    for date_entry in county_data["actualsTimeseries"]:
        date = date_entry.get("date")
        # Filter for March 2021 entries
        if date.startswith("2021-03"):
            # Assuming 'hospitalBeds' data exists and is structured as needed
            hospitalizations = date_entry.get("hsaHospitalBeds", {})
            # Append a new entry for each date in March 2021
            hospitalizations_march_2021.append({
                "County": county_name,
                "Date": date,
                "Hospitalizations": hospitalizations
            })

# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")

# Adjusted print to include date
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Date: {data['Date']}, Hospitalizations: {data['Hospitalizations']}")
# Out:
# Total hospitalization entries for March 2021: 7874
#
# County: Anderson County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-04, Hospitalizations: {'capacity': 264, 'currentUsageTotal': 75, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 12}
# County: Anderson County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-06, Hospitalizations: {'capacity': 263, 'currentUsageTotal': 80, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-11, Hospitalizations: {'capacity': 252, 'currentUsageTotal': 82, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-13, Hospitalizations: {'capacity': 252, 'currentUsageTotal': 78, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-18, Hospitalizations: {'capacity': 275, 'currentUsageTotal': 65, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-20, Hospitalizations: {'capacity': 286, 'currentUsageTotal': 60, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-25, Hospitalizations: {'capacity': 276, 'currentUsageTotal': 63, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-27, Hospitalizations: {'capacity': 267, 'currentUsageTotal': 68, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anderson County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-04, Hospitalizations: {'capacity': 97, 'currentUsageTotal': 40, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-06, Hospitalizations: {'capacity': 95, 'currentUsageTotal': 38, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-11, Hospitalizations: {'capacity': 88, 'currentUsageTotal': 33, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-13, Hospitalizations: {'capacity': 90, 'currentUsageTotal': 34, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-18, Hospitalizations: {'capacity': 95, 'currentUsageTotal': 42, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-20, Hospitalizations: {'capacity': 96, 'currentUsageTotal': 42, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-25, Hospitalizations: {'capacity': 96, 'currentUsageTotal': 38, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-27, Hospitalizations: {'capacity': 94, 'currentUsageTotal': 39, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Andrews County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-04, Hospitalizations: {'capacity': 401, 'currentUsageTotal': 325, 'currentUsageCovid': 53, 'weeklyCovidAdmissions': 19}
# County: Angelina County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-06, Hospitalizations: {'capacity': 403, 'currentUsageTotal': 319, 'currentUsageCovid': 52, 'weeklyCovidAdmissions': 14}
# County: Angelina County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-11, Hospitalizations: {'capacity': 394, 'currentUsageTotal': 319, 'currentUsageCovid': 47, 'weeklyCovidAdmissions': 8}
# County: Angelina County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-13, Hospitalizations: {'capacity': 388, 'currentUsageTotal': 314, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 9}
# County: Angelina County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-18, Hospitalizations: {'capacity': 390, 'currentUsageTotal': 286, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 16}
# County: Angelina County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-20, Hospitalizations: {'capacity': 400, 'currentUsageTotal': 280, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 15}
# County: Angelina County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-25, Hospitalizations: {'capacity': 399, 'currentUsageTotal': 290, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 12}
# County: Angelina County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-27, Hospitalizations: {'capacity': 391, 'currentUsageTotal': 291, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 14}
# County: Angelina County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Angelina County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-04, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 997, 'currentUsageCovid': 98, 'weeklyCovidAdmissions': 42}
# County: Aransas County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-06, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 991, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 50}
# County: Aransas County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-11, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 988, 'currentUsageCovid': 97, 'weeklyCovidAdmissions': 53}
# County: Aransas County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-13, Hospitalizations: {'capacity': 1712, 'currentUsageTotal': 996, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 48}
# County: Aransas County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-18, Hospitalizations: {'capacity': 1721, 'currentUsageTotal': 986, 'currentUsageCovid': 86, 'weeklyCovidAdmissions': 46}
# County: Aransas County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-20, Hospitalizations: {'capacity': 1727, 'currentUsageTotal': 962, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 40}
# County: Aransas County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-25, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 945, 'currentUsageCovid': 80, 'weeklyCovidAdmissions': 44}
# County: Aransas County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-27, Hospitalizations: {'capacity': 1720, 'currentUsageTotal': 953, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 52}
# County: Aransas County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aransas County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Archer County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Archer County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Archer County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Archer County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Archer County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Archer County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Archer County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Archer County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Archer County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-04, Hospitalizations: {'capacity': 823, 'currentUsageTotal': 597, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 42}
# County: Armstrong County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-06, Hospitalizations: {'capacity': 820, 'currentUsageTotal': 597, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 44}
# County: Armstrong County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-11, Hospitalizations: {'capacity': 832, 'currentUsageTotal': 614, 'currentUsageCovid': 44, 'weeklyCovidAdmissions': 46}
# County: Armstrong County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-13, Hospitalizations: {'capacity': 841, 'currentUsageTotal': 615, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 44}
# County: Armstrong County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-18, Hospitalizations: {'capacity': 839, 'currentUsageTotal': 607, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 53}
# County: Armstrong County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-20, Hospitalizations: {'capacity': 828, 'currentUsageTotal': 601, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 58}
# County: Armstrong County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-25, Hospitalizations: {'capacity': 842, 'currentUsageTotal': 612, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 50}
# County: Armstrong County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-27, Hospitalizations: {'capacity': 848, 'currentUsageTotal': 617, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 41}
# County: Armstrong County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Armstrong County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Atascosa County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Atascosa County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Atascosa County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Atascosa County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Atascosa County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Atascosa County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Atascosa County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Atascosa County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Atascosa County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-04, Hospitalizations: {'capacity': 13914, 'currentUsageTotal': 11675, 'currentUsageCovid': 1579, 'weeklyCovidAdmissions': 916}
# County: Austin County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-06, Hospitalizations: {'capacity': 13920, 'currentUsageTotal': 11576, 'currentUsageCovid': 1524, 'weeklyCovidAdmissions': 1005}
# County: Austin County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-11, Hospitalizations: {'capacity': 13834, 'currentUsageTotal': 11385, 'currentUsageCovid': 1442, 'weeklyCovidAdmissions': 1008}
# County: Austin County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-13, Hospitalizations: {'capacity': 13826, 'currentUsageTotal': 11366, 'currentUsageCovid': 1428, 'weeklyCovidAdmissions': 998}
# County: Austin County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-18, Hospitalizations: {'capacity': 13709, 'currentUsageTotal': 11174, 'currentUsageCovid': 1337, 'weeklyCovidAdmissions': 983}
# County: Austin County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-20, Hospitalizations: {'capacity': 13547, 'currentUsageTotal': 10949, 'currentUsageCovid': 1289, 'weeklyCovidAdmissions': 915}
# County: Austin County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-25, Hospitalizations: {'capacity': 13542, 'currentUsageTotal': 10874, 'currentUsageCovid': 1184, 'weeklyCovidAdmissions': 814}
# County: Austin County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-27, Hospitalizations: {'capacity': 13639, 'currentUsageTotal': 11010, 'currentUsageCovid': 1161, 'weeklyCovidAdmissions': 794}
# County: Austin County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Austin County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-04, Hospitalizations: {'capacity': 1206, 'currentUsageTotal': 931, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 65}
# County: Bailey County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-06, Hospitalizations: {'capacity': 1198, 'currentUsageTotal': 923, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 54}
# County: Bailey County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-11, Hospitalizations: {'capacity': 1213, 'currentUsageTotal': 941, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Bailey County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-13, Hospitalizations: {'capacity': 1226, 'currentUsageTotal': 957, 'currentUsageCovid': 55, 'weeklyCovidAdmissions': 77}
# County: Bailey County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-18, Hospitalizations: {'capacity': 1204, 'currentUsageTotal': 933, 'currentUsageCovid': 39, 'weeklyCovidAdmissions': 78}
# County: Bailey County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-20, Hospitalizations: {'capacity': 1184, 'currentUsageTotal': 909, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 71}
# County: Bailey County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-25, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 869, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 51}
# County: Bailey County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-27, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 871, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 52}
# County: Bailey County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bailey County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Bandera County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Bandera County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Bandera County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Bandera County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bandera County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# ...
# County: Yoakum County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yoakum County, Date: 2021-03-27, Hospitalizations: {'capacity': 74, 'currentUsageTotal': 13, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yoakum County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yoakum County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yoakum County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yoakum County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Young County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Young County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Young County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Young County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Young County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Young County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Young County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Young County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Young County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-04, Hospitalizations: {'capacity': 444, 'currentUsageTotal': 331, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 11}
# County: Zapata County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-06, Hospitalizations: {'capacity': 446, 'currentUsageTotal': 327, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 74}
# County: Zapata County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-11, Hospitalizations: {'capacity': 442, 'currentUsageTotal': 328, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 82}
# County: Zapata County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-13, Hospitalizations: {'capacity': 433, 'currentUsageTotal': 327, 'currentUsageCovid': 29, 'weeklyCovidAdmissions': 18}
# County: Zapata County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-18, Hospitalizations: {'capacity': 414, 'currentUsageTotal': 323, 'currentUsageCovid': 23, 'weeklyCovidAdmissions': 7}
# County: Zapata County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-20, Hospitalizations: {'capacity': 416, 'currentUsageTotal': 322, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 8}
# County: Zapata County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-25, Hospitalizations: {'capacity': 418, 'currentUsageTotal': 323, 'currentUsageCovid': 20, 'weeklyCovidAdmissions': 13}
# County: Zapata County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-27, Hospitalizations: {'capacity': 427, 'currentUsageTotal': 329, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 4}
# County: Zapata County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zapata County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-01, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-02, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-03, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Zavala County, Date: 2021-03-05, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Zavala County, Date: 2021-03-07, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-08, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-09, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-10, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Zavala County, Date: 2021-03-12, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Zavala County, Date: 2021-03-14, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-15, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-16, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-17, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Zavala County, Date: 2021-03-19, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Zavala County, Date: 2021-03-21, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-22, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-23, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-24, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Zavala County, Date: 2021-03-26, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Zavala County, Date: 2021-03-28, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-29, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-30, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Zavala County, Date: 2021-03-31, Hospitalizations: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}

# %%
response = requests.get(query_url)
covid_data = response.json()
# Ensure covid_data is a list of dictionaries; each dictionary represents a county
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    # Check if 'actualsTimeseries' is a list and iterate through it
    for date_entry in county_data["actualsTimeseries"]:
        date = date_entry.get("date")
        # Filter for March 2021 entries
        if date.startswith("2021-03"):
            hospitalizations = date_entry.get("hsaHospitalBeds", {})
            # Check if 'hospitalizations' data exists and does not contain any "none" values
            if hospitalizations and not any(value == "none" for value in hospitalizations.values()):
                # Check if specific keys have values other than None
                if all(key not in hospitalizations or hospitalizations[key] is not None for key in ['capacity', 'currentUsageTotal', 'currentUsageCovid', 'weeklyCovidAdmissions']):
                    # Append a new entry for each date in March 2021
                    hospitalizations_march_2021.append({
                        "County": county_name,
                        "Date": date,
                        "Hospitalizations": hospitalizations
                    })
# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")
# Adjusted print to include date for data in hospitalizations_march_2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Date: {data['Date']}, Hospitalizations: {data['Hospitalizations']}")
# Out:
# Total hospitalization entries for March 2021: 1590
#
# County: Anderson County, Date: 2021-03-04, Hospitalizations: {'capacity': 264, 'currentUsageTotal': 75, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 12}
# County: Angelina County, Date: 2021-03-04, Hospitalizations: {'capacity': 401, 'currentUsageTotal': 325, 'currentUsageCovid': 53, 'weeklyCovidAdmissions': 19}
# County: Angelina County, Date: 2021-03-06, Hospitalizations: {'capacity': 403, 'currentUsageTotal': 319, 'currentUsageCovid': 52, 'weeklyCovidAdmissions': 14}
# County: Angelina County, Date: 2021-03-11, Hospitalizations: {'capacity': 394, 'currentUsageTotal': 319, 'currentUsageCovid': 47, 'weeklyCovidAdmissions': 8}
# County: Angelina County, Date: 2021-03-13, Hospitalizations: {'capacity': 388, 'currentUsageTotal': 314, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 9}
# County: Angelina County, Date: 2021-03-18, Hospitalizations: {'capacity': 390, 'currentUsageTotal': 286, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 16}
# County: Angelina County, Date: 2021-03-20, Hospitalizations: {'capacity': 400, 'currentUsageTotal': 280, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 15}
# County: Angelina County, Date: 2021-03-25, Hospitalizations: {'capacity': 399, 'currentUsageTotal': 290, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 12}
# County: Angelina County, Date: 2021-03-27, Hospitalizations: {'capacity': 391, 'currentUsageTotal': 291, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 14}
# County: Aransas County, Date: 2021-03-04, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 997, 'currentUsageCovid': 98, 'weeklyCovidAdmissions': 42}
# County: Aransas County, Date: 2021-03-06, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 991, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 50}
# County: Aransas County, Date: 2021-03-11, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 988, 'currentUsageCovid': 97, 'weeklyCovidAdmissions': 53}
# County: Aransas County, Date: 2021-03-13, Hospitalizations: {'capacity': 1712, 'currentUsageTotal': 996, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 48}
# County: Aransas County, Date: 2021-03-18, Hospitalizations: {'capacity': 1721, 'currentUsageTotal': 986, 'currentUsageCovid': 86, 'weeklyCovidAdmissions': 46}
# County: Aransas County, Date: 2021-03-20, Hospitalizations: {'capacity': 1727, 'currentUsageTotal': 962, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 40}
# County: Aransas County, Date: 2021-03-25, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 945, 'currentUsageCovid': 80, 'weeklyCovidAdmissions': 44}
# County: Aransas County, Date: 2021-03-27, Hospitalizations: {'capacity': 1720, 'currentUsageTotal': 953, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 52}
# County: Archer County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Archer County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Archer County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Archer County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Archer County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Archer County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Archer County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Archer County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Armstrong County, Date: 2021-03-04, Hospitalizations: {'capacity': 823, 'currentUsageTotal': 597, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 42}
# County: Armstrong County, Date: 2021-03-06, Hospitalizations: {'capacity': 820, 'currentUsageTotal': 597, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 44}
# County: Armstrong County, Date: 2021-03-11, Hospitalizations: {'capacity': 832, 'currentUsageTotal': 614, 'currentUsageCovid': 44, 'weeklyCovidAdmissions': 46}
# County: Armstrong County, Date: 2021-03-13, Hospitalizations: {'capacity': 841, 'currentUsageTotal': 615, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 44}
# County: Armstrong County, Date: 2021-03-18, Hospitalizations: {'capacity': 839, 'currentUsageTotal': 607, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 53}
# County: Armstrong County, Date: 2021-03-20, Hospitalizations: {'capacity': 828, 'currentUsageTotal': 601, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 58}
# County: Armstrong County, Date: 2021-03-25, Hospitalizations: {'capacity': 842, 'currentUsageTotal': 612, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 50}
# County: Armstrong County, Date: 2021-03-27, Hospitalizations: {'capacity': 848, 'currentUsageTotal': 617, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 41}
# County: Atascosa County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Atascosa County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Atascosa County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Atascosa County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Atascosa County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Atascosa County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Atascosa County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Atascosa County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Austin County, Date: 2021-03-04, Hospitalizations: {'capacity': 13914, 'currentUsageTotal': 11675, 'currentUsageCovid': 1579, 'weeklyCovidAdmissions': 916}
# County: Austin County, Date: 2021-03-06, Hospitalizations: {'capacity': 13920, 'currentUsageTotal': 11576, 'currentUsageCovid': 1524, 'weeklyCovidAdmissions': 1005}
# County: Austin County, Date: 2021-03-11, Hospitalizations: {'capacity': 13834, 'currentUsageTotal': 11385, 'currentUsageCovid': 1442, 'weeklyCovidAdmissions': 1008}
# County: Austin County, Date: 2021-03-13, Hospitalizations: {'capacity': 13826, 'currentUsageTotal': 11366, 'currentUsageCovid': 1428, 'weeklyCovidAdmissions': 998}
# County: Austin County, Date: 2021-03-18, Hospitalizations: {'capacity': 13709, 'currentUsageTotal': 11174, 'currentUsageCovid': 1337, 'weeklyCovidAdmissions': 983}
# County: Austin County, Date: 2021-03-20, Hospitalizations: {'capacity': 13547, 'currentUsageTotal': 10949, 'currentUsageCovid': 1289, 'weeklyCovidAdmissions': 915}
# County: Austin County, Date: 2021-03-25, Hospitalizations: {'capacity': 13542, 'currentUsageTotal': 10874, 'currentUsageCovid': 1184, 'weeklyCovidAdmissions': 814}
# County: Austin County, Date: 2021-03-27, Hospitalizations: {'capacity': 13639, 'currentUsageTotal': 11010, 'currentUsageCovid': 1161, 'weeklyCovidAdmissions': 794}
# County: Bailey County, Date: 2021-03-04, Hospitalizations: {'capacity': 1206, 'currentUsageTotal': 931, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 65}
# County: Bailey County, Date: 2021-03-06, Hospitalizations: {'capacity': 1198, 'currentUsageTotal': 923, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 54}
# County: Bailey County, Date: 2021-03-11, Hospitalizations: {'capacity': 1213, 'currentUsageTotal': 941, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Bailey County, Date: 2021-03-13, Hospitalizations: {'capacity': 1226, 'currentUsageTotal': 957, 'currentUsageCovid': 55, 'weeklyCovidAdmissions': 77}
# County: Bailey County, Date: 2021-03-18, Hospitalizations: {'capacity': 1204, 'currentUsageTotal': 933, 'currentUsageCovid': 39, 'weeklyCovidAdmissions': 78}
# County: Bailey County, Date: 2021-03-20, Hospitalizations: {'capacity': 1184, 'currentUsageTotal': 909, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 71}
# County: Bailey County, Date: 2021-03-25, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 869, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 51}
# County: Bailey County, Date: 2021-03-27, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 871, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 52}
# County: Bandera County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Bandera County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Bandera County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Bandera County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Bandera County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Bandera County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Bandera County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Bandera County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Bastrop County, Date: 2021-03-04, Hospitalizations: {'capacity': 3103, 'currentUsageTotal': 2599, 'currentUsageCovid': 238, 'weeklyCovidAdmissions': 159}
# County: Bastrop County, Date: 2021-03-06, Hospitalizations: {'capacity': 3107, 'currentUsageTotal': 2603, 'currentUsageCovid': 215, 'weeklyCovidAdmissions': 159}
# County: Bastrop County, Date: 2021-03-11, Hospitalizations: {'capacity': 3112, 'currentUsageTotal': 2642, 'currentUsageCovid': 188, 'weeklyCovidAdmissions': 209}
# County: Bastrop County, Date: 2021-03-13, Hospitalizations: {'capacity': 3098, 'currentUsageTotal': 2632, 'currentUsageCovid': 186, 'weeklyCovidAdmissions': 203}
# County: Bastrop County, Date: 2021-03-18, Hospitalizations: {'capacity': 3057, 'currentUsageTotal': 2496, 'currentUsageCovid': 169, 'weeklyCovidAdmissions': 160}
# County: Bastrop County, Date: 2021-03-20, Hospitalizations: {'capacity': 3040, 'currentUsageTotal': 2431, 'currentUsageCovid': 163, 'weeklyCovidAdmissions': 140}
# County: Bastrop County, Date: 2021-03-25, Hospitalizations: {'capacity': 3078, 'currentUsageTotal': 2446, 'currentUsageCovid': 150, 'weeklyCovidAdmissions': 131}
# County: Bastrop County, Date: 2021-03-27, Hospitalizations: {'capacity': 3126, 'currentUsageTotal': 2490, 'currentUsageCovid': 145, 'weeklyCovidAdmissions': 130}
# County: Baylor County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Baylor County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Baylor County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Baylor County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Baylor County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Baylor County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Baylor County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Baylor County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Bell County, Date: 2021-03-04, Hospitalizations: {'capacity': 893, 'currentUsageTotal': 774, 'currentUsageCovid': 64, 'weeklyCovidAdmissions': 121}
# County: Bell County, Date: 2021-03-06, Hospitalizations: {'capacity': 879, 'currentUsageTotal': 767, 'currentUsageCovid': 62, 'weeklyCovidAdmissions': 125}
# County: Bell County, Date: 2021-03-11, Hospitalizations: {'capacity': 856, 'currentUsageTotal': 747, 'currentUsageCovid': 51, 'weeklyCovidAdmissions': 105}
# County: Bell County, Date: 2021-03-13, Hospitalizations: {'capacity': 849, 'currentUsageTotal': 733, 'currentUsageCovid': 45, 'weeklyCovidAdmissions': 93}
# County: Bell County, Date: 2021-03-18, Hospitalizations: {'capacity': 833, 'currentUsageTotal': 705, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 99}
# County: Bell County, Date: 2021-03-20, Hospitalizations: {'capacity': 833, 'currentUsageTotal': 703, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 98}
# County: Bell County, Date: 2021-03-25, Hospitalizations: {'capacity': 859, 'currentUsageTotal': 739, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 87}
# County: Bell County, Date: 2021-03-27, Hospitalizations: {'capacity': 872, 'currentUsageTotal': 756, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 83}
# County: Bexar County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Bexar County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Bexar County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Bexar County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Bexar County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Bexar County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Bexar County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Bexar County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Blanco County, Date: 2021-03-04, Hospitalizations: {'capacity': 248, 'currentUsageTotal': 125, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Blanco County, Date: 2021-03-06, Hospitalizations: {'capacity': 252, 'currentUsageTotal': 119, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': 14}
# County: Blanco County, Date: 2021-03-11, Hospitalizations: {'capacity': 264, 'currentUsageTotal': 98, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 5}
# County: Blanco County, Date: 2021-03-25, Hospitalizations: {'capacity': 246, 'currentUsageTotal': 97, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 9}
# County: Blanco County, Date: 2021-03-27, Hospitalizations: {'capacity': 251, 'currentUsageTotal': 99, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 9}
# County: Borden County, Date: 2021-03-04, Hospitalizations: {'capacity': 1206, 'currentUsageTotal': 931, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 65}
# County: Borden County, Date: 2021-03-06, Hospitalizations: {'capacity': 1198, 'currentUsageTotal': 923, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 54}
# County: Borden County, Date: 2021-03-11, Hospitalizations: {'capacity': 1213, 'currentUsageTotal': 941, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Borden County, Date: 2021-03-13, Hospitalizations: {'capacity': 1226, 'currentUsageTotal': 957, 'currentUsageCovid': 55, 'weeklyCovidAdmissions': 77}
# County: Borden County, Date: 2021-03-18, Hospitalizations: {'capacity': 1204, 'currentUsageTotal': 933, 'currentUsageCovid': 39, 'weeklyCovidAdmissions': 78}
# County: Borden County, Date: 2021-03-20, Hospitalizations: {'capacity': 1184, 'currentUsageTotal': 909, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 71}
# County: Borden County, Date: 2021-03-25, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 869, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 51}
# County: Borden County, Date: 2021-03-27, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 871, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 52}
# County: Bosque County, Date: 2021-03-04, Hospitalizations: {'capacity': 610, 'currentUsageTotal': 448, 'currentUsageCovid': 45, 'weeklyCovidAdmissions': 40}
# County: Bosque County, Date: 2021-03-06, Hospitalizations: {'capacity': 604, 'currentUsageTotal': 437, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 43}
# County: Bosque County, Date: 2021-03-11, Hospitalizations: {'capacity': 596, 'currentUsageTotal': 423, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 37}
# County: Bosque County, Date: 2021-03-13, Hospitalizations: {'capacity': 590, 'currentUsageTotal': 414, 'currentUsageCovid': 38, 'weeklyCovidAdmissions': 38}
# County: Bosque County, Date: 2021-03-18, Hospitalizations: {'capacity': 583, 'currentUsageTotal': 405, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 35}
# County: Bosque County, Date: 2021-03-20, Hospitalizations: {'capacity': 590, 'currentUsageTotal': 413, 'currentUsageCovid': 29, 'weeklyCovidAdmissions': 26}
# County: Bosque County, Date: 2021-03-25, Hospitalizations: {'capacity': 595, 'currentUsageTotal': 422, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 17}
# County: Bosque County, Date: 2021-03-27, Hospitalizations: {'capacity': 590, 'currentUsageTotal': 427, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 19}
# County: Bowie County, Date: 2021-03-04, Hospitalizations: {'capacity': 796, 'currentUsageTotal': 403, 'currentUsageCovid': 37, 'weeklyCovidAdmissions': 26}
# County: Bowie County, Date: 2021-03-06, Hospitalizations: {'capacity': 797, 'currentUsageTotal': 394, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 21}
# County: Bowie County, Date: 2021-03-11, Hospitalizations: {'capacity': 797, 'currentUsageTotal': 379, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 22}
# County: Bowie County, Date: 2021-03-13, Hospitalizations: {'capacity': 792, 'currentUsageTotal': 380, 'currentUsageCovid': 19, 'weeklyCovidAdmissions': 14}
# County: Bowie County, Date: 2021-03-18, Hospitalizations: {'capacity': 798, 'currentUsageTotal': 394, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': 14}
# County: Bowie County, Date: 2021-03-20, Hospitalizations: {'capacity': 801, 'currentUsageTotal': 398, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': 17}
# County: Bowie County, Date: 2021-03-25, Hospitalizations: {'capacity': 806, 'currentUsageTotal': 388, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 10}
# County: Bowie County, Date: 2021-03-27, Hospitalizations: {'capacity': 809, 'currentUsageTotal': 381, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 5}
# County: Brazoria County, Date: 2021-03-04, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 159, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 23}
# County: Brazoria County, Date: 2021-03-06, Hospitalizations: {'capacity': 229, 'currentUsageTotal': 151, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 26}
# County: Brazoria County, Date: 2021-03-11, Hospitalizations: {'capacity': 223, 'currentUsageTotal': 148, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 31}
# County: Brazoria County, Date: 2021-03-13, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 158, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 28}
# County: Brazoria County, Date: 2021-03-18, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 156, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 17}
# County: Brazoria County, Date: 2021-03-20, Hospitalizations: {'capacity': 229, 'currentUsageTotal': 148, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 19}
# County: Brazoria County, Date: 2021-03-25, Hospitalizations: {'capacity': 244, 'currentUsageTotal': 158, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 45}
# County: Brazoria County, Date: 2021-03-27, Hospitalizations: {'capacity': 244, 'currentUsageTotal': 164, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 42}
# County: Brazos County, Date: 2021-03-04, Hospitalizations: {'capacity': 771, 'currentUsageTotal': 420, 'currentUsageCovid': 52, 'weeklyCovidAdmissions': 44}
# County: Brazos County, Date: 2021-03-06, Hospitalizations: {'capacity': 770, 'currentUsageTotal': 414, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 39}
# County: Brazos County, Date: 2021-03-11, Hospitalizations: {'capacity': 749, 'currentUsageTotal': 380, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 57}
# County: Brazos County, Date: 2021-03-13, Hospitalizations: {'capacity': 743, 'currentUsageTotal': 375, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 57}
# County: Brazos County, Date: 2021-03-18, Hospitalizations: {'capacity': 738, 'currentUsageTotal': 373, 'currentUsageCovid': 38, 'weeklyCovidAdmissions': 32}
# County: Brazos County, Date: 2021-03-20, Hospitalizations: {'capacity': 741, 'currentUsageTotal': 376, 'currentUsageCovid': 37, 'weeklyCovidAdmissions': 26}
# County: Brazos County, Date: 2021-03-25, Hospitalizations: {'capacity': 749, 'currentUsageTotal': 387, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 34}
# County: Brazos County, Date: 2021-03-27, Hospitalizations: {'capacity': 747, 'currentUsageTotal': 386, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 32}
# County: Briscoe County, Date: 2021-03-04, Hospitalizations: {'capacity': 823, 'currentUsageTotal': 597, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 42}
# County: Briscoe County, Date: 2021-03-06, Hospitalizations: {'capacity': 820, 'currentUsageTotal': 597, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 44}
# County: Briscoe County, Date: 2021-03-11, Hospitalizations: {'capacity': 832, 'currentUsageTotal': 614, 'currentUsageCovid': 44, 'weeklyCovidAdmissions': 46}
# County: Briscoe County, Date: 2021-03-13, Hospitalizations: {'capacity': 841, 'currentUsageTotal': 615, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 44}
# County: Briscoe County, Date: 2021-03-18, Hospitalizations: {'capacity': 839, 'currentUsageTotal': 607, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 53}
# County: Briscoe County, Date: 2021-03-20, Hospitalizations: {'capacity': 828, 'currentUsageTotal': 601, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 58}
# County: Briscoe County, Date: 2021-03-25, Hospitalizations: {'capacity': 842, 'currentUsageTotal': 612, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 50}
# County: Briscoe County, Date: 2021-03-27, Hospitalizations: {'capacity': 848, 'currentUsageTotal': 617, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 41}
# County: Brooks County, Date: 2021-03-04, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 997, 'currentUsageCovid': 98, 'weeklyCovidAdmissions': 42}
# County: Brooks County, Date: 2021-03-06, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 991, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 50}
# County: Brooks County, Date: 2021-03-11, Hospitalizations: {'capacity': 1732, 'currentUsageTotal': 988, 'currentUsageCovid': 97, 'weeklyCovidAdmissions': 53}
# County: Brooks County, Date: 2021-03-13, Hospitalizations: {'capacity': 1712, 'currentUsageTotal': 996, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 48}
# County: Brooks County, Date: 2021-03-18, Hospitalizations: {'capacity': 1721, 'currentUsageTotal': 986, 'currentUsageCovid': 86, 'weeklyCovidAdmissions': 46}
# County: Brooks County, Date: 2021-03-20, Hospitalizations: {'capacity': 1727, 'currentUsageTotal': 962, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 40}
# County: Brooks County, Date: 2021-03-25, Hospitalizations: {'capacity': 1722, 'currentUsageTotal': 945, 'currentUsageCovid': 80, 'weeklyCovidAdmissions': 44}
# County: Brooks County, Date: 2021-03-27, Hospitalizations: {'capacity': 1720, 'currentUsageTotal': 953, 'currentUsageCovid': 81, 'weeklyCovidAdmissions': 52}
# County: Brown County, Date: 2021-03-04, Hospitalizations: {'capacity': 68, 'currentUsageTotal': 49, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 9}
# County: Brown County, Date: 2021-03-06, Hospitalizations: {'capacity': 70, 'currentUsageTotal': 51, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 10}
# County: Burleson County, Date: 2021-03-04, Hospitalizations: {'capacity': 771, 'currentUsageTotal': 420, 'currentUsageCovid': 52, 'weeklyCovidAdmissions': 44}
# County: Burleson County, Date: 2021-03-06, Hospitalizations: {'capacity': 770, 'currentUsageTotal': 414, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 39}
# County: Burleson County, Date: 2021-03-11, Hospitalizations: {'capacity': 749, 'currentUsageTotal': 380, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 57}
# County: Burleson County, Date: 2021-03-13, Hospitalizations: {'capacity': 743, 'currentUsageTotal': 375, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 57}
# County: Burleson County, Date: 2021-03-18, Hospitalizations: {'capacity': 738, 'currentUsageTotal': 373, 'currentUsageCovid': 38, 'weeklyCovidAdmissions': 32}
# County: Burleson County, Date: 2021-03-20, Hospitalizations: {'capacity': 741, 'currentUsageTotal': 376, 'currentUsageCovid': 37, 'weeklyCovidAdmissions': 26}
# County: Burleson County, Date: 2021-03-25, Hospitalizations: {'capacity': 749, 'currentUsageTotal': 387, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 34}
# County: Burleson County, Date: 2021-03-27, Hospitalizations: {'capacity': 747, 'currentUsageTotal': 386, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 32}
# County: Burnet County, Date: 2021-03-04, Hospitalizations: {'capacity': 3103, 'currentUsageTotal': 2599, 'currentUsageCovid': 238, 'weeklyCovidAdmissions': 159}
# County: Burnet County, Date: 2021-03-06, Hospitalizations: {'capacity': 3107, 'currentUsageTotal': 2603, 'currentUsageCovid': 215, 'weeklyCovidAdmissions': 159}
# County: Burnet County, Date: 2021-03-11, Hospitalizations: {'capacity': 3112, 'currentUsageTotal': 2642, 'currentUsageCovid': 188, 'weeklyCovidAdmissions': 209}
# County: Burnet County, Date: 2021-03-13, Hospitalizations: {'capacity': 3098, 'currentUsageTotal': 2632, 'currentUsageCovid': 186, 'weeklyCovidAdmissions': 203}
# County: Burnet County, Date: 2021-03-18, Hospitalizations: {'capacity': 3057, 'currentUsageTotal': 2496, 'currentUsageCovid': 169, 'weeklyCovidAdmissions': 160}
# County: Burnet County, Date: 2021-03-20, Hospitalizations: {'capacity': 3040, 'currentUsageTotal': 2431, 'currentUsageCovid': 163, 'weeklyCovidAdmissions': 140}
# County: Burnet County, Date: 2021-03-25, Hospitalizations: {'capacity': 3078, 'currentUsageTotal': 2446, 'currentUsageCovid': 150, 'weeklyCovidAdmissions': 131}
# County: Burnet County, Date: 2021-03-27, Hospitalizations: {'capacity': 3126, 'currentUsageTotal': 2490, 'currentUsageCovid': 145, 'weeklyCovidAdmissions': 130}
# County: Caldwell County, Date: 2021-03-04, Hospitalizations: {'capacity': 412, 'currentUsageTotal': 288, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 26}
# County: Caldwell County, Date: 2021-03-06, Hospitalizations: {'capacity': 413, 'currentUsageTotal': 284, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 31}
# County: Caldwell County, Date: 2021-03-11, Hospitalizations: {'capacity': 414, 'currentUsageTotal': 272, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 39}
# County: Caldwell County, Date: 2021-03-13, Hospitalizations: {'capacity': 405, 'currentUsageTotal': 265, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 40}
# County: Caldwell County, Date: 2021-03-18, Hospitalizations: {'capacity': 384, 'currentUsageTotal': 247, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 24}
# County: Caldwell County, Date: 2021-03-20, Hospitalizations: {'capacity': 386, 'currentUsageTotal': 250, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 16}
# County: Caldwell County, Date: 2021-03-25, Hospitalizations: {'capacity': 395, 'currentUsageTotal': 249, 'currentUsageCovid': 25, 'weeklyCovidAdmissions': 16}
# County: Caldwell County, Date: 2021-03-27, Hospitalizations: {'capacity': 400, 'currentUsageTotal': 238, 'currentUsageCovid': 25, 'weeklyCovidAdmissions': 14}
# County: Calhoun County, Date: 2021-03-04, Hospitalizations: {'capacity': 829, 'currentUsageTotal': 319, 'currentUsageCovid': 57, 'weeklyCovidAdmissions': 31}
# County: Calhoun County, Date: 2021-03-06, Hospitalizations: {'capacity': 812, 'currentUsageTotal': 300, 'currentUsageCovid': 52, 'weeklyCovidAdmissions': 29}
# County: Calhoun County, Date: 2021-03-11, Hospitalizations: {'capacity': 797, 'currentUsageTotal': 294, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 24}
# County: Calhoun County, Date: 2021-03-13, Hospitalizations: {'capacity': 803, 'currentUsageTotal': 295, 'currentUsageCovid': 37, 'weeklyCovidAdmissions': 14}
# County: Calhoun County, Date: 2021-03-18, Hospitalizations: {'capacity': 815, 'currentUsageTotal': 268, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 6}
# County: Calhoun County, Date: 2021-03-20, Hospitalizations: {'capacity': 817, 'currentUsageTotal': 261, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 8}
# County: Calhoun County, Date: 2021-03-25, Hospitalizations: {'capacity': 818, 'currentUsageTotal': 260, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 12}
# County: Calhoun County, Date: 2021-03-27, Hospitalizations: {'capacity': 815, 'currentUsageTotal': 267, 'currentUsageCovid': 23, 'weeklyCovidAdmissions': 9}
# County: Callahan County, Date: 2021-03-04, Hospitalizations: {'capacity': 543, 'currentUsageTotal': 436, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 25}
# County: Callahan County, Date: 2021-03-06, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 431, 'currentUsageCovid': 21, 'weeklyCovidAdmissions': 23}
# County: Callahan County, Date: 2021-03-11, Hospitalizations: {'capacity': 524, 'currentUsageTotal': 399, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 11}
# County: Callahan County, Date: 2021-03-13, Hospitalizations: {'capacity': 512, 'currentUsageTotal': 386, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 11}
# County: Callahan County, Date: 2021-03-18, Hospitalizations: {'capacity': 520, 'currentUsageTotal': 395, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 23}
# County: Callahan County, Date: 2021-03-20, Hospitalizations: {'capacity': 525, 'currentUsageTotal': 405, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': 22}
# County: Callahan County, Date: 2021-03-25, Hospitalizations: {'capacity': 520, 'currentUsageTotal': 407, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 15}
# County: Callahan County, Date: 2021-03-27, Hospitalizations: {'capacity': 513, 'currentUsageTotal': 397, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 12}
# County: Cameron County, Date: 2021-03-04, Hospitalizations: {'capacity': 1035, 'currentUsageTotal': 762, 'currentUsageCovid': 113, 'weeklyCovidAdmissions': 48}
# County: Cameron County, Date: 2021-03-06, Hospitalizations: {'capacity': 1028, 'currentUsageTotal': 746, 'currentUsageCovid': 111, 'weeklyCovidAdmissions': 42}
# County: Cameron County, Date: 2021-03-11, Hospitalizations: {'capacity': 1016, 'currentUsageTotal': 725, 'currentUsageCovid': 103, 'weeklyCovidAdmissions': 39}
# County: Cameron County, Date: 2021-03-13, Hospitalizations: {'capacity': 1024, 'currentUsageTotal': 745, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 39}
# County: Cameron County, Date: 2021-03-18, Hospitalizations: {'capacity': 1039, 'currentUsageTotal': 774, 'currentUsageCovid': 77, 'weeklyCovidAdmissions': 29}
# County: Cameron County, Date: 2021-03-20, Hospitalizations: {'capacity': 1034, 'currentUsageTotal': 769, 'currentUsageCovid': 75, 'weeklyCovidAdmissions': 29}
# County: Cameron County, Date: 2021-03-25, Hospitalizations: {'capacity': 1035, 'currentUsageTotal': 747, 'currentUsageCovid': 66, 'weeklyCovidAdmissions': 31}
# County: Cameron County, Date: 2021-03-27, Hospitalizations: {'capacity': 1049, 'currentUsageTotal': 750, 'currentUsageCovid': 60, 'weeklyCovidAdmissions': 28}
# County: Camp County, Date: 2021-03-04, Hospitalizations: {'capacity': 107, 'currentUsageTotal': 59, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 5}
# County: Camp County, Date: 2021-03-06, Hospitalizations: {'capacity': 107, 'currentUsageTotal': 54, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Camp County, Date: 2021-03-11, Hospitalizations: {'capacity': 98, 'currentUsageTotal': 52, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Camp County, Date: 2021-03-13, Hospitalizations: {'capacity': 95, 'currentUsageTotal': 52, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Carson County, Date: 2021-03-04, Hospitalizations: {'capacity': 823, 'currentUsageTotal': 597, 'currentUsageCovid': 48, 'weeklyCovidAdmissions': 42}
# County: Carson County, Date: 2021-03-06, Hospitalizations: {'capacity': 820, 'currentUsageTotal': 597, 'currentUsageCovid': 46, 'weeklyCovidAdmissions': 44}
# County: Carson County, Date: 2021-03-11, Hospitalizations: {'capacity': 832, 'currentUsageTotal': 614, 'currentUsageCovid': 44, 'weeklyCovidAdmissions': 46}
# County: Carson County, Date: 2021-03-13, Hospitalizations: {'capacity': 841, 'currentUsageTotal': 615, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 44}
# County: Carson County, Date: 2021-03-18, Hospitalizations: {'capacity': 839, 'currentUsageTotal': 607, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 53}
# County: Carson County, Date: 2021-03-20, Hospitalizations: {'capacity': 828, 'currentUsageTotal': 601, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 58}
# County: Carson County, Date: 2021-03-25, Hospitalizations: {'capacity': 842, 'currentUsageTotal': 612, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 50}
# County: Carson County, Date: 2021-03-27, Hospitalizations: {'capacity': 848, 'currentUsageTotal': 617, 'currentUsageCovid': 43, 'weeklyCovidAdmissions': 41}
# County: Chambers County, Date: 2021-03-04, Hospitalizations: {'capacity': 13914, 'currentUsageTotal': 11675, 'currentUsageCovid': 1579, 'weeklyCovidAdmissions': 916}
# County: Chambers County, Date: 2021-03-06, Hospitalizations: {'capacity': 13920, 'currentUsageTotal': 11576, 'currentUsageCovid': 1524, 'weeklyCovidAdmissions': 1005}
# County: Chambers County, Date: 2021-03-11, Hospitalizations: {'capacity': 13834, 'currentUsageTotal': 11385, 'currentUsageCovid': 1442, 'weeklyCovidAdmissions': 1008}
# County: Chambers County, Date: 2021-03-13, Hospitalizations: {'capacity': 13826, 'currentUsageTotal': 11366, 'currentUsageCovid': 1428, 'weeklyCovidAdmissions': 998}
# County: Chambers County, Date: 2021-03-18, Hospitalizations: {'capacity': 13709, 'currentUsageTotal': 11174, 'currentUsageCovid': 1337, 'weeklyCovidAdmissions': 983}
# County: Chambers County, Date: 2021-03-20, Hospitalizations: {'capacity': 13547, 'currentUsageTotal': 10949, 'currentUsageCovid': 1289, 'weeklyCovidAdmissions': 915}
# County: Chambers County, Date: 2021-03-25, Hospitalizations: {'capacity': 13542, 'currentUsageTotal': 10874, 'currentUsageCovid': 1184, 'weeklyCovidAdmissions': 814}
# County: Chambers County, Date: 2021-03-27, Hospitalizations: {'capacity': 13639, 'currentUsageTotal': 11010, 'currentUsageCovid': 1161, 'weeklyCovidAdmissions': 794}
# County: Cherokee County, Date: 2021-03-04, Hospitalizations: {'capacity': 264, 'currentUsageTotal': 75, 'currentUsageCovid': 14, 'weeklyCovidAdmissions': 12}
# County: Clay County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Clay County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Clay County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Clay County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Clay County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Clay County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Clay County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Clay County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Cochran County, Date: 2021-03-04, Hospitalizations: {'capacity': 1206, 'currentUsageTotal': 931, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 65}
# County: Cochran County, Date: 2021-03-06, Hospitalizations: {'capacity': 1198, 'currentUsageTotal': 923, 'currentUsageCovid': 73, 'weeklyCovidAdmissions': 54}
# County: Cochran County, Date: 2021-03-11, Hospitalizations: {'capacity': 1213, 'currentUsageTotal': 941, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Cochran County, Date: 2021-03-13, Hospitalizations: {'capacity': 1226, 'currentUsageTotal': 957, 'currentUsageCovid': 55, 'weeklyCovidAdmissions': 77}
# County: Cochran County, Date: 2021-03-18, Hospitalizations: {'capacity': 1204, 'currentUsageTotal': 933, 'currentUsageCovid': 39, 'weeklyCovidAdmissions': 78}
# County: Cochran County, Date: 2021-03-20, Hospitalizations: {'capacity': 1184, 'currentUsageTotal': 909, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 71}
# County: Cochran County, Date: 2021-03-25, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 869, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 51}
# County: Cochran County, Date: 2021-03-27, Hospitalizations: {'capacity': 1173, 'currentUsageTotal': 871, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 52}
# County: Coke County, Date: 2021-03-04, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 267, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 12}
# County: Coke County, Date: 2021-03-06, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 269, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 13}
# County: Coke County, Date: 2021-03-11, Hospitalizations: {'capacity': 732, 'currentUsageTotal': 272, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 10}
# County: Coke County, Date: 2021-03-13, Hospitalizations: {'capacity': 736, 'currentUsageTotal': 270, 'currentUsageCovid': 10, 'weeklyCovidAdmissions': 6}
# County: Coke County, Date: 2021-03-18, Hospitalizations: {'capacity': 746, 'currentUsageTotal': 265, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': 7}
# County: Coke County, Date: 2021-03-20, Hospitalizations: {'capacity': 744, 'currentUsageTotal': 259, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 6}
# County: Coke County, Date: 2021-03-25, Hospitalizations: {'capacity': 740, 'currentUsageTotal': 260, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 7}
# County: Coke County, Date: 2021-03-27, Hospitalizations: {'capacity': 741, 'currentUsageTotal': 273, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 9}
# County: Coleman County, Date: 2021-03-04, Hospitalizations: {'capacity': 68, 'currentUsageTotal': 49, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 9}
# County: Coleman County, Date: 2021-03-06, Hospitalizations: {'capacity': 70, 'currentUsageTotal': 51, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 10}
# County: Collin County, Date: 2021-03-04, Hospitalizations: {'capacity': 8251, 'currentUsageTotal': 7323, 'currentUsageCovid': 739, 'weeklyCovidAdmissions': 469}
# County: Collin County, Date: 2021-03-06, Hospitalizations: {'capacity': 8253, 'currentUsageTotal': 7273, 'currentUsageCovid': 691, 'weeklyCovidAdmissions': 431}
# County: Collin County, Date: 2021-03-11, Hospitalizations: {'capacity': 8144, 'currentUsageTotal': 7058, 'currentUsageCovid': 563, 'weeklyCovidAdmissions': 356}
# County: Collin County, Date: 2021-03-13, Hospitalizations: {'capacity': 8097, 'currentUsageTotal': 6984, 'currentUsageCovid': 521, 'weeklyCovidAdmissions': 332}
# County: Collin County, Date: 2021-03-18, Hospitalizations: {'capacity': 7998, 'currentUsageTotal': 6873, 'currentUsageCovid': 459, 'weeklyCovidAdmissions': 312}
# County: Collin County, Date: 2021-03-20, Hospitalizations: {'capacity': 7972, 'currentUsageTotal': 6797, 'currentUsageCovid': 432, 'weeklyCovidAdmissions': 299}
# County: Collin County, Date: 2021-03-25, Hospitalizations: {'capacity': 7964, 'currentUsageTotal': 6764, 'currentUsageCovid': 393, 'weeklyCovidAdmissions': 292}
# County: Collin County, Date: 2021-03-27, Hospitalizations: {'capacity': 8043, 'currentUsageTotal': 6855, 'currentUsageCovid': 385, 'weeklyCovidAdmissions': 291}
# County: Colorado County, Date: 2021-03-25, Hospitalizations: {'capacity': 67, 'currentUsageTotal': 30, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Comal County, Date: 2021-03-04, Hospitalizations: {'capacity': 127, 'currentUsageTotal': 80, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 7}
# County: Comal County, Date: 2021-03-06, Hospitalizations: {'capacity': 130, 'currentUsageTotal': 74, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 6}
# County: Comal County, Date: 2021-03-20, Hospitalizations: {'capacity': 133, 'currentUsageTotal': 57, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Concho County, Date: 2021-03-04, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 267, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 12}
# County: Concho County, Date: 2021-03-06, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 269, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 13}
# County: Concho County, Date: 2021-03-11, Hospitalizations: {'capacity': 732, 'currentUsageTotal': 272, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 10}
# County: Concho County, Date: 2021-03-13, Hospitalizations: {'capacity': 736, 'currentUsageTotal': 270, 'currentUsageCovid': 10, 'weeklyCovidAdmissions': 6}
# County: Concho County, Date: 2021-03-18, Hospitalizations: {'capacity': 746, 'currentUsageTotal': 265, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': 7}
# County: Concho County, Date: 2021-03-20, Hospitalizations: {'capacity': 744, 'currentUsageTotal': 259, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 6}
# County: Concho County, Date: 2021-03-25, Hospitalizations: {'capacity': 740, 'currentUsageTotal': 260, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 7}
# County: Concho County, Date: 2021-03-27, Hospitalizations: {'capacity': 741, 'currentUsageTotal': 273, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 9}
# County: Cooke County, Date: 2021-03-04, Hospitalizations: {'capacity': 1073, 'currentUsageTotal': 806, 'currentUsageCovid': 109, 'weeklyCovidAdmissions': 90}
# County: Cooke County, Date: 2021-03-06, Hospitalizations: {'capacity': 1109, 'currentUsageTotal': 796, 'currentUsageCovid': 98, 'weeklyCovidAdmissions': 75}
# County: Cooke County, Date: 2021-03-11, Hospitalizations: {'capacity': 1064, 'currentUsageTotal': 765, 'currentUsageCovid': 70, 'weeklyCovidAdmissions': 55}
# County: Cooke County, Date: 2021-03-13, Hospitalizations: {'capacity': 1106, 'currentUsageTotal': 767, 'currentUsageCovid': 67, 'weeklyCovidAdmissions': 69}
# County: Cooke County, Date: 2021-03-18, Hospitalizations: {'capacity': 1046, 'currentUsageTotal': 744, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 51}
# County: Cooke County, Date: 2021-03-20, Hospitalizations: {'capacity': 1085, 'currentUsageTotal': 736, 'currentUsageCovid': 54, 'weeklyCovidAdmissions': 37}
# County: Cooke County, Date: 2021-03-25, Hospitalizations: {'capacity': 1040, 'currentUsageTotal': 713, 'currentUsageCovid': 50, 'weeklyCovidAdmissions': 22}
# County: Cooke County, Date: 2021-03-27, Hospitalizations: {'capacity': 1092, 'currentUsageTotal': 722, 'currentUsageCovid': 50, 'weeklyCovidAdmissions': 23}
# County: Coryell County, Date: 2021-03-04, Hospitalizations: {'capacity': 893, 'currentUsageTotal': 774, 'currentUsageCovid': 64, 'weeklyCovidAdmissions': 121}
# County: Coryell County, Date: 2021-03-06, Hospitalizations: {'capacity': 879, 'currentUsageTotal': 767, 'currentUsageCovid': 62, 'weeklyCovidAdmissions': 125}
# County: Coryell County, Date: 2021-03-11, Hospitalizations: {'capacity': 856, 'currentUsageTotal': 747, 'currentUsageCovid': 51, 'weeklyCovidAdmissions': 105}
# County: Coryell County, Date: 2021-03-13, Hospitalizations: {'capacity': 849, 'currentUsageTotal': 733, 'currentUsageCovid': 45, 'weeklyCovidAdmissions': 93}
# County: Coryell County, Date: 2021-03-18, Hospitalizations: {'capacity': 833, 'currentUsageTotal': 705, 'currentUsageCovid': 41, 'weeklyCovidAdmissions': 99}
# County: Coryell County, Date: 2021-03-20, Hospitalizations: {'capacity': 833, 'currentUsageTotal': 703, 'currentUsageCovid': 42, 'weeklyCovidAdmissions': 98}
# County: Coryell County, Date: 2021-03-25, Hospitalizations: {'capacity': 859, 'currentUsageTotal': 739, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 87}
# County: Coryell County, Date: 2021-03-27, Hospitalizations: {'capacity': 872, 'currentUsageTotal': 756, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 83}
# County: Crane County, Date: 2021-03-04, Hospitalizations: {'capacity': 652, 'currentUsageTotal': 386, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 10}
# County: Crane County, Date: 2021-03-06, Hospitalizations: {'capacity': 639, 'currentUsageTotal': 386, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 18}
# County: Crane County, Date: 2021-03-11, Hospitalizations: {'capacity': 596, 'currentUsageTotal': 363, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 22}
# County: Crane County, Date: 2021-03-13, Hospitalizations: {'capacity': 604, 'currentUsageTotal': 364, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 16}
# County: Crane County, Date: 2021-03-18, Hospitalizations: {'capacity': 666, 'currentUsageTotal': 422, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 16}
# County: Crane County, Date: 2021-03-20, Hospitalizations: {'capacity': 666, 'currentUsageTotal': 421, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 15}
# County: Crane County, Date: 2021-03-25, Hospitalizations: {'capacity': 597, 'currentUsageTotal': 349, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 14}
# County: Crane County, Date: 2021-03-27, Hospitalizations: {'capacity': 583, 'currentUsageTotal': 336, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 13}
# County: Crockett County, Date: 2021-03-04, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 267, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 12}
# County: Crockett County, Date: 2021-03-06, Hospitalizations: {'capacity': 731, 'currentUsageTotal': 269, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 13}
# County: Crockett County, Date: 2021-03-11, Hospitalizations: {'capacity': 732, 'currentUsageTotal': 272, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 10}
# ...
# County: Washington County, Date: 2021-03-18, Hospitalizations: {'capacity': 738, 'currentUsageTotal': 373, 'currentUsageCovid': 38, 'weeklyCovidAdmissions': 32}
# County: Washington County, Date: 2021-03-20, Hospitalizations: {'capacity': 741, 'currentUsageTotal': 376, 'currentUsageCovid': 37, 'weeklyCovidAdmissions': 26}
# County: Washington County, Date: 2021-03-25, Hospitalizations: {'capacity': 749, 'currentUsageTotal': 387, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 34}
# County: Washington County, Date: 2021-03-27, Hospitalizations: {'capacity': 747, 'currentUsageTotal': 386, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 32}
# County: Webb County, Date: 2021-03-04, Hospitalizations: {'capacity': 444, 'currentUsageTotal': 331, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 11}
# County: Webb County, Date: 2021-03-06, Hospitalizations: {'capacity': 446, 'currentUsageTotal': 327, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 74}
# County: Webb County, Date: 2021-03-11, Hospitalizations: {'capacity': 442, 'currentUsageTotal': 328, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 82}
# County: Webb County, Date: 2021-03-13, Hospitalizations: {'capacity': 433, 'currentUsageTotal': 327, 'currentUsageCovid': 29, 'weeklyCovidAdmissions': 18}
# County: Webb County, Date: 2021-03-18, Hospitalizations: {'capacity': 414, 'currentUsageTotal': 323, 'currentUsageCovid': 23, 'weeklyCovidAdmissions': 7}
# County: Webb County, Date: 2021-03-20, Hospitalizations: {'capacity': 416, 'currentUsageTotal': 322, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 8}
# County: Webb County, Date: 2021-03-25, Hospitalizations: {'capacity': 418, 'currentUsageTotal': 323, 'currentUsageCovid': 20, 'weeklyCovidAdmissions': 13}
# County: Webb County, Date: 2021-03-27, Hospitalizations: {'capacity': 427, 'currentUsageTotal': 329, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 4}
# County: Wharton County, Date: 2021-03-04, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 159, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 23}
# County: Wharton County, Date: 2021-03-06, Hospitalizations: {'capacity': 229, 'currentUsageTotal': 151, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 26}
# County: Wharton County, Date: 2021-03-11, Hospitalizations: {'capacity': 223, 'currentUsageTotal': 148, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 31}
# County: Wharton County, Date: 2021-03-13, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 158, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 28}
# County: Wharton County, Date: 2021-03-18, Hospitalizations: {'capacity': 235, 'currentUsageTotal': 156, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 17}
# County: Wharton County, Date: 2021-03-20, Hospitalizations: {'capacity': 229, 'currentUsageTotal': 148, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 19}
# County: Wharton County, Date: 2021-03-25, Hospitalizations: {'capacity': 244, 'currentUsageTotal': 158, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 45}
# County: Wharton County, Date: 2021-03-27, Hospitalizations: {'capacity': 244, 'currentUsageTotal': 164, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 42}
# County: Wichita County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Wichita County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Wichita County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Wichita County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Wichita County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Wichita County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Wichita County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Wichita County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Wilbarger County, Date: 2021-03-18, Hospitalizations: {'capacity': 60, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Willacy County, Date: 2021-03-04, Hospitalizations: {'capacity': 1035, 'currentUsageTotal': 762, 'currentUsageCovid': 113, 'weeklyCovidAdmissions': 48}
# County: Willacy County, Date: 2021-03-06, Hospitalizations: {'capacity': 1028, 'currentUsageTotal': 746, 'currentUsageCovid': 111, 'weeklyCovidAdmissions': 42}
# County: Willacy County, Date: 2021-03-11, Hospitalizations: {'capacity': 1016, 'currentUsageTotal': 725, 'currentUsageCovid': 103, 'weeklyCovidAdmissions': 39}
# County: Willacy County, Date: 2021-03-13, Hospitalizations: {'capacity': 1024, 'currentUsageTotal': 745, 'currentUsageCovid': 95, 'weeklyCovidAdmissions': 39}
# County: Willacy County, Date: 2021-03-18, Hospitalizations: {'capacity': 1039, 'currentUsageTotal': 774, 'currentUsageCovid': 77, 'weeklyCovidAdmissions': 29}
# County: Willacy County, Date: 2021-03-20, Hospitalizations: {'capacity': 1034, 'currentUsageTotal': 769, 'currentUsageCovid': 75, 'weeklyCovidAdmissions': 29}
# County: Willacy County, Date: 2021-03-25, Hospitalizations: {'capacity': 1035, 'currentUsageTotal': 747, 'currentUsageCovid': 66, 'weeklyCovidAdmissions': 31}
# County: Willacy County, Date: 2021-03-27, Hospitalizations: {'capacity': 1049, 'currentUsageTotal': 750, 'currentUsageCovid': 60, 'weeklyCovidAdmissions': 28}
# County: Williamson County, Date: 2021-03-04, Hospitalizations: {'capacity': 3103, 'currentUsageTotal': 2599, 'currentUsageCovid': 238, 'weeklyCovidAdmissions': 159}
# County: Williamson County, Date: 2021-03-06, Hospitalizations: {'capacity': 3107, 'currentUsageTotal': 2603, 'currentUsageCovid': 215, 'weeklyCovidAdmissions': 159}
# County: Williamson County, Date: 2021-03-11, Hospitalizations: {'capacity': 3112, 'currentUsageTotal': 2642, 'currentUsageCovid': 188, 'weeklyCovidAdmissions': 209}
# County: Williamson County, Date: 2021-03-13, Hospitalizations: {'capacity': 3098, 'currentUsageTotal': 2632, 'currentUsageCovid': 186, 'weeklyCovidAdmissions': 203}
# County: Williamson County, Date: 2021-03-18, Hospitalizations: {'capacity': 3057, 'currentUsageTotal': 2496, 'currentUsageCovid': 169, 'weeklyCovidAdmissions': 160}
# County: Williamson County, Date: 2021-03-20, Hospitalizations: {'capacity': 3040, 'currentUsageTotal': 2431, 'currentUsageCovid': 163, 'weeklyCovidAdmissions': 140}
# County: Williamson County, Date: 2021-03-25, Hospitalizations: {'capacity': 3078, 'currentUsageTotal': 2446, 'currentUsageCovid': 150, 'weeklyCovidAdmissions': 131}
# County: Williamson County, Date: 2021-03-27, Hospitalizations: {'capacity': 3126, 'currentUsageTotal': 2490, 'currentUsageCovid': 145, 'weeklyCovidAdmissions': 130}
# County: Wilson County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Wilson County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Wilson County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Wilson County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Wilson County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Wilson County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Wilson County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Wilson County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
# County: Winkler County, Date: 2021-03-04, Hospitalizations: {'capacity': 652, 'currentUsageTotal': 386, 'currentUsageCovid': 35, 'weeklyCovidAdmissions': 10}
# County: Winkler County, Date: 2021-03-06, Hospitalizations: {'capacity': 639, 'currentUsageTotal': 386, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 18}
# County: Winkler County, Date: 2021-03-11, Hospitalizations: {'capacity': 596, 'currentUsageTotal': 363, 'currentUsageCovid': 32, 'weeklyCovidAdmissions': 22}
# County: Winkler County, Date: 2021-03-13, Hospitalizations: {'capacity': 604, 'currentUsageTotal': 364, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 16}
# County: Winkler County, Date: 2021-03-18, Hospitalizations: {'capacity': 666, 'currentUsageTotal': 422, 'currentUsageCovid': 28, 'weeklyCovidAdmissions': 16}
# County: Winkler County, Date: 2021-03-20, Hospitalizations: {'capacity': 666, 'currentUsageTotal': 421, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 15}
# County: Winkler County, Date: 2021-03-25, Hospitalizations: {'capacity': 597, 'currentUsageTotal': 349, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 14}
# County: Winkler County, Date: 2021-03-27, Hospitalizations: {'capacity': 583, 'currentUsageTotal': 336, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 13}
# County: Wise County, Date: 2021-03-04, Hospitalizations: {'capacity': 1073, 'currentUsageTotal': 806, 'currentUsageCovid': 109, 'weeklyCovidAdmissions': 90}
# County: Wise County, Date: 2021-03-06, Hospitalizations: {'capacity': 1109, 'currentUsageTotal': 796, 'currentUsageCovid': 98, 'weeklyCovidAdmissions': 75}
# County: Wise County, Date: 2021-03-11, Hospitalizations: {'capacity': 1064, 'currentUsageTotal': 765, 'currentUsageCovid': 70, 'weeklyCovidAdmissions': 55}
# County: Wise County, Date: 2021-03-13, Hospitalizations: {'capacity': 1106, 'currentUsageTotal': 767, 'currentUsageCovid': 67, 'weeklyCovidAdmissions': 69}
# County: Wise County, Date: 2021-03-18, Hospitalizations: {'capacity': 1046, 'currentUsageTotal': 744, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 51}
# County: Wise County, Date: 2021-03-20, Hospitalizations: {'capacity': 1085, 'currentUsageTotal': 736, 'currentUsageCovid': 54, 'weeklyCovidAdmissions': 37}
# County: Wise County, Date: 2021-03-25, Hospitalizations: {'capacity': 1040, 'currentUsageTotal': 713, 'currentUsageCovid': 50, 'weeklyCovidAdmissions': 22}
# County: Wise County, Date: 2021-03-27, Hospitalizations: {'capacity': 1092, 'currentUsageTotal': 722, 'currentUsageCovid': 50, 'weeklyCovidAdmissions': 23}
# County: Wood County, Date: 2021-03-04, Hospitalizations: {'capacity': 1357, 'currentUsageTotal': 1025, 'currentUsageCovid': 100, 'weeklyCovidAdmissions': 47}
# County: Wood County, Date: 2021-03-06, Hospitalizations: {'capacity': 1374, 'currentUsageTotal': 1026, 'currentUsageCovid': 89, 'weeklyCovidAdmissions': 47}
# County: Wood County, Date: 2021-03-11, Hospitalizations: {'capacity': 1372, 'currentUsageTotal': 975, 'currentUsageCovid': 76, 'weeklyCovidAdmissions': 37}
# County: Wood County, Date: 2021-03-13, Hospitalizations: {'capacity': 1377, 'currentUsageTotal': 920, 'currentUsageCovid': 75, 'weeklyCovidAdmissions': 43}
# County: Wood County, Date: 2021-03-18, Hospitalizations: {'capacity': 1418, 'currentUsageTotal': 886, 'currentUsageCovid': 71, 'weeklyCovidAdmissions': 51}
# County: Wood County, Date: 2021-03-20, Hospitalizations: {'capacity': 1420, 'currentUsageTotal': 893, 'currentUsageCovid': 65, 'weeklyCovidAdmissions': 43}
# County: Wood County, Date: 2021-03-25, Hospitalizations: {'capacity': 1442, 'currentUsageTotal': 901, 'currentUsageCovid': 56, 'weeklyCovidAdmissions': 34}
# County: Wood County, Date: 2021-03-27, Hospitalizations: {'capacity': 1449, 'currentUsageTotal': 911, 'currentUsageCovid': 54, 'weeklyCovidAdmissions': 34}
# County: Young County, Date: 2021-03-04, Hospitalizations: {'capacity': 527, 'currentUsageTotal': 280, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 23}
# County: Young County, Date: 2021-03-06, Hospitalizations: {'capacity': 535, 'currentUsageTotal': 281, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 23}
# County: Young County, Date: 2021-03-11, Hospitalizations: {'capacity': 534, 'currentUsageTotal': 269, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 17}
# County: Young County, Date: 2021-03-13, Hospitalizations: {'capacity': 529, 'currentUsageTotal': 257, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 13}
# County: Young County, Date: 2021-03-18, Hospitalizations: {'capacity': 530, 'currentUsageTotal': 242, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 8}
# County: Young County, Date: 2021-03-20, Hospitalizations: {'capacity': 528, 'currentUsageTotal': 241, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 10}
# County: Young County, Date: 2021-03-25, Hospitalizations: {'capacity': 536, 'currentUsageTotal': 253, 'currentUsageCovid': 12, 'weeklyCovidAdmissions': 16}
# County: Young County, Date: 2021-03-27, Hospitalizations: {'capacity': 540, 'currentUsageTotal': 257, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 15}
# County: Zapata County, Date: 2021-03-04, Hospitalizations: {'capacity': 444, 'currentUsageTotal': 331, 'currentUsageCovid': 40, 'weeklyCovidAdmissions': 11}
# County: Zapata County, Date: 2021-03-06, Hospitalizations: {'capacity': 446, 'currentUsageTotal': 327, 'currentUsageCovid': 36, 'weeklyCovidAdmissions': 74}
# County: Zapata County, Date: 2021-03-11, Hospitalizations: {'capacity': 442, 'currentUsageTotal': 328, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 82}
# County: Zapata County, Date: 2021-03-13, Hospitalizations: {'capacity': 433, 'currentUsageTotal': 327, 'currentUsageCovid': 29, 'weeklyCovidAdmissions': 18}
# County: Zapata County, Date: 2021-03-18, Hospitalizations: {'capacity': 414, 'currentUsageTotal': 323, 'currentUsageCovid': 23, 'weeklyCovidAdmissions': 7}
# County: Zapata County, Date: 2021-03-20, Hospitalizations: {'capacity': 416, 'currentUsageTotal': 322, 'currentUsageCovid': 22, 'weeklyCovidAdmissions': 8}
# County: Zapata County, Date: 2021-03-25, Hospitalizations: {'capacity': 418, 'currentUsageTotal': 323, 'currentUsageCovid': 20, 'weeklyCovidAdmissions': 13}
# County: Zapata County, Date: 2021-03-27, Hospitalizations: {'capacity': 427, 'currentUsageTotal': 329, 'currentUsageCovid': 16, 'weeklyCovidAdmissions': 4}
# County: Zavala County, Date: 2021-03-04, Hospitalizations: {'capacity': 6818, 'currentUsageTotal': 4074, 'currentUsageCovid': 507, 'weeklyCovidAdmissions': 371}
# County: Zavala County, Date: 2021-03-06, Hospitalizations: {'capacity': 6792, 'currentUsageTotal': 4020, 'currentUsageCovid': 465, 'weeklyCovidAdmissions': 347}
# County: Zavala County, Date: 2021-03-11, Hospitalizations: {'capacity': 6734, 'currentUsageTotal': 3879, 'currentUsageCovid': 370, 'weeklyCovidAdmissions': 298}
# County: Zavala County, Date: 2021-03-13, Hospitalizations: {'capacity': 6709, 'currentUsageTotal': 3826, 'currentUsageCovid': 348, 'weeklyCovidAdmissions': 307}
# County: Zavala County, Date: 2021-03-18, Hospitalizations: {'capacity': 6725, 'currentUsageTotal': 3800, 'currentUsageCovid': 302, 'weeklyCovidAdmissions': 283}
# County: Zavala County, Date: 2021-03-20, Hospitalizations: {'capacity': 6751, 'currentUsageTotal': 3806, 'currentUsageCovid': 285, 'weeklyCovidAdmissions': 264}
# County: Zavala County, Date: 2021-03-25, Hospitalizations: {'capacity': 6749, 'currentUsageTotal': 3765, 'currentUsageCovid': 247, 'weeklyCovidAdmissions': 228}
# County: Zavala County, Date: 2021-03-27, Hospitalizations: {'capacity': 6740, 'currentUsageTotal': 3765, 'currentUsageCovid': 233, 'weeklyCovidAdmissions': 227}
