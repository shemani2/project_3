# %%
import requests
import json
from config import api_key
from datetime import datetime

# %%
####Find All fields from JSON###

# URL for GET requests to retrieve historical hospitalization data
url = "https://api.covidactnow.org/v2/counties.json?"

# Date range for March 2021
start_date = "2021-03-01"
end_date = "2021-03-03"  # Adjusted to cover the full month of March 2021

# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# Function to recursively collect field names from a JSON object/dictionary
def collect_fields(json_obj, fields_set, parent_key=''):
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            # Constructing a "path" for nested fields
            new_key = f"{parent_key}.{key}" if parent_key else key
            fields_set.add(new_key)
            collect_fields(value, fields_set, new_key)
    elif isinstance(json_obj, list):
        for item in json_obj:
            collect_fields(item, fields_set, parent_key)

# Function to fetch and parse the JSON data from the API
def fetch_data_and_fields(url):
    response = requests.get(url)
    response_json = response.json()
    
    fields_set = set()
    collect_fields(response_json, fields_set)
    
    return list(fields_set)

# Fetching data and collecting fields
fields = fetch_data_and_fields(query_url)

# Printing the number of different fields
print(f"Total number of different fields: {len(fields)}")

# Printing the list of all fields
for field in sorted(fields):
    print(field)
# Out:
# Total number of different fields: 320
# actuals
# actuals.cases
# actuals.contactTracers
# actuals.deaths
# actuals.hospitalBeds
# actuals.hospitalBeds.capacity
# actuals.hospitalBeds.currentUsageCovid
# actuals.hospitalBeds.currentUsageTotal
# actuals.hospitalBeds.weeklyCovidAdmissions
# actuals.hsaHospitalBeds
# actuals.hsaHospitalBeds.capacity
# actuals.hsaHospitalBeds.currentUsageCovid
# actuals.hsaHospitalBeds.currentUsageTotal
# actuals.hsaHospitalBeds.weeklyCovidAdmissions
# actuals.hsaIcuBeds
# actuals.hsaIcuBeds.capacity
# actuals.hsaIcuBeds.currentUsageCovid
# actuals.hsaIcuBeds.currentUsageTotal
# actuals.icuBeds
# actuals.icuBeds.capacity
# actuals.icuBeds.currentUsageCovid
# actuals.icuBeds.currentUsageTotal
# actuals.negativeTests
# actuals.newCases
# actuals.newDeaths
# actuals.positiveTests
# actuals.vaccinationsAdditionalDose
# actuals.vaccinationsCompleted
# actuals.vaccinationsFall2022BivalentBooster
# actuals.vaccinationsInitiated
# actuals.vaccinationsInitiatedDemographics
# actuals.vaccinationsInitiatedDemographics.age
# actuals.vaccinationsInitiatedDemographics.age.0-11
# actuals.vaccinationsInitiatedDemographics.age.0-15
# actuals.vaccinationsInitiatedDemographics.age.0-17
# actuals.vaccinationsInitiatedDemographics.age.0-19
# actuals.vaccinationsInitiatedDemographics.age.0-4
# actuals.vaccinationsInitiatedDemographics.age.0-9
# actuals.vaccinationsInitiatedDemographics.age.10-14
# actuals.vaccinationsInitiatedDemographics.age.10-19
# actuals.vaccinationsInitiatedDemographics.age.100-104
# actuals.vaccinationsInitiatedDemographics.age.105_plus
# actuals.vaccinationsInitiatedDemographics.age.12-15
# actuals.vaccinationsInitiatedDemographics.age.12-17
# actuals.vaccinationsInitiatedDemographics.age.12-19
# actuals.vaccinationsInitiatedDemographics.age.12-24
# actuals.vaccinationsInitiatedDemographics.age.15-19
# actuals.vaccinationsInitiatedDemographics.age.16-17
# actuals.vaccinationsInitiatedDemographics.age.16-19
# actuals.vaccinationsInitiatedDemographics.age.16-20
# actuals.vaccinationsInitiatedDemographics.age.16-25
# actuals.vaccinationsInitiatedDemographics.age.16-49
# actuals.vaccinationsInitiatedDemographics.age.16-54
# actuals.vaccinationsInitiatedDemographics.age.18-19
# actuals.vaccinationsInitiatedDemographics.age.18-24
# actuals.vaccinationsInitiatedDemographics.age.18-25
# actuals.vaccinationsInitiatedDemographics.age.18-29
# actuals.vaccinationsInitiatedDemographics.age.18-34
# actuals.vaccinationsInitiatedDemographics.age.18-49
# actuals.vaccinationsInitiatedDemographics.age.20-24
# actuals.vaccinationsInitiatedDemographics.age.20-29
# actuals.vaccinationsInitiatedDemographics.age.20-49
# actuals.vaccinationsInitiatedDemographics.age.21-25
# actuals.vaccinationsInitiatedDemographics.age.25-29
# actuals.vaccinationsInitiatedDemographics.age.25-34
# actuals.vaccinationsInitiatedDemographics.age.25-49
# actuals.vaccinationsInitiatedDemographics.age.26-30
# actuals.vaccinationsInitiatedDemographics.age.26-34
# actuals.vaccinationsInitiatedDemographics.age.30-34
# actuals.vaccinationsInitiatedDemographics.age.30-39
# actuals.vaccinationsInitiatedDemographics.age.30-49
# actuals.vaccinationsInitiatedDemographics.age.31-40
# actuals.vaccinationsInitiatedDemographics.age.35-39
# actuals.vaccinationsInitiatedDemographics.age.35-44
# actuals.vaccinationsInitiatedDemographics.age.35-49
# actuals.vaccinationsInitiatedDemographics.age.40-44
# actuals.vaccinationsInitiatedDemographics.age.40-49
# actuals.vaccinationsInitiatedDemographics.age.41-50
# actuals.vaccinationsInitiatedDemographics.age.45-49
# actuals.vaccinationsInitiatedDemographics.age.45-54
# actuals.vaccinationsInitiatedDemographics.age.5-11
# actuals.vaccinationsInitiatedDemographics.age.5-17
# actuals.vaccinationsInitiatedDemographics.age.5-9
# actuals.vaccinationsInitiatedDemographics.age.50-54
# actuals.vaccinationsInitiatedDemographics.age.50-59
# actuals.vaccinationsInitiatedDemographics.age.50-64
# actuals.vaccinationsInitiatedDemographics.age.51-60
# actuals.vaccinationsInitiatedDemographics.age.55-59
# actuals.vaccinationsInitiatedDemographics.age.55-64
# actuals.vaccinationsInitiatedDemographics.age.60-64
# actuals.vaccinationsInitiatedDemographics.age.60-69
# actuals.vaccinationsInitiatedDemographics.age.61-70
# actuals.vaccinationsInitiatedDemographics.age.65-69
# actuals.vaccinationsInitiatedDemographics.age.65-74
# actuals.vaccinationsInitiatedDemographics.age.65-79
# actuals.vaccinationsInitiatedDemographics.age.65_plus
# actuals.vaccinationsInitiatedDemographics.age.70-74
# actuals.vaccinationsInitiatedDemographics.age.70-79
# actuals.vaccinationsInitiatedDemographics.age.70_plus
# actuals.vaccinationsInitiatedDemographics.age.71_plus
# actuals.vaccinationsInitiatedDemographics.age.75-79
# actuals.vaccinationsInitiatedDemographics.age.75-84
# actuals.vaccinationsInitiatedDemographics.age.75_plus
# actuals.vaccinationsInitiatedDemographics.age.80-84
# actuals.vaccinationsInitiatedDemographics.age.80_plus
# actuals.vaccinationsInitiatedDemographics.age.85-89
# actuals.vaccinationsInitiatedDemographics.age.85_plus
# actuals.vaccinationsInitiatedDemographics.age.90-94
# actuals.vaccinationsInitiatedDemographics.age.95-99
# actuals.vaccinationsInitiatedDemographics.age.unknown
# actuals.vaccinationsInitiatedDemographics.ethnicity
# actuals.vaccinationsInitiatedDemographics.ethnicity.hispanic
# actuals.vaccinationsInitiatedDemographics.ethnicity.non-hispanic
# actuals.vaccinationsInitiatedDemographics.ethnicity.unknown
# actuals.vaccinationsInitiatedDemographics.race
# actuals.vaccinationsInitiatedDemographics.race.ai_an
# actuals.vaccinationsInitiatedDemographics.race.ai_an_asian_or_pacific_islander
# actuals.vaccinationsInitiatedDemographics.race.asian
# actuals.vaccinationsInitiatedDemographics.race.asian_or_pacific_islander
# actuals.vaccinationsInitiatedDemographics.race.black
# actuals.vaccinationsInitiatedDemographics.race.hispanic
# actuals.vaccinationsInitiatedDemographics.race.latino
# actuals.vaccinationsInitiatedDemographics.race.middle_eastern_or_north_africa
# actuals.vaccinationsInitiatedDemographics.race.multiple
# actuals.vaccinationsInitiatedDemographics.race.multiple_other
# actuals.vaccinationsInitiatedDemographics.race.other
# actuals.vaccinationsInitiatedDemographics.race.pacific_islander
# actuals.vaccinationsInitiatedDemographics.race.unknown
# actuals.vaccinationsInitiatedDemographics.race.white
# actuals.vaccinationsInitiatedDemographics.sex
# actuals.vaccinationsInitiatedDemographics.sex.female
# actuals.vaccinationsInitiatedDemographics.sex.male
# actuals.vaccinationsInitiatedDemographics.sex.other
# actuals.vaccinationsInitiatedDemographics.sex.unknown
# actuals.vaccinesAdministered
# actuals.vaccinesAdministeredDemographics
# actuals.vaccinesAdministeredDemographics.age
# actuals.vaccinesAdministeredDemographics.age.12-15
# actuals.vaccinesAdministeredDemographics.age.16-49
# actuals.vaccinesAdministeredDemographics.age.5-11
# actuals.vaccinesAdministeredDemographics.age.50-64
# actuals.vaccinesAdministeredDemographics.age.65-79
# actuals.vaccinesAdministeredDemographics.age.80_plus
# actuals.vaccinesAdministeredDemographics.age.unknown
# actuals.vaccinesAdministeredDemographics.ethnicity
# actuals.vaccinesAdministeredDemographics.race
# actuals.vaccinesAdministeredDemographics.race.asian
# actuals.vaccinesAdministeredDemographics.race.black
# actuals.vaccinesAdministeredDemographics.race.other
# actuals.vaccinesAdministeredDemographics.race.unknown
# actuals.vaccinesAdministeredDemographics.race.white
# actuals.vaccinesAdministeredDemographics.sex
# actuals.vaccinesDistributed
# annotations
# annotations.bedsWithCovidPatientsRatio
# annotations.bedsWithCovidPatientsRatio.anomalies
# annotations.bedsWithCovidPatientsRatio.sources
# annotations.bedsWithCovidPatientsRatio.sources.name
# annotations.bedsWithCovidPatientsRatio.sources.type
# annotations.bedsWithCovidPatientsRatio.sources.url
# annotations.caseDensity
# annotations.caseDensity.anomalies
# annotations.caseDensity.sources
# annotations.caseDensity.sources.name
# annotations.caseDensity.sources.type
# annotations.caseDensity.sources.url
# annotations.cases
# annotations.cases.anomalies
# annotations.cases.sources
# annotations.cases.sources.name
# annotations.cases.sources.type
# annotations.cases.sources.url
# annotations.contactTracerCapacityRatio
# annotations.contactTracers
# annotations.deaths
# annotations.deaths.anomalies
# annotations.deaths.sources
# annotations.deaths.sources.name
# annotations.deaths.sources.type
# annotations.deaths.sources.url
# annotations.hospitalBeds
# annotations.hospitalBeds.anomalies
# annotations.hospitalBeds.sources
# annotations.hospitalBeds.sources.name
# annotations.hospitalBeds.sources.type
# annotations.hospitalBeds.sources.url
# annotations.hsaHospitalBeds
# annotations.hsaIcuBeds
# annotations.icuBeds
# annotations.icuBeds.anomalies
# annotations.icuBeds.sources
# annotations.icuBeds.sources.name
# annotations.icuBeds.sources.type
# annotations.icuBeds.sources.url
# annotations.icuCapacityRatio
# annotations.icuCapacityRatio.anomalies
# annotations.icuCapacityRatio.sources
# annotations.icuCapacityRatio.sources.name
# annotations.icuCapacityRatio.sources.type
# annotations.icuCapacityRatio.sources.url
# annotations.infectionRate
# annotations.infectionRate.anomalies
# annotations.infectionRate.sources
# annotations.infectionRate.sources.name
# annotations.infectionRate.sources.type
# annotations.infectionRate.sources.url
# annotations.infectionRateCI90
# annotations.infectionRateCI90.anomalies
# annotations.infectionRateCI90.sources
# annotations.infectionRateCI90.sources.name
# annotations.infectionRateCI90.sources.type
# annotations.infectionRateCI90.sources.url
# annotations.negativeTests
# annotations.newCases
# annotations.newCases.anomalies
# annotations.newCases.anomalies.date
# annotations.newCases.anomalies.original_observation
# annotations.newCases.anomalies.type
# annotations.newCases.sources
# annotations.newDeaths
# annotations.newDeaths.anomalies
# annotations.newDeaths.anomalies.date
# annotations.newDeaths.anomalies.original_observation
# annotations.newDeaths.anomalies.type
# annotations.newDeaths.sources
# annotations.positiveTests
# annotations.testPositivityRatio
# annotations.vaccinationsAdditionalDose
# annotations.vaccinationsAdditionalDose.anomalies
# annotations.vaccinationsAdditionalDose.sources
# annotations.vaccinationsAdditionalDose.sources.name
# annotations.vaccinationsAdditionalDose.sources.type
# annotations.vaccinationsAdditionalDose.sources.url
# annotations.vaccinationsAdditionalDoseRatio
# annotations.vaccinationsCompleted
# annotations.vaccinationsCompleted.anomalies
# annotations.vaccinationsCompleted.sources
# annotations.vaccinationsCompleted.sources.name
# annotations.vaccinationsCompleted.sources.type
# annotations.vaccinationsCompleted.sources.url
# annotations.vaccinationsCompletedRatio
# annotations.vaccinationsFall2022BivalentBooster
# annotations.vaccinationsFall2022BivalentBooster.anomalies
# annotations.vaccinationsFall2022BivalentBooster.sources
# annotations.vaccinationsFall2022BivalentBooster.sources.name
# annotations.vaccinationsFall2022BivalentBooster.sources.type
# annotations.vaccinationsFall2022BivalentBooster.sources.url
# annotations.vaccinationsFall2022BivalentBoosterRatio
# annotations.vaccinationsInitiated
# annotations.vaccinationsInitiated.anomalies
# annotations.vaccinationsInitiated.sources
# annotations.vaccinationsInitiated.sources.name
# annotations.vaccinationsInitiated.sources.type
# annotations.vaccinationsInitiated.sources.url
# annotations.vaccinationsInitiatedRatio
# annotations.vaccinesAdministered
# annotations.vaccinesAdministered.anomalies
# annotations.vaccinesAdministered.sources
# annotations.vaccinesAdministered.sources.name
# annotations.vaccinesAdministered.sources.type
# annotations.vaccinesAdministered.sources.url
# annotations.vaccinesDistributed
# annotations.vaccinesDistributed.anomalies
# annotations.vaccinesDistributed.sources
# annotations.vaccinesDistributed.sources.name
# annotations.vaccinesDistributed.sources.type
# annotations.vaccinesDistributed.sources.url
# annotations.weeklyCovidAdmissionsPer100k
# annotations.weeklyCovidAdmissionsPer100k.anomalies
# annotations.weeklyCovidAdmissionsPer100k.sources
# annotations.weeklyCovidAdmissionsPer100k.sources.name
# annotations.weeklyCovidAdmissionsPer100k.sources.type
# annotations.weeklyCovidAdmissionsPer100k.sources.url
# annotations.weeklyNewCasesPer100k
# annotations.weeklyNewCasesPer100k.anomalies
# annotations.weeklyNewCasesPer100k.sources
# annotations.weeklyNewCasesPer100k.sources.name
# annotations.weeklyNewCasesPer100k.sources.type
# annotations.weeklyNewCasesPer100k.sources.url
# cdcTransmissionLevel
# communityLevels
# communityLevels.canCommunityLevel
# communityLevels.cdcCommunityLevel
# country
# county
# fips
# hsa
# hsaName
# hsaPopulation
# lastUpdatedDate
# lat
# level
# locationId
# long
# metrics
# metrics.bedsWithCovidPatientsRatio
# metrics.caseDensity
# metrics.contactTracerCapacityRatio
# metrics.icuCapacityRatio
# metrics.infectionRate
# metrics.infectionRateCI90
# metrics.testPositivityRatio
# metrics.testPositivityRatioDetails
# metrics.testPositivityRatioDetails.source
# metrics.vaccinationsAdditionalDoseRatio
# metrics.vaccinationsCompletedRatio
# metrics.vaccinationsFall2022BivalentBoosterRatio
# metrics.vaccinationsInitiatedRatio
# metrics.weeklyCovidAdmissionsPer100k
# metrics.weeklyNewCasesPer100k
# population
# riskLevels
# riskLevels.caseDensity
# riskLevels.contactTracerCapacityRatio
# riskLevels.icuCapacityRatio
# riskLevels.infectionRate
# riskLevels.overall
# riskLevels.testPositivityRatio
# state
# url

# %%
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()

# Extract and process hospitalization data for March 2021
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    hospitalizations = county_data["actuals"]["hospitalBeds"]
    hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})

# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")

# Print hospitalization data for March 2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# Total hospitalization entries for March 2021: 3223
#
# County: Aleutians East Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aleutians West Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anchorage Municipality, Hospitalizations in March 2021: {'capacity': 189, 'currentUsageTotal': 108, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Bethel Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bristol Bay Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Denali Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Dillingham Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Fairbanks North Star Borough, Hospitalizations in March 2021: {'capacity': 101, 'currentUsageTotal': 78, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Haines Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Hoonah-Angoon Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Juneau City and Borough, Hospitalizations in March 2021: {'capacity': 57, 'currentUsageTotal': 37, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Kenai Peninsula Borough, Hospitalizations in March 2021: {'capacity': 81, 'currentUsageTotal': 48, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Ketchikan Gateway Borough, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Kodiak Island Borough, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Kusilvak Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lake and Peninsula Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Matanuska-Susitna Borough, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 77, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 6}
# County: Nome Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: North Slope Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Northwest Arctic Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Petersburg Borough, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Prince of Wales-Hyder Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sitka City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Skagway Municipality, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Southeast Fairbanks Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Valdez-Cordova Census Area, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wrangell City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yakutat City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yukon-Koyukuk Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Autauga County, Hospitalizations in March 2021: {'capacity': 90, 'currentUsageTotal': 72, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Baldwin County, Hospitalizations in March 2021: {'capacity': 334, 'currentUsageTotal': 283, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Barbour County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 25, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bibb County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Blount County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bullock County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Butler County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': 230, 'currentUsageTotal': 172, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Chambers County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 32, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cherokee County, Hospitalizations in March 2021: {'capacity': 46, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Chilton County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Choctaw County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Clarke County, Hospitalizations in March 2021: {'capacity': 96, 'currentUsageTotal': 26, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Cleburne County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Coffee County, Hospitalizations in March 2021: {'capacity': 54, 'currentUsageTotal': 39, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Colbert County, Hospitalizations in March 2021: {'capacity': 270, 'currentUsageTotal': 134, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Conecuh County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Coosa County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Covington County, Hospitalizations in March 2021: {'capacity': 86, 'currentUsageTotal': 45, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Crenshaw County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 18, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cullman County, Hospitalizations in March 2021: {'capacity': 175, 'currentUsageTotal': 93, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 6}
# County: Dale County, Hospitalizations in March 2021: {'capacity': 59, 'currentUsageTotal': 20, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Dallas County, Hospitalizations in March 2021: {'capacity': 69, 'currentUsageTotal': 30, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: DeKalb County, Hospitalizations in March 2021: {'capacity': 58, 'currentUsageTotal': 35, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Elmore County, Hospitalizations in March 2021: {'capacity': 73, 'currentUsageTotal': 23, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Escambia County, Hospitalizations in March 2021: {'capacity': 65, 'currentUsageTotal': 23, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Etowah County, Hospitalizations in March 2021: {'capacity': 320, 'currentUsageTotal': 265, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Fayette County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Franklin County, Hospitalizations in March 2021: {'capacity': 47, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Geneva County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 28, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greene County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Hale County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Henry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Houston County, Hospitalizations in March 2021: {'capacity': 556, 'currentUsageTotal': 507, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 4}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 20, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 3293, 'currentUsageTotal': 2877, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 18}
# County: Lamar County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lauderdale County, Hospitalizations in March 2021: {'capacity': 252, 'currentUsageTotal': 211, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 11}
# County: Lawrence County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Lee County, Hospitalizations in March 2021: {'capacity': 274, 'currentUsageTotal': 219, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 5}
# County: Limestone County, Hospitalizations in March 2021: {'capacity': 102, 'currentUsageTotal': 40, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Lowndes County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Macon County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Madison County, Hospitalizations in March 2021: {'capacity': 1095, 'currentUsageTotal': 925, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 61}
# County: Marengo County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 35, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Marion County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 30, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Marshall County, Hospitalizations in March 2021: {'capacity': 120, 'currentUsageTotal': 72, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mobile County, Hospitalizations in March 2021: {'capacity': 1473, 'currentUsageTotal': 1308, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 17, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Montgomery County, Hospitalizations in March 2021: {'capacity': 840, 'currentUsageTotal': 638, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 9}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 247, 'currentUsageTotal': 158, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Perry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pickens County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pike County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 27, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Russell County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 22, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: St. Clair County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 33, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Shelby County, Hospitalizations in March 2021: {'capacity': 155, 'currentUsageTotal': 112, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Sumter County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Talladega County, Hospitalizations in March 2021: {'capacity': 116, 'currentUsageTotal': 62, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Tallapoosa County, Hospitalizations in March 2021: {'capacity': 73, 'currentUsageTotal': 33, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Tuscaloosa County, Hospitalizations in March 2021: {'capacity': 545, 'currentUsageTotal': 432, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 4}
# County: Walker County, Hospitalizations in March 2021: {'capacity': 120, 'currentUsageTotal': 71, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wilcox County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Winston County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Arkansas County, Hospitalizations in March 2021: {'capacity': 307, 'currentUsageTotal': 180, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Ashley County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Baxter County, Hospitalizations in March 2021: {'capacity': 270, 'currentUsageTotal': 187, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Benton County, Hospitalizations in March 2021: {'capacity': 193, 'currentUsageTotal': 184, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 12}
# County: Boone County, Hospitalizations in March 2021: {'capacity': 64, 'currentUsageTotal': 25, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Bradley County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Carroll County, Hospitalizations in March 2021: {'capacity': 11, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Chicot County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clark County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Cleburne County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cleveland County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Columbia County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Conway County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Craighead County, Hospitalizations in March 2021: {'capacity': 478, 'currentUsageTotal': 400, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 5}
# County: Crawford County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Crittenden County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cross County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Dallas County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Desha County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Drew County, Hospitalizations in March 2021: {'capacity': 30, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 9}
# County: Faulkner County, Hospitalizations in March 2021: {'capacity': 251, 'currentUsageTotal': 188, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Franklin County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Fulton County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Garland County, Hospitalizations in March 2021: {'capacity': 446, 'currentUsageTotal': 312, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Grant County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Greene County, Hospitalizations in March 2021: {'capacity': 190, 'currentUsageTotal': 80, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Hempstead County, Hospitalizations in March 2021: {'capacity': 46, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hot Spring County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Howard County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Independence County, Hospitalizations in March 2021: {'capacity': 130, 'currentUsageTotal': 83, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Izard County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 20, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 226, 'currentUsageTotal': 132, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Johnson County, Hospitalizations in March 2021: {'capacity': 122, 'currentUsageTotal': 41, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Lafayette County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lawrence County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Lee County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Little River County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 1, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Lonoke County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Madison County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Marion County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Miller County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Mississippi County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 22, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Montgomery County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Nevada County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Newton County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Ouachita County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 15, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Perry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Phillips County, Hospitalizations in March 2021: {'capacity': 4, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pike County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Poinsett County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Polk County, Hospitalizations in March 2021: {'capacity': 58, 'currentUsageTotal': 20, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Pope County, Hospitalizations in March 2021: {'capacity': 110, 'currentUsageTotal': 69, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Prairie County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pulaski County, Hospitalizations in March 2021: {'capacity': 2315, 'currentUsageTotal': 1752, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 18}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: St. Francis County, Hospitalizations in March 2021: {'capacity': 70, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Saline County, Hospitalizations in March 2021: {'capacity': 210, 'currentUsageTotal': 97, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Scott County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Searcy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sebastian County, Hospitalizations in March 2021: {'capacity': 468, 'currentUsageTotal': 414, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 5}
# County: Sevier County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 5, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sharp County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Stone County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Union County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 43, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Van Buren County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 453, 'currentUsageTotal': 353, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: White County, Hospitalizations in March 2021: {'capacity': 194, 'currentUsageTotal': 144, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Woodruff County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yell County, Hospitalizations in March 2021: {'capacity': 62, 'currentUsageTotal': 35, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Apache County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Cochise County, Hospitalizations in March 2021: {'capacity': 133, 'currentUsageTotal': 62, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Coconino County, Hospitalizations in March 2021: {'capacity': 201, 'currentUsageTotal': 178, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Gila County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Graham County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greenlee County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: La Paz County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Maricopa County, Hospitalizations in March 2021: {'capacity': 9304, 'currentUsageTotal': 7617, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Mohave County, Hospitalizations in March 2021: {'capacity': 482, 'currentUsageTotal': 158, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 8}
# County: Navajo County, Hospitalizations in March 2021: {'capacity': 140, 'currentUsageTotal': 66, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pima County, Hospitalizations in March 2021: {'capacity': 1802, 'currentUsageTotal': 1418, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 10}
# County: Pinal County, Hospitalizations in March 2021: {'capacity': 294, 'currentUsageTotal': 155, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Santa Cruz County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Yavapai County, Hospitalizations in March 2021: {'capacity': 244, 'currentUsageTotal': 225, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Yuma County, Hospitalizations in March 2021: {'capacity': 257, 'currentUsageTotal': 242, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Alameda County, Hospitalizations in March 2021: {'capacity': 2489, 'currentUsageTotal': 1572, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 48}
# County: Alpine County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Amador County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Butte County, Hospitalizations in March 2021: {'capacity': 424, 'currentUsageTotal': 358, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Calaveras County, Hospitalizations in March 2021: {'capacity': 42, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Colusa County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Contra Costa County, Hospitalizations in March 2021: {'capacity': 1306, 'currentUsageTotal': 1051, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 33}
# County: Del Norte County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 31, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: El Dorado County, Hospitalizations in March 2021: {'capacity': 105, 'currentUsageTotal': 83, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Fresno County, Hospitalizations in March 2021: {'capacity': 1739, 'currentUsageTotal': 1564, 'currentUsageCovid': 47, 'weeklyCovidAdmissions': 30}
# County: Glenn County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 19, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Humboldt County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 17, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Imperial County, Hospitalizations in March 2021: {'capacity': 261, 'currentUsageTotal': 105, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Inyo County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Kern County, Hospitalizations in March 2021: {'capacity': 906, 'currentUsageTotal': 760, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 8}
# County: Kings County, Hospitalizations in March 2021: {'capacity': 149, 'currentUsageTotal': 113, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lake County, Hospitalizations in March 2021: {'capacity': 53, 'currentUsageTotal': 34, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Lassen County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Los Angeles County, Hospitalizations in March 2021: {'capacity': 16169, 'currentUsageTotal': 12274, 'currentUsageCovid': 128, 'weeklyCovidAdmissions': 68}
# County: Madera County, Hospitalizations in March 2021: {'capacity': 106, 'currentUsageTotal': 3, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Marin County, Hospitalizations in March 2021: {'capacity': 438, 'currentUsageTotal': 324, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Mariposa County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Mendocino County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 70, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Merced County, Hospitalizations in March 2021: {'capacity': 276, 'currentUsageTotal': 159, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Modoc County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Mono County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Monterey County, Hospitalizations in March 2021: {'capacity': 688, 'currentUsageTotal': 419, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Napa County, Hospitalizations in March 2021: {'capacity': 45, 'currentUsageTotal': 41, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Nevada County, Hospitalizations in March 2021: {'capacity': 104, 'currentUsageTotal': 78, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Orange County, Hospitalizations in March 2021: {'capacity': 3615, 'currentUsageTotal': 2874, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 43}
# County: Placer County, Hospitalizations in March 2021: {'capacity': 828, 'currentUsageTotal': 784, 'currentUsageCovid': 19, 'weeklyCovidAdmissions': 44}
# County: Plumas County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Riverside County, Hospitalizations in March 2021: {'capacity': 2899, 'currentUsageTotal': 2272, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 9}
# County: Sacramento County, Hospitalizations in March 2021: {'capacity': 2309, 'currentUsageTotal': 2132, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 49}
# County: San Benito County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: San Bernardino County, Hospitalizations in March 2021: {'capacity': 3342, 'currentUsageTotal': 2585, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 11}
# County: San Diego County, Hospitalizations in March 2021: {'capacity': 5591, 'currentUsageTotal': 4111, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 22}
# County: San Francisco County, Hospitalizations in March 2021: {'capacity': 2100, 'currentUsageTotal': 1696, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 21}
# County: San Joaquin County, Hospitalizations in March 2021: {'capacity': 819, 'currentUsageTotal': 715, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 16}
# County: San Luis Obispo County, Hospitalizations in March 2021: {'capacity': 196, 'currentUsageTotal': 188, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: San Mateo County, Hospitalizations in March 2021: {'capacity': 856, 'currentUsageTotal': 425, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 13}
# County: Santa Barbara County, Hospitalizations in March 2021: {'capacity': 741, 'currentUsageTotal': 451, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 7}
# County: Santa Clara County, Hospitalizations in March 2021: {'capacity': 3314, 'currentUsageTotal': 2576, 'currentUsageCovid': 56, 'weeklyCovidAdmissions': 50}
# County: Santa Cruz County, Hospitalizations in March 2021: {'capacity': 196, 'currentUsageTotal': 165, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Shasta County, Hospitalizations in March 2021: {'capacity': 418, 'currentUsageTotal': 333, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 5}
# County: Sierra County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Siskiyou County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 22, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Solano County, Hospitalizations in March 2021: {'capacity': 422, 'currentUsageTotal': 342, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 10}
# County: Sonoma County, Hospitalizations in March 2021: {'capacity': 359, 'currentUsageTotal': 297, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 6}
# County: Stanislaus County, Hospitalizations in March 2021: {'capacity': 918, 'currentUsageTotal': 787, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 21}
# County: Sutter County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Tehama County, Hospitalizations in March 2021: {'capacity': 106, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Trinity County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Tulare County, Hospitalizations in March 2021: {'capacity': 434, 'currentUsageTotal': 353, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Tuolumne County, Hospitalizations in March 2021: {'capacity': 62, 'currentUsageTotal': 51, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Ventura County, Hospitalizations in March 2021: {'capacity': 1170, 'currentUsageTotal': 918, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 9}
# County: Yolo County, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 109, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Yuba County, Hospitalizations in March 2021: {'capacity': 217, 'currentUsageTotal': 163, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Adams County, Hospitalizations in March 2021: {'capacity': 1508, 'currentUsageTotal': 1231, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': 12}
# County: Alamosa County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Arapahoe County, Hospitalizations in March 2021: {'capacity': 1101, 'currentUsageTotal': 822, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 9}
# County: Archuleta County, Hospitalizations in March 2021: {'capacity': 9, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Baca County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Bent County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Boulder County, Hospitalizations in March 2021: {'capacity': 579, 'currentUsageTotal': 325, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Broomfield County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Chaffee County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Cheyenne County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clear Creek County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Conejos County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 2, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Costilla County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Crowley County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Custer County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Delta County, Hospitalizations in March 2021: {'capacity': 49, 'currentUsageTotal': 18, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Denver County, Hospitalizations in March 2021: {'capacity': 1784, 'currentUsageTotal': 1162, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Dolores County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Douglas County, Hospitalizations in March 2021: {'capacity': 624, 'currentUsageTotal': 427, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 12}
# County: Eagle County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Elbert County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: El Paso County, Hospitalizations in March 2021: {'capacity': 1216, 'currentUsageTotal': 770, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Fremont County, Hospitalizations in March 2021: {'capacity': 37, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Garfield County, Hospitalizations in March 2021: {'capacity': 97, 'currentUsageTotal': 51, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Gilpin County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Grand County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gunnison County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hinsdale County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Huerfano County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 535, 'currentUsageTotal': 352, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Kiowa County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Kit Carson County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lake County, Hospitalizations in March 2021: {'capacity': 8, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: La Plata County, Hospitalizations in March 2021: {'capacity': 97, 'currentUsageTotal': 55, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Larimer County, Hospitalizations in March 2021: {'capacity': 652, 'currentUsageTotal': 363, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Las Animas County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 13}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mesa County, Hospitalizations in March 2021: {'capacity': 320, 'currentUsageTotal': 237, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Mineral County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Moffat County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Montezuma County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 15, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Montrose County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 26, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 51, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Otero County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Ouray County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Park County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Phillips County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 25, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Pitkin County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Prowers County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Pueblo County, Hospitalizations in March 2021: {'capacity': 410, 'currentUsageTotal': 245, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Rio Blanco County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 24, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Rio Grande County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 3, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Routt County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Saguache County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Juan County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Miguel County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sedgwick County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 1, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Summit County, Hospitalizations in March 2021: {'capacity': 37, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Teller County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Washington County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Weld County, Hospitalizations in March 2021: {'capacity': 373, 'currentUsageTotal': 196, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Yuma County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Fairfield County, Hospitalizations in March 2021: {'capacity': 1820, 'currentUsageTotal': 1326, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': 12}
# County: Hartford County, Hospitalizations in March 2021: {'capacity': 2688, 'currentUsageTotal': 1979, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 18}
# County: Litchfield County, Hospitalizations in March 2021: {'capacity': 158, 'currentUsageTotal': 105, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# ...
# County: Ozaukee County, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 109, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Pepin County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pierce County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Polk County, Hospitalizations in March 2021: {'capacity': 77, 'currentUsageTotal': 33, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Portage County, Hospitalizations in March 2021: {'capacity': 65, 'currentUsageTotal': 31, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Price County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Racine County, Hospitalizations in March 2021: {'capacity': 249, 'currentUsageTotal': 225, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Richland County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Rock County, Hospitalizations in March 2021: {'capacity': 235, 'currentUsageTotal': 214, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Rusk County, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: St. Croix County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 23, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Sauk County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 50, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Sawyer County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 14, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Shawano County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 17, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Sheboygan County, Hospitalizations in March 2021: {'capacity': 174, 'currentUsageTotal': 102, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Taylor County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Trempealeau County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Vernon County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 16, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Vilas County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Walworth County, Hospitalizations in March 2021: {'capacity': 79, 'currentUsageTotal': 44, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Washburn County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 12}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 105, 'currentUsageTotal': 58, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Waukesha County, Hospitalizations in March 2021: {'capacity': 626, 'currentUsageTotal': 422, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 8}
# County: Waupaca County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 12, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Waushara County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Winnebago County, Hospitalizations in March 2021: {'capacity': 297, 'currentUsageTotal': 194, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Wood County, Hospitalizations in March 2021: {'capacity': 248, 'currentUsageTotal': 208, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Barbour County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Berkeley County, Hospitalizations in March 2021: {'capacity': 180, 'currentUsageTotal': 110, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Boone County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Braxton County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Brooke County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Cabell County, Hospitalizations in March 2021: {'capacity': 683, 'currentUsageTotal': 576, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 8}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Doddridge County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Fayette County, Hospitalizations in March 2021: {'capacity': 44, 'currentUsageTotal': 31, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gilmer County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Grant County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 15, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greenbrier County, Hospitalizations in March 2021: {'capacity': 45, 'currentUsageTotal': 45, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Hampshire County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 6, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Hancock County, Hospitalizations in March 2021: {'capacity': 223, 'currentUsageTotal': 185, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Hardy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Harrison County, Hospitalizations in March 2021: {'capacity': 264, 'currentUsageTotal': 204, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 16, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Kanawha County, Hospitalizations in March 2021: {'capacity': 990, 'currentUsageTotal': 878, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 8}
# County: Lewis County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 9}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 112, 'currentUsageTotal': 57, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: McDowell County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Marion County, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Marshall County, Hospitalizations in March 2021: {'capacity': 94, 'currentUsageTotal': 34, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Mason County, Hospitalizations in March 2021: {'capacity': 41, 'currentUsageTotal': 20, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mercer County, Hospitalizations in March 2021: {'capacity': 140, 'currentUsageTotal': 103, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Mineral County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 16, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mingo County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Monongalia County, Hospitalizations in March 2021: {'capacity': 735, 'currentUsageTotal': 654, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 14, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Nicholas County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 25, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Ohio County, Hospitalizations in March 2021: {'capacity': 221, 'currentUsageTotal': 154, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Pendleton County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pleasants County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pocahontas County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Preston County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Putnam County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Raleigh County, Hospitalizations in March 2021: {'capacity': 252, 'currentUsageTotal': 183, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Ritchie County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Roane County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Summers County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Taylor County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Tucker County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Tyler County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Upshur County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 17, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Wayne County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Webster County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wetzel County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Wirt County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Wood County, Hospitalizations in March 2021: {'capacity': 259, 'currentUsageTotal': 216, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Wyoming County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Albany County, Hospitalizations in March 2021: {'capacity': 89, 'currentUsageTotal': 29, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Big Horn County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Campbell County, Hospitalizations in March 2021: {'capacity': 86, 'currentUsageTotal': 32, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Carbon County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Converse County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Crook County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Fremont County, Hospitalizations in March 2021: {'capacity': 146, 'currentUsageTotal': 19, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Goshen County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hot Springs County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Johnson County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Laramie County, Hospitalizations in March 2021: {'capacity': 182, 'currentUsageTotal': 129, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 18}
# County: Natrona County, Hospitalizations in March 2021: {'capacity': 155, 'currentUsageTotal': 141, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Niobrara County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 17, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Park County, Hospitalizations in March 2021: {'capacity': 61, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Platte County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Sheridan County, Hospitalizations in March 2021: {'capacity': 88, 'currentUsageTotal': 38, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Sublette County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sweetwater County, Hospitalizations in March 2021: {'capacity': 51, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Teton County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 18, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Uinta County, Hospitalizations in March 2021: {'capacity': 44, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Washakie County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Weston County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}

# %%
# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&date={start_date}-{end_date}"
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()
# Extract and process hospitalization data for March 2021
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    hospitalizations = county_data["actuals"]["hospitalBeds"]
    hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})
# Print hospitalization data for March 2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# County: Aleutians East Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Aleutians West Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Anchorage Municipality, Hospitalizations in March 2021: {'capacity': 189, 'currentUsageTotal': 108, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Bethel Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Bristol Bay Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Denali Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Dillingham Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Fairbanks North Star Borough, Hospitalizations in March 2021: {'capacity': 101, 'currentUsageTotal': 78, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Haines Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Hoonah-Angoon Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Juneau City and Borough, Hospitalizations in March 2021: {'capacity': 57, 'currentUsageTotal': 37, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Kenai Peninsula Borough, Hospitalizations in March 2021: {'capacity': 81, 'currentUsageTotal': 48, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Ketchikan Gateway Borough, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Kodiak Island Borough, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Kusilvak Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lake and Peninsula Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Matanuska-Susitna Borough, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 77, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 6}
# County: Nome Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: North Slope Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Northwest Arctic Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Petersburg Borough, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Prince of Wales-Hyder Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sitka City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Skagway Municipality, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Southeast Fairbanks Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Valdez-Cordova Census Area, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wrangell City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yakutat City and Borough, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yukon-Koyukuk Census Area, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Autauga County, Hospitalizations in March 2021: {'capacity': 90, 'currentUsageTotal': 72, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Baldwin County, Hospitalizations in March 2021: {'capacity': 334, 'currentUsageTotal': 283, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Barbour County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 25, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bibb County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Blount County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Bullock County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Butler County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': 230, 'currentUsageTotal': 172, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Chambers County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 32, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cherokee County, Hospitalizations in March 2021: {'capacity': 46, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Chilton County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Choctaw County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Clarke County, Hospitalizations in March 2021: {'capacity': 96, 'currentUsageTotal': 26, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Cleburne County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Coffee County, Hospitalizations in March 2021: {'capacity': 54, 'currentUsageTotal': 39, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Colbert County, Hospitalizations in March 2021: {'capacity': 270, 'currentUsageTotal': 134, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Conecuh County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Coosa County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Covington County, Hospitalizations in March 2021: {'capacity': 86, 'currentUsageTotal': 45, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Crenshaw County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 18, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cullman County, Hospitalizations in March 2021: {'capacity': 175, 'currentUsageTotal': 93, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 6}
# County: Dale County, Hospitalizations in March 2021: {'capacity': 59, 'currentUsageTotal': 20, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Dallas County, Hospitalizations in March 2021: {'capacity': 69, 'currentUsageTotal': 30, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: DeKalb County, Hospitalizations in March 2021: {'capacity': 58, 'currentUsageTotal': 35, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Elmore County, Hospitalizations in March 2021: {'capacity': 73, 'currentUsageTotal': 23, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Escambia County, Hospitalizations in March 2021: {'capacity': 65, 'currentUsageTotal': 23, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Etowah County, Hospitalizations in March 2021: {'capacity': 320, 'currentUsageTotal': 265, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Fayette County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Franklin County, Hospitalizations in March 2021: {'capacity': 47, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Geneva County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 28, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greene County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Hale County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Henry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Houston County, Hospitalizations in March 2021: {'capacity': 556, 'currentUsageTotal': 507, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 4}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 20, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 3293, 'currentUsageTotal': 2877, 'currentUsageCovid': 33, 'weeklyCovidAdmissions': 18}
# County: Lamar County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lauderdale County, Hospitalizations in March 2021: {'capacity': 252, 'currentUsageTotal': 211, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 11}
# County: Lawrence County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Lee County, Hospitalizations in March 2021: {'capacity': 274, 'currentUsageTotal': 219, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 5}
# County: Limestone County, Hospitalizations in March 2021: {'capacity': 102, 'currentUsageTotal': 40, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Lowndes County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Macon County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Madison County, Hospitalizations in March 2021: {'capacity': 1095, 'currentUsageTotal': 925, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 61}
# County: Marengo County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 35, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Marion County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 30, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Marshall County, Hospitalizations in March 2021: {'capacity': 120, 'currentUsageTotal': 72, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mobile County, Hospitalizations in March 2021: {'capacity': 1473, 'currentUsageTotal': 1308, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 17, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Montgomery County, Hospitalizations in March 2021: {'capacity': 840, 'currentUsageTotal': 638, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 9}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 247, 'currentUsageTotal': 158, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Perry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pickens County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pike County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 27, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Russell County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 22, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: St. Clair County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 33, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Shelby County, Hospitalizations in March 2021: {'capacity': 155, 'currentUsageTotal': 112, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Sumter County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Talladega County, Hospitalizations in March 2021: {'capacity': 116, 'currentUsageTotal': 62, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Tallapoosa County, Hospitalizations in March 2021: {'capacity': 73, 'currentUsageTotal': 33, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Tuscaloosa County, Hospitalizations in March 2021: {'capacity': 545, 'currentUsageTotal': 432, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 4}
# County: Walker County, Hospitalizations in March 2021: {'capacity': 120, 'currentUsageTotal': 71, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wilcox County, Hospitalizations in March 2021: {'capacity': 21, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Winston County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Arkansas County, Hospitalizations in March 2021: {'capacity': 307, 'currentUsageTotal': 180, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Ashley County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Baxter County, Hospitalizations in March 2021: {'capacity': 270, 'currentUsageTotal': 187, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Benton County, Hospitalizations in March 2021: {'capacity': 193, 'currentUsageTotal': 184, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 12}
# County: Boone County, Hospitalizations in March 2021: {'capacity': 64, 'currentUsageTotal': 25, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Bradley County, Hospitalizations in March 2021: {'capacity': 33, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Carroll County, Hospitalizations in March 2021: {'capacity': 11, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Chicot County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clark County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Cleburne County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cleveland County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Columbia County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Conway County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Craighead County, Hospitalizations in March 2021: {'capacity': 478, 'currentUsageTotal': 400, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 5}
# County: Crawford County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Crittenden County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Cross County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Dallas County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Desha County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Drew County, Hospitalizations in March 2021: {'capacity': 30, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 9}
# County: Faulkner County, Hospitalizations in March 2021: {'capacity': 251, 'currentUsageTotal': 188, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Franklin County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Fulton County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Garland County, Hospitalizations in March 2021: {'capacity': 446, 'currentUsageTotal': 312, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Grant County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Greene County, Hospitalizations in March 2021: {'capacity': 190, 'currentUsageTotal': 80, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Hempstead County, Hospitalizations in March 2021: {'capacity': 46, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Hot Spring County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Howard County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Independence County, Hospitalizations in March 2021: {'capacity': 130, 'currentUsageTotal': 83, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Izard County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 20, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 226, 'currentUsageTotal': 132, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Johnson County, Hospitalizations in March 2021: {'capacity': 122, 'currentUsageTotal': 41, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Lafayette County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lawrence County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Lee County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Little River County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 1, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Lonoke County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Madison County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Marion County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Miller County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Mississippi County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 22, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Montgomery County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Nevada County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Newton County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Ouachita County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 15, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Perry County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Phillips County, Hospitalizations in March 2021: {'capacity': 4, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pike County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Poinsett County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Polk County, Hospitalizations in March 2021: {'capacity': 58, 'currentUsageTotal': 20, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Pope County, Hospitalizations in March 2021: {'capacity': 110, 'currentUsageTotal': 69, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Prairie County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pulaski County, Hospitalizations in March 2021: {'capacity': 2315, 'currentUsageTotal': 1752, 'currentUsageCovid': 17, 'weeklyCovidAdmissions': 18}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: St. Francis County, Hospitalizations in March 2021: {'capacity': 70, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Saline County, Hospitalizations in March 2021: {'capacity': 210, 'currentUsageTotal': 97, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Scott County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Searcy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sebastian County, Hospitalizations in March 2021: {'capacity': 468, 'currentUsageTotal': 414, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 5}
# County: Sevier County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 5, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sharp County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Stone County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Union County, Hospitalizations in March 2021: {'capacity': 43, 'currentUsageTotal': 43, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Van Buren County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 453, 'currentUsageTotal': 353, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: White County, Hospitalizations in March 2021: {'capacity': 194, 'currentUsageTotal': 144, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Woodruff County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Yell County, Hospitalizations in March 2021: {'capacity': 62, 'currentUsageTotal': 35, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Apache County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Cochise County, Hospitalizations in March 2021: {'capacity': 133, 'currentUsageTotal': 62, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Coconino County, Hospitalizations in March 2021: {'capacity': 201, 'currentUsageTotal': 178, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Gila County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Graham County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greenlee County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: La Paz County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Maricopa County, Hospitalizations in March 2021: {'capacity': 9304, 'currentUsageTotal': 7617, 'currentUsageCovid': 59, 'weeklyCovidAdmissions': 67}
# County: Mohave County, Hospitalizations in March 2021: {'capacity': 482, 'currentUsageTotal': 158, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 8}
# County: Navajo County, Hospitalizations in March 2021: {'capacity': 140, 'currentUsageTotal': 66, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pima County, Hospitalizations in March 2021: {'capacity': 1802, 'currentUsageTotal': 1418, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 10}
# County: Pinal County, Hospitalizations in March 2021: {'capacity': 294, 'currentUsageTotal': 155, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Santa Cruz County, Hospitalizations in March 2021: {'capacity': 27, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Yavapai County, Hospitalizations in March 2021: {'capacity': 244, 'currentUsageTotal': 225, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Yuma County, Hospitalizations in March 2021: {'capacity': 257, 'currentUsageTotal': 242, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Alameda County, Hospitalizations in March 2021: {'capacity': 2489, 'currentUsageTotal': 1572, 'currentUsageCovid': 31, 'weeklyCovidAdmissions': 48}
# County: Alpine County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Amador County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Butte County, Hospitalizations in March 2021: {'capacity': 424, 'currentUsageTotal': 358, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Calaveras County, Hospitalizations in March 2021: {'capacity': 42, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Colusa County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Contra Costa County, Hospitalizations in March 2021: {'capacity': 1306, 'currentUsageTotal': 1051, 'currentUsageCovid': 24, 'weeklyCovidAdmissions': 33}
# County: Del Norte County, Hospitalizations in March 2021: {'capacity': 55, 'currentUsageTotal': 31, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: El Dorado County, Hospitalizations in March 2021: {'capacity': 105, 'currentUsageTotal': 83, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Fresno County, Hospitalizations in March 2021: {'capacity': 1739, 'currentUsageTotal': 1564, 'currentUsageCovid': 47, 'weeklyCovidAdmissions': 30}
# County: Glenn County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 19, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Humboldt County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 17, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Imperial County, Hospitalizations in March 2021: {'capacity': 261, 'currentUsageTotal': 105, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Inyo County, Hospitalizations in March 2021: {'capacity': 29, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Kern County, Hospitalizations in March 2021: {'capacity': 906, 'currentUsageTotal': 760, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 8}
# County: Kings County, Hospitalizations in March 2021: {'capacity': 149, 'currentUsageTotal': 113, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lake County, Hospitalizations in March 2021: {'capacity': 53, 'currentUsageTotal': 34, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Lassen County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Los Angeles County, Hospitalizations in March 2021: {'capacity': 16169, 'currentUsageTotal': 12274, 'currentUsageCovid': 128, 'weeklyCovidAdmissions': 68}
# County: Madera County, Hospitalizations in March 2021: {'capacity': 106, 'currentUsageTotal': 3, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Marin County, Hospitalizations in March 2021: {'capacity': 438, 'currentUsageTotal': 324, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Mariposa County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': None}
# County: Mendocino County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 70, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Merced County, Hospitalizations in March 2021: {'capacity': 276, 'currentUsageTotal': 159, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Modoc County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Mono County, Hospitalizations in March 2021: {'capacity': 17, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Monterey County, Hospitalizations in March 2021: {'capacity': 688, 'currentUsageTotal': 419, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Napa County, Hospitalizations in March 2021: {'capacity': 45, 'currentUsageTotal': 41, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Nevada County, Hospitalizations in March 2021: {'capacity': 104, 'currentUsageTotal': 78, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Orange County, Hospitalizations in March 2021: {'capacity': 3615, 'currentUsageTotal': 2874, 'currentUsageCovid': 27, 'weeklyCovidAdmissions': 43}
# County: Placer County, Hospitalizations in March 2021: {'capacity': 828, 'currentUsageTotal': 784, 'currentUsageCovid': 19, 'weeklyCovidAdmissions': 44}
# County: Plumas County, Hospitalizations in March 2021: {'capacity': 35, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Riverside County, Hospitalizations in March 2021: {'capacity': 2899, 'currentUsageTotal': 2272, 'currentUsageCovid': 18, 'weeklyCovidAdmissions': 9}
# County: Sacramento County, Hospitalizations in March 2021: {'capacity': 2309, 'currentUsageTotal': 2132, 'currentUsageCovid': 30, 'weeklyCovidAdmissions': 49}
# County: San Benito County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: San Bernardino County, Hospitalizations in March 2021: {'capacity': 3342, 'currentUsageTotal': 2585, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 11}
# County: San Diego County, Hospitalizations in March 2021: {'capacity': 5591, 'currentUsageTotal': 4111, 'currentUsageCovid': 34, 'weeklyCovidAdmissions': 22}
# County: San Francisco County, Hospitalizations in March 2021: {'capacity': 2100, 'currentUsageTotal': 1696, 'currentUsageCovid': 26, 'weeklyCovidAdmissions': 21}
# County: San Joaquin County, Hospitalizations in March 2021: {'capacity': 819, 'currentUsageTotal': 715, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 16}
# County: San Luis Obispo County, Hospitalizations in March 2021: {'capacity': 196, 'currentUsageTotal': 188, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: San Mateo County, Hospitalizations in March 2021: {'capacity': 856, 'currentUsageTotal': 425, 'currentUsageCovid': 13, 'weeklyCovidAdmissions': 13}
# County: Santa Barbara County, Hospitalizations in March 2021: {'capacity': 741, 'currentUsageTotal': 451, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 7}
# County: Santa Clara County, Hospitalizations in March 2021: {'capacity': 3314, 'currentUsageTotal': 2576, 'currentUsageCovid': 56, 'weeklyCovidAdmissions': 50}
# County: Santa Cruz County, Hospitalizations in March 2021: {'capacity': 196, 'currentUsageTotal': 165, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Shasta County, Hospitalizations in March 2021: {'capacity': 418, 'currentUsageTotal': 333, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 5}
# County: Sierra County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Siskiyou County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 22, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Solano County, Hospitalizations in March 2021: {'capacity': 422, 'currentUsageTotal': 342, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 10}
# County: Sonoma County, Hospitalizations in March 2021: {'capacity': 359, 'currentUsageTotal': 297, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 6}
# County: Stanislaus County, Hospitalizations in March 2021: {'capacity': 918, 'currentUsageTotal': 787, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 21}
# County: Sutter County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Tehama County, Hospitalizations in March 2021: {'capacity': 106, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Trinity County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Tulare County, Hospitalizations in March 2021: {'capacity': 434, 'currentUsageTotal': 353, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Tuolumne County, Hospitalizations in March 2021: {'capacity': 62, 'currentUsageTotal': 51, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Ventura County, Hospitalizations in March 2021: {'capacity': 1170, 'currentUsageTotal': 918, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 9}
# County: Yolo County, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 109, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Yuba County, Hospitalizations in March 2021: {'capacity': 217, 'currentUsageTotal': 163, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Adams County, Hospitalizations in March 2021: {'capacity': 1508, 'currentUsageTotal': 1231, 'currentUsageCovid': 15, 'weeklyCovidAdmissions': 12}
# County: Alamosa County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Arapahoe County, Hospitalizations in March 2021: {'capacity': 1101, 'currentUsageTotal': 822, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 9}
# County: Archuleta County, Hospitalizations in March 2021: {'capacity': 9, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Baca County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Bent County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Boulder County, Hospitalizations in March 2021: {'capacity': 579, 'currentUsageTotal': 325, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Broomfield County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 21, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Chaffee County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Cheyenne County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clear Creek County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Conejos County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 2, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Costilla County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Crowley County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Custer County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Delta County, Hospitalizations in March 2021: {'capacity': 49, 'currentUsageTotal': 18, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Denver County, Hospitalizations in March 2021: {'capacity': 1784, 'currentUsageTotal': 1162, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Dolores County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Douglas County, Hospitalizations in March 2021: {'capacity': 624, 'currentUsageTotal': 427, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 12}
# County: Eagle County, Hospitalizations in March 2021: {'capacity': 56, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Elbert County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: El Paso County, Hospitalizations in March 2021: {'capacity': 1216, 'currentUsageTotal': 770, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Fremont County, Hospitalizations in March 2021: {'capacity': 37, 'currentUsageTotal': 14, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Garfield County, Hospitalizations in March 2021: {'capacity': 97, 'currentUsageTotal': 51, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Gilpin County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Grand County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gunnison County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hinsdale County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Huerfano County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 11, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 535, 'currentUsageTotal': 352, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# County: Kiowa County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 13, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Kit Carson County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lake County, Hospitalizations in March 2021: {'capacity': 8, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: La Plata County, Hospitalizations in March 2021: {'capacity': 97, 'currentUsageTotal': 55, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Larimer County, Hospitalizations in March 2021: {'capacity': 652, 'currentUsageTotal': 363, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Las Animas County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 13}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mesa County, Hospitalizations in March 2021: {'capacity': 320, 'currentUsageTotal': 237, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Mineral County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Moffat County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Montezuma County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 15, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Montrose County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 26, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 51, 'currentUsageTotal': 13, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Otero County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Ouray County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Park County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Phillips County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 25, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Pitkin County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Prowers County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Pueblo County, Hospitalizations in March 2021: {'capacity': 410, 'currentUsageTotal': 245, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Rio Blanco County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 24, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Rio Grande County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 3, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Routt County, Hospitalizations in March 2021: {'capacity': 34, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Saguache County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Juan County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: San Miguel County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sedgwick County, Hospitalizations in March 2021: {'capacity': 10, 'currentUsageTotal': 1, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Summit County, Hospitalizations in March 2021: {'capacity': 37, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Teller County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 0, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Washington County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Weld County, Hospitalizations in March 2021: {'capacity': 373, 'currentUsageTotal': 196, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 7}
# County: Yuma County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Fairfield County, Hospitalizations in March 2021: {'capacity': 1820, 'currentUsageTotal': 1326, 'currentUsageCovid': 9, 'weeklyCovidAdmissions': 12}
# County: Hartford County, Hospitalizations in March 2021: {'capacity': 2688, 'currentUsageTotal': 1979, 'currentUsageCovid': 11, 'weeklyCovidAdmissions': 18}
# County: Litchfield County, Hospitalizations in March 2021: {'capacity': 158, 'currentUsageTotal': 105, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Middlesex County, Hospitalizations in March 2021: {'capacity': 220, 'currentUsageTotal': 138, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 5}
# ...
# County: Ozaukee County, Hospitalizations in March 2021: {'capacity': 160, 'currentUsageTotal': 109, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Pepin County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 2, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Pierce County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Polk County, Hospitalizations in March 2021: {'capacity': 77, 'currentUsageTotal': 33, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Portage County, Hospitalizations in March 2021: {'capacity': 65, 'currentUsageTotal': 31, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Price County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Racine County, Hospitalizations in March 2021: {'capacity': 249, 'currentUsageTotal': 225, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Richland County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Rock County, Hospitalizations in March 2021: {'capacity': 235, 'currentUsageTotal': 214, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 4}
# County: Rusk County, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: St. Croix County, Hospitalizations in March 2021: {'capacity': 93, 'currentUsageTotal': 23, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Sauk County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 50, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Sawyer County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 14, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Shawano County, Hospitalizations in March 2021: {'capacity': 40, 'currentUsageTotal': 17, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Sheboygan County, Hospitalizations in March 2021: {'capacity': 174, 'currentUsageTotal': 102, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Taylor County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Trempealeau County, Hospitalizations in March 2021: {'capacity': 31, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Vernon County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 16, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Vilas County, Hospitalizations in March 2021: {'capacity': 13, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Walworth County, Hospitalizations in March 2021: {'capacity': 79, 'currentUsageTotal': 44, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Washburn County, Hospitalizations in March 2021: {'capacity': 28, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 12}
# County: Washington County, Hospitalizations in March 2021: {'capacity': 105, 'currentUsageTotal': 58, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Waukesha County, Hospitalizations in March 2021: {'capacity': 626, 'currentUsageTotal': 422, 'currentUsageCovid': 7, 'weeklyCovidAdmissions': 8}
# County: Waupaca County, Hospitalizations in March 2021: {'capacity': 38, 'currentUsageTotal': 12, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Waushara County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Winnebago County, Hospitalizations in March 2021: {'capacity': 297, 'currentUsageTotal': 194, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: Wood County, Hospitalizations in March 2021: {'capacity': 248, 'currentUsageTotal': 208, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Barbour County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': None}
# County: Berkeley County, Hospitalizations in March 2021: {'capacity': 180, 'currentUsageTotal': 110, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Boone County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 21, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Braxton County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Brooke County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Cabell County, Hospitalizations in March 2021: {'capacity': 683, 'currentUsageTotal': 576, 'currentUsageCovid': 8, 'weeklyCovidAdmissions': 8}
# County: Calhoun County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Clay County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Doddridge County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Fayette County, Hospitalizations in March 2021: {'capacity': 44, 'currentUsageTotal': 31, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Gilmer County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Grant County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 15, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Greenbrier County, Hospitalizations in March 2021: {'capacity': 45, 'currentUsageTotal': 45, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 8}
# County: Hampshire County, Hospitalizations in March 2021: {'capacity': 14, 'currentUsageTotal': 6, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Hancock County, Hospitalizations in March 2021: {'capacity': 223, 'currentUsageTotal': 185, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}
# County: Hardy County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Harrison County, Hospitalizations in March 2021: {'capacity': 264, 'currentUsageTotal': 204, 'currentUsageCovid': 3, 'weeklyCovidAdmissions': 5}
# County: Jackson County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 12, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Jefferson County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 16, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Kanawha County, Hospitalizations in March 2021: {'capacity': 990, 'currentUsageTotal': 878, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 8}
# County: Lewis County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 14, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 9}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Logan County, Hospitalizations in March 2021: {'capacity': 112, 'currentUsageTotal': 57, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 8}
# County: McDowell County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 6, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Marion County, Hospitalizations in March 2021: {'capacity': 5, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Marshall County, Hospitalizations in March 2021: {'capacity': 94, 'currentUsageTotal': 34, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Mason County, Hospitalizations in March 2021: {'capacity': 41, 'currentUsageTotal': 20, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mercer County, Hospitalizations in March 2021: {'capacity': 140, 'currentUsageTotal': 103, 'currentUsageCovid': 5, 'weeklyCovidAdmissions': 4}
# County: Mineral County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 16, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Mingo County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Monongalia County, Hospitalizations in March 2021: {'capacity': 735, 'currentUsageTotal': 654, 'currentUsageCovid': 6, 'weeklyCovidAdmissions': 4}
# County: Monroe County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Morgan County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 14, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 5}
# County: Nicholas County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 25, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Ohio County, Hospitalizations in March 2021: {'capacity': 221, 'currentUsageTotal': 154, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 6}
# County: Pendleton County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pleasants County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Pocahontas County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 6}
# County: Preston County, Hospitalizations in March 2021: {'capacity': 20, 'currentUsageTotal': 9, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Putnam County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Raleigh County, Hospitalizations in March 2021: {'capacity': 252, 'currentUsageTotal': 183, 'currentUsageCovid': 2, 'weeklyCovidAdmissions': 4}
# County: Randolph County, Hospitalizations in March 2021: {'capacity': 32, 'currentUsageTotal': 26, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Ritchie County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Roane County, Hospitalizations in March 2021: {'capacity': 22, 'currentUsageTotal': 10, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Summers County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 10, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Taylor County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Tucker County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Tyler County, Hospitalizations in March 2021: {'capacity': 6, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Upshur County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 17, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Wayne County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Webster County, Hospitalizations in March 2021: {'capacity': 15, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Wetzel County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 8, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Wirt County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Wood County, Hospitalizations in March 2021: {'capacity': 259, 'currentUsageTotal': 216, 'currentUsageCovid': 4, 'weeklyCovidAdmissions': 4}
# County: Wyoming County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Albany County, Hospitalizations in March 2021: {'capacity': 89, 'currentUsageTotal': 29, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Big Horn County, Hospitalizations in March 2021: {'capacity': 24, 'currentUsageTotal': 9, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 10}
# County: Campbell County, Hospitalizations in March 2021: {'capacity': 86, 'currentUsageTotal': 32, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Carbon County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Converse County, Hospitalizations in March 2021: {'capacity': 50, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Crook County, Hospitalizations in March 2021: {'capacity': 16, 'currentUsageTotal': 1, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Fremont County, Hospitalizations in March 2021: {'capacity': 146, 'currentUsageTotal': 19, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Goshen County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Hot Springs County, Hospitalizations in March 2021: {'capacity': 19, 'currentUsageTotal': 5, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Johnson County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Laramie County, Hospitalizations in March 2021: {'capacity': 182, 'currentUsageTotal': 129, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Lincoln County, Hospitalizations in March 2021: {'capacity': 76, 'currentUsageTotal': 7, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 18}
# County: Natrona County, Hospitalizations in March 2021: {'capacity': 155, 'currentUsageTotal': 141, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 4}
# County: Niobrara County, Hospitalizations in March 2021: {'capacity': 26, 'currentUsageTotal': 17, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 7}
# County: Park County, Hospitalizations in March 2021: {'capacity': 61, 'currentUsageTotal': 29, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 12}
# County: Platte County, Hospitalizations in March 2021: {'capacity': 25, 'currentUsageTotal': 8, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Sheridan County, Hospitalizations in March 2021: {'capacity': 88, 'currentUsageTotal': 38, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 7}
# County: Sublette County, Hospitalizations in March 2021: {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}
# County: Sweetwater County, Hospitalizations in March 2021: {'capacity': 51, 'currentUsageTotal': 27, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Teton County, Hospitalizations in March 2021: {'capacity': 48, 'currentUsageTotal': 18, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 5}
# County: Uinta County, Hospitalizations in March 2021: {'capacity': 44, 'currentUsageTotal': 3, 'currentUsageCovid': 1, 'weeklyCovidAdmissions': 4}
# County: Washakie County, Hospitalizations in March 2021: {'capacity': 18, 'currentUsageTotal': 4, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 5}
# County: Weston County, Hospitalizations in March 2021: {'capacity': 12, 'currentUsageTotal': 3, 'currentUsageCovid': 0, 'weeklyCovidAdmissions': 6}

# %%
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()
# Ensure covid_data is a list of dictionaries; each dictionary represents a county
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    # Check if 'actualsTimeseries' is a list and iterate through it
    for date_entry in county_data["actuals"]:
        date = date_entry.get("date")
        # Filter for March 2021 entries
        if date.startswith("2021-03"):
            hospitalizations = date_entry.get("HospitalBeds", {})
            # Check if 'hospitalizations' data exists and does not contain any "none" values
            if hospitalizations and not any(value == "none" for value in hospitalizations.values()):
                # Check if specific keys have values other than None
                if all(key not in hospitalizations or hospitalizations[key] is not None for key in ['capacity', 'currentUsageTotal', 'currentUsageCovid', 'weeklyCovidAdmissions']):
                    # Append a new entry for each date in March 2021
                    hospitalizations_march_2021.append({
                        "County": county_name,
                        "Date": date,
                        "Hospitalizations": hospitalizations
                    })
# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")
# Adjusted print to include date for data in hospitalizations_march_2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Date: {data['Date']}, Hospitalizations: {data['Hospitalizations']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       8 # Check if 'actualsTimeseries' is a list and iterate through it
#       9 for date_entry in county_data["actuals"]:
# ---> 10     date = date_entry.get("date")
#      11     # Filter for March 2021 entries
#      12     if date.startswith("2021-03"):
#
# AttributeError: 'str' object has no attribute 'get'
