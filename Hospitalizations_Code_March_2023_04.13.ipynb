# %%
import requests
import json
from config import api_key
from datetime import datetime

# %%
####Find All fields from JSON###

# URL for GET requests to retrieve historical hospitalization data
url = "https://api.covidactnow.org/v2/state/TX.json?"

# Date range for March 2021
start_date = "2021-03-01"
end_date = "2021-03-03"  # Adjusted to cover the full month of March 2021

# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# Function to recursively collect field names from a JSON object/dictionary
def collect_fields(json_obj, fields_set, parent_key=''):
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            # Constructing a "path" for nested fields
            new_key = f"{parent_key}.{key}" if parent_key else key
            fields_set.add(new_key)
            collect_fields(value, fields_set, new_key)
    elif isinstance(json_obj, list):
        for item in json_obj:
            collect_fields(item, fields_set, parent_key)

# Function to fetch and parse the JSON data from the API
def fetch_data_and_fields(url):
    response = requests.get(url)
    response_json = response.json()
    
    fields_set = set()
    collect_fields(response_json, fields_set)
    
    return list(fields_set)

# Fetching data and collecting fields
fields = fetch_data_and_fields(query_url)

# Printing the number of different fields
print(f"Total number of different fields: {len(fields)}")

# Printing the list of all fields
for field in sorted(fields):
    print(field)
# Out:
# Total number of different fields: 221
# actuals
# actuals.cases
# actuals.contactTracers
# actuals.deaths
# actuals.hospitalBeds
# actuals.hospitalBeds.capacity
# actuals.hospitalBeds.currentUsageCovid
# actuals.hospitalBeds.currentUsageTotal
# actuals.hospitalBeds.weeklyCovidAdmissions
# actuals.hsaHospitalBeds
# actuals.hsaHospitalBeds.capacity
# actuals.hsaHospitalBeds.currentUsageCovid
# actuals.hsaHospitalBeds.currentUsageTotal
# actuals.hsaHospitalBeds.weeklyCovidAdmissions
# actuals.hsaIcuBeds
# actuals.hsaIcuBeds.capacity
# actuals.hsaIcuBeds.currentUsageCovid
# actuals.hsaIcuBeds.currentUsageTotal
# actuals.icuBeds
# actuals.icuBeds.capacity
# actuals.icuBeds.currentUsageCovid
# actuals.icuBeds.currentUsageTotal
# actuals.negativeTests
# actuals.newCases
# actuals.newDeaths
# actuals.positiveTests
# actuals.vaccinationsAdditionalDose
# actuals.vaccinationsCompleted
# actuals.vaccinationsFall2022BivalentBooster
# actuals.vaccinationsInitiated
# actuals.vaccinationsInitiatedDemographics
# actuals.vaccinesAdministered
# actuals.vaccinesAdministeredDemographics
# actuals.vaccinesDistributed
# annotations
# annotations.bedsWithCovidPatientsRatio
# annotations.bedsWithCovidPatientsRatio.anomalies
# annotations.bedsWithCovidPatientsRatio.sources
# annotations.bedsWithCovidPatientsRatio.sources.name
# annotations.bedsWithCovidPatientsRatio.sources.type
# annotations.bedsWithCovidPatientsRatio.sources.url
# annotations.caseDensity
# annotations.caseDensity.anomalies
# annotations.caseDensity.sources
# annotations.caseDensity.sources.name
# annotations.caseDensity.sources.type
# annotations.caseDensity.sources.url
# annotations.cases
# annotations.cases.anomalies
# annotations.cases.sources
# annotations.cases.sources.name
# annotations.cases.sources.type
# annotations.cases.sources.url
# annotations.contactTracerCapacityRatio
# annotations.contactTracerCapacityRatio.anomalies
# annotations.contactTracerCapacityRatio.sources
# annotations.contactTracerCapacityRatio.sources.name
# annotations.contactTracerCapacityRatio.sources.type
# annotations.contactTracerCapacityRatio.sources.url
# annotations.contactTracers
# annotations.contactTracers.anomalies
# annotations.contactTracers.sources
# annotations.contactTracers.sources.name
# annotations.contactTracers.sources.type
# annotations.contactTracers.sources.url
# annotations.deaths
# annotations.deaths.anomalies
# annotations.deaths.sources
# annotations.deaths.sources.name
# annotations.deaths.sources.type
# annotations.deaths.sources.url
# annotations.hospitalBeds
# annotations.hospitalBeds.anomalies
# annotations.hospitalBeds.sources
# annotations.hospitalBeds.sources.name
# annotations.hospitalBeds.sources.type
# annotations.hospitalBeds.sources.url
# annotations.hsaHospitalBeds
# annotations.hsaIcuBeds
# annotations.icuBeds
# annotations.icuBeds.anomalies
# annotations.icuBeds.sources
# annotations.icuBeds.sources.name
# annotations.icuBeds.sources.type
# annotations.icuBeds.sources.url
# annotations.icuCapacityRatio
# annotations.icuCapacityRatio.anomalies
# annotations.icuCapacityRatio.sources
# annotations.icuCapacityRatio.sources.name
# annotations.icuCapacityRatio.sources.type
# annotations.icuCapacityRatio.sources.url
# annotations.infectionRate
# annotations.infectionRate.anomalies
# annotations.infectionRate.sources
# annotations.infectionRate.sources.name
# annotations.infectionRate.sources.type
# annotations.infectionRate.sources.url
# annotations.infectionRateCI90
# annotations.infectionRateCI90.anomalies
# annotations.infectionRateCI90.sources
# annotations.infectionRateCI90.sources.name
# annotations.infectionRateCI90.sources.type
# annotations.infectionRateCI90.sources.url
# annotations.negativeTests
# annotations.negativeTests.anomalies
# annotations.negativeTests.sources
# annotations.negativeTests.sources.name
# annotations.negativeTests.sources.type
# annotations.negativeTests.sources.url
# annotations.newCases
# annotations.newCases.anomalies
# annotations.newCases.anomalies.date
# annotations.newCases.anomalies.original_observation
# annotations.newCases.anomalies.type
# annotations.newCases.sources
# annotations.newDeaths
# annotations.newDeaths.anomalies
# annotations.newDeaths.anomalies.date
# annotations.newDeaths.anomalies.original_observation
# annotations.newDeaths.anomalies.type
# annotations.newDeaths.sources
# annotations.positiveTests
# annotations.positiveTests.anomalies
# annotations.positiveTests.sources
# annotations.positiveTests.sources.name
# annotations.positiveTests.sources.type
# annotations.positiveTests.sources.url
# annotations.testPositivityRatio
# annotations.testPositivityRatio.anomalies
# annotations.testPositivityRatio.sources
# annotations.testPositivityRatio.sources.name
# annotations.testPositivityRatio.sources.type
# annotations.testPositivityRatio.sources.url
# annotations.vaccinationsAdditionalDose
# annotations.vaccinationsAdditionalDose.anomalies
# annotations.vaccinationsAdditionalDose.sources
# annotations.vaccinationsAdditionalDose.sources.name
# annotations.vaccinationsAdditionalDose.sources.type
# annotations.vaccinationsAdditionalDose.sources.url
# annotations.vaccinationsAdditionalDoseRatio
# annotations.vaccinationsCompleted
# annotations.vaccinationsCompleted.anomalies
# annotations.vaccinationsCompleted.sources
# annotations.vaccinationsCompleted.sources.name
# annotations.vaccinationsCompleted.sources.type
# annotations.vaccinationsCompleted.sources.url
# annotations.vaccinationsCompletedRatio
# annotations.vaccinationsFall2022BivalentBooster
# annotations.vaccinationsFall2022BivalentBooster.anomalies
# annotations.vaccinationsFall2022BivalentBooster.sources
# annotations.vaccinationsFall2022BivalentBooster.sources.name
# annotations.vaccinationsFall2022BivalentBooster.sources.type
# annotations.vaccinationsFall2022BivalentBooster.sources.url
# annotations.vaccinationsFall2022BivalentBoosterRatio
# annotations.vaccinationsInitiated
# annotations.vaccinationsInitiated.anomalies
# annotations.vaccinationsInitiated.sources
# annotations.vaccinationsInitiated.sources.name
# annotations.vaccinationsInitiated.sources.type
# annotations.vaccinationsInitiated.sources.url
# annotations.vaccinationsInitiatedRatio
# annotations.vaccinesAdministered
# annotations.vaccinesAdministered.anomalies
# annotations.vaccinesAdministered.sources
# annotations.vaccinesAdministered.sources.name
# annotations.vaccinesAdministered.sources.type
# annotations.vaccinesAdministered.sources.url
# annotations.vaccinesDistributed
# annotations.vaccinesDistributed.anomalies
# annotations.vaccinesDistributed.sources
# annotations.vaccinesDistributed.sources.name
# annotations.vaccinesDistributed.sources.type
# annotations.vaccinesDistributed.sources.url
# annotations.weeklyCovidAdmissionsPer100k
# annotations.weeklyNewCasesPer100k
# annotations.weeklyNewCasesPer100k.anomalies
# annotations.weeklyNewCasesPer100k.sources
# annotations.weeklyNewCasesPer100k.sources.name
# annotations.weeklyNewCasesPer100k.sources.type
# annotations.weeklyNewCasesPer100k.sources.url
# cdcTransmissionLevel
# communityLevels
# communityLevels.canCommunityLevel
# communityLevels.cdcCommunityLevel
# country
# county
# fips
# hsa
# hsaName
# hsaPopulation
# lastUpdatedDate
# lat
# level
# locationId
# long
# metrics
# metrics.bedsWithCovidPatientsRatio
# metrics.caseDensity
# metrics.contactTracerCapacityRatio
# metrics.icuCapacityRatio
# metrics.infectionRate
# metrics.infectionRateCI90
# metrics.testPositivityRatio
# metrics.testPositivityRatioDetails
# metrics.testPositivityRatioDetails.source
# metrics.vaccinationsAdditionalDoseRatio
# metrics.vaccinationsCompletedRatio
# metrics.vaccinationsFall2022BivalentBoosterRatio
# metrics.vaccinationsInitiatedRatio
# metrics.weeklyCovidAdmissionsPer100k
# metrics.weeklyNewCasesPer100k
# population
# riskLevels
# riskLevels.caseDensity
# riskLevels.contactTracerCapacityRatio
# riskLevels.icuCapacityRatio
# riskLevels.infectionRate
# riskLevels.overall
# riskLevels.testPositivityRatio
# state
# url

# %%
# URL for GET requests to retrieve data
url = "https://api.covidactnow.org/v2/state/TX.json?"
start_date = "2021-03-01"
end_date = "2021-03-03"
query_url = f"{url}apiKey={api_key}&start={start_date}&end={end_date}"

# Function to fetch and inspect the JSON data
def fetch_data(url):
    response = requests.get(url)
    response_json = response.json()
    return response_json

# Fetching data
covid_data = fetch_data(query_url)

# Printing the JSON structure to understand its layout
print(json.dumps(covid_data, indent=2))

# Access Data
hospitalizations_march_2021 = []
if 'counties' in covid_data:  # Ensure that counties key exists
    for county_data in covid_data['counties']:
        if 'county' in county_data and 'actuals' in county_data:
            county_name = county_data['county']
            if 'hsaHospitalBeds' in county_data['actuals']:
                hospitalizations = county_data['actuals']['hsaHospitalBeds']
                hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})

# Print the hospitalization data
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}")
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# {
#   "fips": "48",
#   "country": "US",
#   "state": "TX",
#   "county": null,
#   "hsa": null,
#   "hsaName": null,
#   "level": "state",
#   "lat": null,
#   "locationId": "iso1:us#iso2:us-tx",
#   "long": null,
#   "population": 28995881,
#   "hsaPopulation": null,
#   "metrics": {
#     "testPositivityRatio": null,
#     "testPositivityRatioDetails": {
#       "source": "other"
#     },
#     "caseDensity": null,
#     "weeklyNewCasesPer100k": null,
#     "contactTracerCapacityRatio": null,
#     "infectionRate": null,
#     "infectionRateCI90": null,
#     "icuCapacityRatio": 0.87,
#     "bedsWithCovidPatientsRatio": 0.003,
#     "weeklyCovidAdmissionsPer100k": 2.3,
#     "vaccinationsInitiatedRatio": 0.77,
#     "vaccinationsCompletedRatio": 0.635,
#     "vaccinationsAdditionalDoseRatio": 0.258,
#     "vaccinationsFall2022BivalentBoosterRatio": 0.113
#   },
#   "riskLevels": {
#     "overall": 4,
#     "testPositivityRatio": 4,
#     "caseDensity": 4,
#     "contactTracerCapacityRatio": 4,
#     "infectionRate": 4,
#     "icuCapacityRatio": 3
#   },
#   "cdcTransmissionLevel": 4,
#   "communityLevels": {
#     "cdcCommunityLevel": null,
#     "canCommunityLevel": 0
#   },
#   "actuals": {
#     "cases": 8508204,
#     "deaths": 93780,
#     "positiveTests": 8133115,
#     "negativeTests": 48879641,
#     "contactTracers": 3722,
#     "hospitalBeds": {
#       "capacity": 53596,
#       "currentUsageTotal": 43073,
#       "currentUsageCovid": 170,
#       "weeklyCovidAdmissions": 655
#     },
#     "hsaHospitalBeds": {
#       "capacity": null,
#       "currentUsageTotal": null,
#       "currentUsageCovid": null,
#       "weeklyCovidAdmissions": null
#     },
#     "icuBeds": {
#       "capacity": 5831,
#       "currentUsageTotal": 5054,
#       "currentUsageCovid": 103
#     },
#     "hsaIcuBeds": {
#       "capacity": null,
#       "currentUsageTotal": null,
#       "currentUsageCovid": null
#     },
#     "newCases": 5620,
#     "newDeaths": 42,
#     "vaccinesDistributed": 80813315,
#     "vaccinationsInitiated": 22322586,
#     "vaccinationsCompleted": 18406327,
#     "vaccinationsAdditionalDose": 7493737,
#     "vaccinationsFall2022BivalentBooster": 3288778,
#     "vaccinesAdministered": 52510128,
#     "vaccinesAdministeredDemographics": null,
#     "vaccinationsInitiatedDemographics": null
#   },
#   "annotations": {
#     "cases": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "deaths": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "positiveTests": {
#       "sources": [
#         {
#           "type": "HHSTesting",
#           "url": "https://healthdata.gov/dataset/COVID-19-Diagnostic-Laboratory-Testing-PCR-Testing/j8mb-icvb",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "negativeTests": {
#       "sources": [
#         {
#           "type": "HHSTesting",
#           "url": "https://healthdata.gov/dataset/COVID-19-Diagnostic-Laboratory-Testing-PCR-Testing/j8mb-icvb",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "contactTracers": {
#       "sources": [
#         {
#           "type": "TestAndTrace",
#           "url": null,
#           "name": null
#         }
#       ],
#       "anomalies": []
#     },
#     "hospitalBeds": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "hsaHospitalBeds": null,
#     "icuBeds": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "hsaIcuBeds": null,
#     "newCases": {
#       "sources": [],
#       "anomalies": [
#         {
#           "date": "2020-03-18",
#           "type": "zscore_outlier",
#           "original_observation": 60.0
#         },
#         {
#           "date": "2022-01-03",
#           "type": "zscore_outlier",
#           "original_observation": 164902.0
#         },
#         {
#           "date": "2023-03-23",
#           "type": "zscore_outlier",
#           "original_observation": 39282.0
#         }
#       ]
#     },
#     "newDeaths": {
#       "sources": [],
#       "anomalies": [
#         {
#           "date": "2022-11-11",
#           "type": "zscore_outlier",
#           "original_observation": 779.0
#         },
#         {
#           "date": "2022-12-07",
#           "type": "zscore_outlier",
#           "original_observation": 61.0
#         }
#       ]
#     },
#     "vaccinesDistributed": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "vaccinationsInitiated": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "vaccinationsCompleted": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "vaccinationsAdditionalDose": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "vaccinationsFall2022BivalentBooster": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "vaccinesAdministered": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc",
#           "name": "Centers for Disease Control and Prevention"
#         }
#       ],
#       "anomalies": []
#     },
#     "testPositivityRatio": {
#       "sources": [
#         {
#           "type": "HHSTesting",
#           "url": "https://healthdata.gov/dataset/COVID-19-Diagnostic-Laboratory-Testing-PCR-Testing/j8mb-icvb",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "caseDensity": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "weeklyNewCasesPer100k": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "contactTracerCapacityRatio": {
#       "sources": [
#         {
#           "type": "TestAndTrace",
#           "url": null,
#           "name": null
#         }
#       ],
#       "anomalies": []
#     },
#     "infectionRate": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "infectionRateCI90": {
#       "sources": [
#         {
#           "type": "other",
#           "url": [
#             "https://github.com/nytimes/covid-19-data",
#             "https://covid.cdc.gov/covid-data-tracker/#datatracker-home"
#           ],
#           "name": "Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards."
#         }
#       ],
#       "anomalies": []
#     },
#     "icuCapacityRatio": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "bedsWithCovidPatientsRatio": {
#       "sources": [
#         {
#           "type": "other",
#           "url": "https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh",
#           "name": "Department of Health and Human Services"
#         }
#       ],
#       "anomalies": []
#     },
#     "weeklyCovidAdmissionsPer100k": null,
#     "vaccinationsInitiatedRatio": null,
#     "vaccinationsCompletedRatio": null,
#     "vaccinationsAdditionalDoseRatio": null,
#     "vaccinationsFall2022BivalentBoosterRatio": null
#   },
#   "lastUpdatedDate": "2024-04-15",
#   "url": "https://covidactnow.org/us/texas-tx"
# }
# Total hospitalization entries for March 2021: 0

# %%
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()

# Extract and process hospitalization data for March 2021
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    hospitalizations = county_data["actuals"]["hsaHospitalBeds"]
    hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})

# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")

# Print hospitalization data for March 2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       6 hospitalizations_march_2021 = []
#       7 for county_data in covid_data:
# ----> 8     county_name = county_data["county"]
#       9     hospitalizations = county_data["actuals"]["hsaHospitalBeds"]
#      10     hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})
#
# TypeError: string indices must be integers

# %%
# Query URL with date range and API key
query_url = f"{url}apiKey={api_key}&date={start_date}-{end_date}"
# Make a GET request to retrieve the historical data
response = requests.get(query_url)
covid_data = response.json()
# Extract and process hospitalization data for March 2021
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    hospitalizations = county_data["actuals"]["hsaHospitalBeds"]
    hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})
# Print hospitalization data for March 2021

# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")

for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Hospitalizations in March 2021: {data['Hospitalizations']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       7 hospitalizations_march_2021 = []
#       8 for county_data in covid_data:
# ----> 9     county_name = county_data["county"]
#      10     hospitalizations = county_data["actuals"]["hsaHospitalBeds"]
#      11     hospitalizations_march_2021.append({"County": county_name, "Hospitalizations": hospitalizations})
#
# TypeError: string indices must be integers

# %%
response = requests.get(query_url)
covid_data = response.json()
print(covid_data)

for county_data in covid_data:
    county_name = county_data["county"]

    # Check if 'actualsTimeseries' is a list and iterate through it
    for date_entry in county_data["actuals"]:
        date = date_entry.get("date")
        # Filter for March 2021 entries
        if date.startswith("2021-03"):
            hospitalizations = date_entry.get("hsaHospitalBeds", {})
            # Check if 'hospitalizations' data exists and does not contain any "none" values
            if hospitalizations and not any(value == "none" for value in hospitalizations.values()):
                # Check if specific keys have values other than None
                if all(key not in hospitalizations or hospitalizations[key] is not None for key in ['capacity', 'currentUsageTotal', 'currentUsageCovid', 'weeklyCovidAdmissions']):
                    # Append a new entry for each date in March 2021
                    hospitalizations_march_2021.append({
                        "County": county_name,
                        "Date": date,
                        "Hospitalizations": hospitalizations
                    })
# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")
# Adjusted print to include date for data in hospitalizations_march_2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Date: {data['Date']}, Hospitalizations: {data['Hospitalizations']}")
# Out:
# {'fips': '48', 'country': 'US', 'state': 'TX', 'county': None, 'hsa': None, 'hsaName': None, 'level': 'state', 'lat': None, 'locationId': 'iso1:us#iso2:us-tx', 'long': None, 'population': 28995881, 'hsaPopulation': None, 'metrics': {'testPositivityRatio': None, 'testPositivityRatioDetails': {'source': 'other'}, 'caseDensity': None, 'weeklyNewCasesPer100k': None, 'contactTracerCapacityRatio': None, 'infectionRate': None, 'infectionRateCI90': None, 'icuCapacityRatio': 0.87, 'bedsWithCovidPatientsRatio': 0.003, 'weeklyCovidAdmissionsPer100k': 2.3, 'vaccinationsInitiatedRatio': 0.77, 'vaccinationsCompletedRatio': 0.635, 'vaccinationsAdditionalDoseRatio': 0.258, 'vaccinationsFall2022BivalentBoosterRatio': 0.113}, 'riskLevels': {'overall': 4, 'testPositivityRatio': 4, 'caseDensity': 4, 'contactTracerCapacityRatio': 4, 'infectionRate': 4, 'icuCapacityRatio': 3}, 'cdcTransmissionLevel': 4, 'communityLevels': {'cdcCommunityLevel': None, 'canCommunityLevel': 0}, 'actuals': {'cases': 8508204, 'deaths': 93780, 'positiveTests': 8133115, 'negativeTests': 48879641, 'contactTracers': 3722, 'hospitalBeds': {'capacity': 53596, 'currentUsageTotal': 43073, 'currentUsageCovid': 170, 'weeklyCovidAdmissions': 655}, 'hsaHospitalBeds': {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None, 'weeklyCovidAdmissions': None}, 'icuBeds': {'capacity': 5831, 'currentUsageTotal': 5054, 'currentUsageCovid': 103}, 'hsaIcuBeds': {'capacity': None, 'currentUsageTotal': None, 'currentUsageCovid': None}, 'newCases': 5620, 'newDeaths': 42, 'vaccinesDistributed': 80813315, 'vaccinationsInitiated': 22322586, 'vaccinationsCompleted': 18406327, 'vaccinationsAdditionalDose': 7493737, 'vaccinationsFall2022BivalentBooster': 3288778, 'vaccinesAdministered': 52510128, 'vaccinesAdministeredDemographics': None, 'vaccinationsInitiatedDemographics': None}, 'annotations': {'cases': {'sources': [{'type': 'other', 'url': ['https://github.com/nytimes/covid-19-data', 'https://covid.cdc.gov/covid-data-tracker/#datatracker-home'], 'name': 'Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.'}], 'anomalies': []}, 'deaths': {'sources': [{'type': 'other', 'url': ['https://github.com/nytimes/covid-19-data', 'https://covid.cdc.gov/covid-data-tracker/#datatracker-home'], 'name': 'Daily-resolution NYT data before 2023-03-23, weekly-resolution CDC data afterwards.'}], 'anomalies': []}, 'positiveTests': {'sources': [{'type': 'HHSTesting', 'url': 'https://healthdata.gov/dataset/COVID-19-Diagnostic-Laboratory-Testing-PCR-Testing/j8mb-icvb', 'name': 'Department of Health and Human Services'}], 'anomalies': []}, 'negativeTests': {'sources': [{'type': 'HHSTesting', 'url': 'https://healthdata.gov/dataset/COVID-19-Diagnostic-Laboratory-Testing-PCR-Testing/j8mb-icvb', 'name': 'Department of Health and Human Services'}], 'anomalies': []}, 'contactTracers': {'sources': [{'type': 'TestAndTrace', 'url': None, 'name': None}], 'anomalies': []}, 'hospitalBeds': {'sources': [{'type': 'other', 'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh', 'name': 'Department of Health and Human Services'}], 'anomalies': []}, 'hsaHospitalBeds': None, 'icuBeds': {'sources': [{'type': 'other', 'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh', 'name': 'Department of Health and Human Services'}], 'anomalies': []}, 'hsaIcuBeds': None, 'newCases': {'sources': [], 'anomalies': [{'date': '2020-03-18', 'type': 'zscore_outlier', 'original_observation': 60.0}, {'date': '2022-01-03', 'type': 'zscore_outlier', 'original_observation': 164902.0}, {'date': '2023-03-23', 'type': 'zscore_outlier', 'original_observation': 39282.0}]}, 'newDeaths': {'sources': [], 'anomalies': [{'date': '2022-11-11', 'type': 'zscore_outlier', 'original_observation': 779.0}, {'date': '2022-12-07', 'type': 'zscore_outlier', 'original_observation': 61.0}]}, 'vaccinesDistributed': {'sources': [{'type': 'other', 'u ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       3 print(covid_data)
#       5 for county_data in covid_data:
# ----> 6     county_name = county_data["county"]
#       8     # Check if 'actualsTimeseries' is a list and iterate through it
#       9     for date_entry in county_data["actuals"]:
#
# TypeError: string indices must be integers

# %%
response = requests.get(query_url)
covid_data = response.json()
print(covid_data)

# Ensure covid_data is a list of dictionaries; each dictionary represents a county
hospitalizations_march_2021 = []
for county_data in covid_data:
    county_name = county_data["county"]
    # Check if 'actualsTimeseries' is a list and iterate through it
    for date_entry in county_data["actualsTimeseries"]:
        date = date_entry.get("date")
        # Filter for March 2021 entries
        if date.startswith("2021-03"):
            hospitalizations = date_entry.get("hsaHospitalBeds", {})
            # Check if 'hospitalizations' data exists and does not contain any "none" values
            if hospitalizations and not any(value == "none" for value in hospitalizations.values()):
                # Check if specific keys have values other than None
                if all(key not in hospitalizations or hospitalizations[key] is not None for key in ['capacity', 'currentUsageTotal', 'currentUsageCovid', 'weeklyCovidAdmissions']):
                    # Append a new entry for each date in March 2021
                    hospitalizations_march_2021.append({
                        "County": county_name,
                        "Date": date,
                        "Hospitalizations": hospitalizations
                    })
# Printing the number of different fields
print(f"Total hospitalization entries for March 2021: {len(hospitalizations_march_2021)}\n")
# Adjusted print to include date for data in hospitalizations_march_2021
for data in hospitalizations_march_2021:
    print(f"County: {data['County']}, Date: {data['Date']}, Hospitalizations: {data['Hospitalizations']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4 hospitalizations_march_2021 = []
#       5 for county_data in covid_data:
# ----> 6     county_name = county_data["county"]
#       7     # Check if 'actualsTimeseries' is a list and iterate through it
#       8     for date_entry in county_data["actualsTimeseries"]:
#
# TypeError: string indices must be integers
